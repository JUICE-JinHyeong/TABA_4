# %%
from predict_rena_v3 import psng_predict_all_v3

# %%
test1 = psng_predict_all_v3(['여기 햄버거 정말 맛있어요' , '서비스가 개판입니다. 정말 끔찍했어요'])

# %%
test1.prediction()
# Out:
# 1/1 [==============================] - 1s 537ms/step
# ['0', '1']

# %%
import pandas as pd
datatest = pd.read_excel('model_test_data.xlsx')

# %%
test_lst = datatest.리뷰.tolist()

# %%
test_lst
# Out:
# ['좋아요',
#  '피낫버터랑 쿠키앤크림 맛있어요~',
#  '좋아요',
#  '굿',
#  '굿',
#  '젤라또는 맛있는데 아포카토는 먹지마세요\n구멍난 컵은 내 잘못이 아닌데..\n말했다가 기분이 상했네요',
#  '스타필드오면 꼭 먹어야하는 젤라또.',
#  '직원분이 친절해요 ~ 매장도 청결하구요 아이스크림도 맛있네요 👍',
#  '굳',
#  '골라먹는 젤리또 맛집\n굳굳굳 맛있었어요😆😆\n사이즈 업그레이드혜택도 있네요',
#  '젤라또 쫀득하게 맛있습니다',
#  '좋어요',
#  '굿',
#  '조아요',
#  '..',
#  '굿',
#  '맛있고.친절해요',
#  '맛나네요 굿',
#  '귯',
#  '굿굿',
#  '굿',
#  '친절해요',
#  '너무 맛있어요~~',
#  '친절해요 음료 맛있어요',
#  '.',
#  '좋아요',
#  '맛나요',
#  '맛있다...',
#  '친절하고 좋았어요',
#  '친절하고 좋았습니다',
#  '쫀득 쫀득 맛나유',
#  '좋아요',
#  '굿',
#  'ㅇㅇ',
#  '아이가 좋아해요,친절하시구요😁',
#  '라떼 맛있었어요 ☕️',
#  '지파시 스타필드시티 명지점',
#  '맛있어요!!',
#  '지파씨 아이스크림 달아도 너무 달아서 다 못먹겠어용 ㅠㅠ',
#  '젤라또 맛있어요😃',
#  '쌍콤한 젤라또는 역시 지파씨!! ㅎㅎ\n라즈베리는 진짜 최애맛 원ㄹ래 라즈베리 초콜라또 조합을 굉장히 좋아하는데 오늘은 그린티! ㅎㅎ 진짜 넘맛있어요 ㅎㅎ',
#  '맛있어요',
#  '양이 적다고 생각했는데 먹어보니 만족했어요.\n과일류들이 특히 더 맛있었습니다.',
#  '좋아요!',
#  '굿',
#  '굿',
#  '맛있어요~',
#  '젤라또가 먹고싶어서 사먹었어요.\n개인적으로 리조, 그린티 맛있어요 ㅎ',
#  '아이스크림이 맛있오요',
#  '생각보다 크기가 작아서 아쉽다고 생각했는데.. 먹어보니 그렇게 작진 않았어요 망고맛은 조금 별로 였고 갠적으로 한라봉이 맛있었어용',
# ...

# %%
test2 = psng_predict_all_v3(test_lst)

# %%
test2.prediction()
# Out:
# 4/4 [==============================] - 0s 26ms/step
# ['2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '0',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '0',
#  '0',
#  '1',
#  '0',
#  '2',
#  '2',
#  '2',
#  '0',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '1',
#  '0',
#  '2',
#  '0',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '0',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '0',
#  '0',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '1',
#  '2',
#  '0',
#  '1',
#  '2',
#  '2',
#  '2']
