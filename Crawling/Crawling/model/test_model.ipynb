# %%
from predict_rena import psng_predict_all

# %%
import pandas as pd
data = pd.read_excel('model_test_data.xlsx')
# data

# %%
test = psng_predict_all(data)

# %%
test.prediction()
# Out:
# 4/4 [==============================] - 1s 28ms/step
# ['0',
#  '2',
#  '0',
#  '2',
#  '2',
#  '1',
#  '0',
#  '0',
#  '2',
#  '0',
#  '2',
#  '1',
#  '2',
#  '1',
#  '1',
#  '2',
#  '0',
#  '2',
#  '1',
#  '0',
#  '2',
#  '2',
#  '0',
#  '0',
#  '1',
#  '0',
#  '2',
#  '0',
#  '0',
#  '0',
#  '2',
#  '0',
#  '2',
#  '1',
#  '2',
#  '2',
#  '2',
#  '0',
#  '1',
#  '2',
#  '0',
#  '0',
#  '0',
#  '0',
#  '2',
#  '2',
#  '0',
#  '2',
#  '1',
#  '2',
#  '2',
#  '1',
#  '1',
#  '2',
#  '2',
#  '0',
#  '2',
#  '1',
#  '0',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '0',
#  '1',
#  '0',
#  '1',
#  '2',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '2',
#  '0',
#  '0',
#  '0',
#  '2',
#  '2',
#  '0',
#  '0',
#  '0',
#  '2',
#  '0',
#  '0',
#  '0',
#  '0',
#  '2',
#  '1',
#  '1',
#  '2',
#  '2',
#  '1',
#  '2',
#  '0',
#  '1',
#  '2',
#  '0',
#  '0']

# %%
from predict_rena_v2 import psng_predict_all_v2

# %%
test = psng_predict_all_v2(data)

# %%
result_lst = test.prediction()
# Out:
# 4/4 [==============================] - 0s 28ms/step

# %%
frm = data[['리뷰']]

# %%
frm['result'] = result_lst
# Out:
# C:\Users\PiGiraffe0\AppData\Local\Temp\ipykernel_18040\1087312503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frm['result'] = result_lst

# %%
frm
# Out:
#                            리뷰 result
# 0                         좋아요      2
# 1           피낫버터랑 쿠키앤크림 맛있어요~      2
# 2                         좋아요      2
# 3                           굿      0
# 4                           굿      0
# ..                        ...    ...
# 95                         굿굿      0
# 96                       맛잇어요      2
# 97                          굿      0
# 98  로마에서 먹었던 파시를 먹을 수 있어서 좋아요      2
# 99                       맛있어요      0
#
# [100 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)
frm
# Out:
#                                                    리뷰 result
# 0                                                 좋아요      2
# 1                                   피낫버터랑 쿠키앤크림 맛있어요~      2
# 2                                                 좋아요      2
# 3                                                   굿      0
# 4                                                   굿      0
# 5   젤라또는 맛있는데 아포카토는 먹지마세요\n구멍난 컵은 내 잘못이 아닌데..\n말했다...      1
# 6                                 스타필드오면 꼭 먹어야하는 젤라또.      2
# 7                 직원분이 친절해요 ~ 매장도 청결하구요 아이스크림도 맛있네요 👍      0
# 8                                                   굳      2
# 9          골라먹는 젤리또 맛집\n굳굳굳 맛있었어요😆😆\n사이즈 업그레이드혜택도 있네요      0
# 10                                     젤라또 쫀득하게 맛있습니다      2
# 11                                                좋어요      2
# 12                                                  굿      0
# 13                                                조아요      2
# ...
