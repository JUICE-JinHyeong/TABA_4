# %%
# import os, sys
# from google.colab import drive
# drive.mount('/content/drive')
# my_path = '/content/notebooks'

# %%
from tensorflow.keras.layers import Embedding, Dense, GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from konlpy.tag import Okt
import re
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import urllib.request
from collections import Counter
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

okt = Okt()
# Out:
# D:\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
test_data = pd.read_csv('test_data.csv' , encoding = 'euc-kr')
train_data = pd.read_csv('train_data.csv' , encoding = 'euc-kr')

# %%
import tensorflow as tf
print(tf.__version__)
import keras
print(keras.__version__)
import konlpy
print(konlpy.__version__)
print(pd.__version__)
print(np.__version__)
# Out:
# 2.12.0
# 2.12.0
# 0.6.0
# 1.4.4
# 1.23.5

# %%
# loaded_model = load_model('/content/drive/MyDrive/data_review/best_model.h5')
# print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))

# 버전 확인
# pip install --upgrade tensorflow==2.12.0
# pip install --upgrade keras==2.12.0

loaded_model = load_model('best_model2.h5')

# %%
# 불용어를 지정하여 필요없는 토큰들은 제거하도록 합니다.

stopwords = ['도', '는', '다', '의', '가', '이', '은', 
             '한', '에', '하', '고', '을', '를', '인', '듯', 
             '과', '와', '네', '들', '듯', '지', '임', '게']

# %%
# 단어 집합(vocabulary)의 크기 : 64152
# 등장 빈도가 1번 이하인 희귀 단어의 수: 29480
# 단어 집합에서 희귀 단어의 비율: 45.953360768175585
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.289171484296422

# %%
# total_cnt = 64152
# rare_cnt = 29480
# vocab_size = total_cnt - rare_cnt + 2
# tokenizer = Tokenizer(vocab_size, oov_token = 'OOV')

# %%
# 긍정 리뷰보다는 부정 리뷰가 좀 더 길게 작성된 경향이 있는 것 같습니다.

X_train = train_data['tokenized'].values
y_train = train_data['label'].values
X_test= test_data['tokenized'].values
y_test = test_data['label'].values

# %%
# 정수 인코딩

# 기계가 텍스트를 숫자로 처리할 수 있도록 훈련 데이터와 테스트 데이터에 정수 인코딩을 수행해야 합니다. 
# 훈련 데이터에 대해서 단어 집합(vocaburary)을 만들어봅시다.

tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
total_cnt = 64152
rare_cnt = 29480
vocab_size = total_cnt - rare_cnt + 2

# %%
# 단어 집합의 크기는 34674개입니다. 
# 이를 토크나이저의 인자로 넘겨주고, 텍스트 시퀀스를 정수 시퀀스로 변환합니다. 
# 정수 인코딩 과정에서 이보다 큰 숫자가 부여된 단어들은 OOV로 변환하겠습니다.

tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
max_len = 330

# %%
# 훈련용 리뷰의 99.99%가 330 이하의 길이를 가집니다. 훈련용 리뷰를 길이 330으로 패딩하겠습니다.

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
# # test파일 업로드

# from google.colab import files

# # 파일 선택 대화상자 표시
# uploaded = files.upload()

# # 업로드한 파일 확인
# for filename in uploaded.keys():
#     print(f'Uploaded file: {filename}')

# %%
# test 파일 업로드 2
#uploaded
# test_re = pd.read_csv('/content/drive/MyDrive/(주)시더스초밥제주연동점_review.csv' , encoding = 'euc-kr')
test_re = pd.read_csv('(주)시더스초밥제주연동점_review.csv' , encoding = 'euc-kr')

# %%
# 결측치 처리
test_re = test_re.dropna().reset_index(drop=True)

# %%
def sentiment_predict(new_sentence):
    new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
    new_sentence = okt.morphs(new_sentence)
    new_sentence = [word for word in new_sentence if not word in stopwords]
    encoded = tokenizer.texts_to_sequences([new_sentence])
    pad_new = pad_sequences(encoded, maxlen = max_len)

    score = float(loaded_model.predict(pad_new))
    if (score > 0.5):
        print("{:.2f}% 확률로 긍정 리뷰입니다.".format(score * 100))
    else :
        print("{:.2f}% 확률로 부정 리뷰입니다.".format((1 - score) * 100))

# %%
# test
for num , i in enumerate(test_re.리뷰.tolist()) :
    print(num)
    print(i)
    print(sentiment_predict(i))
    print()
# Out:
# 0
# 원코스요리
# 1/1 [==============================] - 0s 267ms/step
# 84.22% 확률로 긍정 리뷰입니다.
# None
#
# 1
# 대박이에요
# 1/1 [==============================] - 0s 25ms/step
# 82.25% 확률로 긍정 리뷰입니다.
# None
#
# 2
# 역시시더니휴스템코리아영농조합 이라서 가능합니다
# 1/1 [==============================] - 0s 25ms/step
# 84.35% 확률로 긍정 리뷰입니다.
# None
#
# 3
# 맛도좋아요
# 1/1 [==============================] - 0s 24ms/step
# 82.25% 확률로 긍정 리뷰입니다.
# None
#
# 4
# 가성비 갑입니다
# 1/1 [==============================] - 0s 25ms/step
# 85.26% 확률로 긍정 리뷰입니다.
# None
#
# 5
# 신축이라서 깨끗하기도 하고 친절합니다
# 1/1 [==============================] - 0s 26ms/step
# 85.65% 확률로 긍정 리뷰입니다.
# None
#
# 6
# 신선한 회 초밥 너무나 맛나요
# 1/1 [==============================] - 0s 25ms/step
# 85.13% 확률로 긍정 리뷰입니다.
# None
#
# 7
# 또 오고싶어요
# 1/1 [==============================] - 0s 24ms/step
# 82.25% 확률로 긍정 리뷰입니다.
# None
#
# 8
# 잘 먹고왔어요
# 1/1 [==============================] - 0s 24ms/step
# 84.22% 확률로 긍정 리뷰입니다.
# None
#
# 9
# 재료도 신선 맛도 일품 아주 좋아요
# 1/1 [==============================] - 0s 28ms/step
# 85.58% 확률로 긍정 리뷰입니다.
# None
#
# 10
# 초밥이 너무 맛있고 흑돼지돈가스도 고기가 두꺼워요
# 1/1 [==============================] - 0s 25ms/step
# 84.35% 확률로 긍정 리뷰입니다.
# None
#
# 11
# 제주 렌트카 빌린곳 근처에 초밥집 있어서 먹었는데 맛있었어요
# 1/1 [==============================] - 0s 24ms/step
# 81.90% 확률로 긍정 리뷰입니다.
# None
#
# 12
# 구성도 많고 양도 충분하고 회도 괜찮고 인테리어 깔끔해요
# 1/1 [==============================] - 0s 25ms/step
# 84.35% 확률로 긍정 리뷰입니다.
# None
#
# 13
# 초밥 맛나게 먹었엉먹었어요
# 1/1 [==============================] - 0s 26ms/step
# 85.58% 확률로 긍정 리뷰입니다.
# None
#
# 14
# 생선살이 신선해요
# 1/1 [==============================] - 0s 25ms/step
# 84.22% 확률로 긍정 리뷰입니다.
# None
#
# 15
# 굿
# 1/1 [==============================] - 0s 28ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 16
# 근처 가까운 초밥먹을 곳이 여기뿐이라 가기하는데 가격대비 음식으좀알탕시켰는데 건더기 무 미나리 쬐끔에 알두개충격알밥도 그렇그 회덥밥도돈까스도 너무 얇고 그냥 초밥이 그나마 제일낫긴함
# 1/1 [==============================] - 0s 26ms/step
# 85.81% 확률로 부정 리뷰입니다.
# None
#
# 17
# 좋아요
# 1/1 [==============================] - 0s 25ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 18
# 재료가신선해요
# 1/1 [==============================] - 0s 26ms/step
# 82.25% 확률로 긍정 리뷰입니다.
# None
#
# 19
# 오늘의 초밥 먹을만 하네요  매장도 깔끔하고 좋아요
# 1/1 [==============================] - 0s 25ms/step
# 85.13% 확률로 긍정 리뷰입니다.
# None
#
# 20
# 서울에서 온지 년정도 된 도민입니다
# 1/1 [==============================] - 0s 27ms/step
# 84.35% 확률로 긍정 리뷰입니다.
# None
#
# 21
# 동네 지나가다가 리뷰도 나쁘지않아 방문하게 되었습니다
# 1/1 [==============================] - 0s 28ms/step
# 84.35% 확률로 긍정 리뷰입니다.
# None
#
# 22
# 하지만 왜 리뷰가 좋은지 이얘가 되질않네요
# 1/1 [==============================] - 0s 26ms/step
# 85.13% 확률로 긍정 리뷰입니다.
# None
#
# 23
# 초밥은 가성비는 괜찮고 맛은 있지도 맛없지도않는 보통의  한 맛있입니다
# 1/1 [==============================] - 0s 26ms/step
# 80.25% 확률로 긍정 리뷰입니다.
# None
#
# 24
# 하지만 식사류의 지리탕은 장말 천원이라고 믿기지 않을정도로 맛이 없었습니다
# 1/1 [==============================] - 0s 27ms/step
# 73.64% 확률로 긍정 리뷰입니다.
# None
#
# 25
# 첫번째 뚝배기는 뜨거운데 생선 안은 차갑고 비립니다 최소한 뜨뜻하게 안까지 익혀서댑혀는 주셔야죠
# 1/1 [==============================] - 0s 25ms/step
# 70.91% 확률로 긍정 리뷰입니다.
# None
#
# 26
# 다시 끓어달라고 하니 냉동생선이 얼마나 그안에 있었는지 모르겠지만 생선이 다 풀어지고 내용물도 형편없었습니다
# 1/1 [==============================] - 0s 28ms/step
# 67.96% 확률로 긍정 리뷰입니다.
# None
#
# 27
# 두번째 맛이 무맛입니다 진한 생선국물이 맛이 안나 양도적고 반찬도 새모이만큼
# 1/1 [==============================] - 0s 27ms/step
# 70.91% 확률로 긍정 리뷰입니다.
# None
#
# 28
# 만원에 판다고해도 다신 안먹을듯하네요
# 1/1 [==============================] - 0s 28ms/step
# 85.13% 확률로 긍정 리뷰입니다.
# None
#
# 29
# 기분좋게 엄마 모시고 갔는데 어린알바 친구들도 서비스 교육좀
# 1/1 [==============================] - 0s 31ms/step
# 80.25% 확률로 긍정 리뷰입니다.
# None
#
# 30
# 맛있어요 매장도 깔끔하고 룸도 있어서 모임장소로 좋은것 같아요
# 1/1 [==============================] - 0s 28ms/step
# 80.25% 확률로 긍정 리뷰입니다.
# None
#
# 31
# 후식으로 옆 카페  할인도 해주니 좋아요
# 1/1 [==============================] - 0s 29ms/step
# 85.13% 확률로 긍정 리뷰입니다.
# None
#
# 32
# 초밥 맛집 한군데 알았네요
# 1/1 [==============================] - 0s 27ms/step
# 85.26% 확률로 긍정 리뷰입니다.
# None
#
# 33
# 부분적으로 아쉬운게 있지만 전체적으로 괜찮아요
# 1/1 [==============================] - 0s 26ms/step
# 83.27% 확률로 긍정 리뷰입니다.
# None
#
# 34
# 오늘의초밥에서 유부랑계란고민하고있었는데
# 1/1 [==============================] - 0s 27ms/step
# 83.27% 확률로 긍정 리뷰입니다.
# None
#
# 35
# 둘다준다는말에 유부계란주는줄알았는데
# 1/1 [==============================] - 0s 26ms/step
# 85.58% 확률로 긍정 리뷰입니다.
# None
#
# 36
# 유부계란개
# 1/1 [==============================] - 0s 25ms/step
# 84.22% 확률로 긍정 리뷰입니다.
# None
#
# 37
# 말이라도잘해주지
# 1/1 [==============================] - 0s 26ms/step
# 84.22% 확률로 긍정 리뷰입니다.
# None
#
# 38
# 굳
# 1/1 [==============================] - 0s 25ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 39
# 특별해요
# 1/1 [==============================] - 0s 26ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 40
# 새로긴곳인지 방문했는데 친절하시고 회도 정말 맛있어요
# 1/1 [==============================] - 0s 25ms/step
# 83.27% 확률로 긍정 리뷰입니다.
# None
#
# 41
# 굿
# 1/1 [==============================] - 0s 28ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 42
# 첫방문 좋아요
# 1/1 [==============================] - 0s 27ms/step
# 84.22% 확률로 긍정 리뷰입니다.
# None
#
# 43
# 조아요
# 1/1 [==============================] - 0s 27ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 44
# 연어너무맛있어요
# 1/1 [==============================] - 0s 29ms/step
# 84.22% 확률로 긍정 리뷰입니다.
# None
#
# 45
# 밥이떡밥이고 우동국물은 맹탕이라 좀아쉬웠어요
# 1/1 [==============================] - 0s 27ms/step
# 83.27% 확률로 긍정 리뷰입니다.
# None
#
# 46
# 여자직원분 정말친절해요소문대로 상냥하고 과하지않게 친절하네요 먹고 나갈때까지 기분좋았어요
# 1/1 [==============================] - 0s 26ms/step
# 64.81% 확률로 긍정 리뷰입니다.
# None
#
# 47
# 조아요
# 1/1 [==============================] - 0s 28ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 48
# 굿
# 1/1 [==============================] - 0s 27ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 49
# 재료가 신선해용
# 1/1 [==============================] - 0s 28ms/step
# 82.25% 확률로 긍정 리뷰입니다.
# None
#
# 50
# 맛있음
# 1/1 [==============================] - 0s 27ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 51
# 자주 먹기에는 조금 비쌈
# 1/1 [==============================] - 0s 27ms/step
# 85.65% 확률로 긍정 리뷰입니다.
# None
#
# 52
# 조아요
# 1/1 [==============================] - 0s 25ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 53
# 굿좋아요
# 1/1 [==============================] - 0s 26ms/step
# 82.25% 확률로 긍정 리뷰입니다.
# None
#
# 54
# 굿
# 1/1 [==============================] - 0s 26ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 55
# 제주여행첫날
# 1/1 [==============================] - 0s 25ms/step
# 84.22% 확률로 긍정 리뷰입니다.
# None
#
# 56
#  시더스초밥 소개받고 왓는데 너무맛있어요 담에 여행오면 또와야겟어요
# 1/1 [==============================] - 0s 27ms/step
# 76.11% 확률로 긍정 리뷰입니다.
# None
#
# 57
# 여기 초밥 예술임 진짜 맛있어요 제주에서 초밥 제일 맛있는듯 합니다 직원분들도 친절하고 분위기도 좋고 최고네요
# 1/1 [==============================] - 0s 24ms/step
# 61.51% 확률로 긍정 리뷰입니다.
# None
#
# 58
# 좋아요
# 1/1 [==============================] - 0s 25ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 59
# 전체적으로 맛은 괜찮았어요
# 1/1 [==============================] - 0s 25ms/step
# 85.65% 확률로 긍정 리뷰입니다.
# None
#
# 60
# 진심 최고
# 1/1 [==============================] - 0s 26ms/step
# 82.25% 확률로 긍정 리뷰입니다.
# None
#
# 61
# 광어는 쫄깃하고 연어는 느끼함도없이 부드러움요 간장새우초밥도 너무맛있어요
# 1/1 [==============================] - 0s 26ms/step
# 76.11% 확률로 긍정 리뷰입니다.
# None
#
# 62
# 정말 신선하고 밥양도 딱좋아요
# 1/1 [==============================] - 0s 24ms/step
# 85.65% 확률로 긍정 리뷰입니다.
# None
#
# 63
# 그리고 엄청친절해요
# 1/1 [==============================] - 0s 24ms/step
# 84.22% 확률로 긍정 리뷰입니다.
# None
#
# 64
# 너무맛있게 잘먹언요 또갈께요
# 1/1 [==============================] - 0s 25ms/step
# 84.35% 확률로 긍정 리뷰입니다.
# None
#
# 65
# 가성비를 따진다면 좀
# 1/1 [==============================] - 0s 26ms/step
# 85.26% 확률로 긍정 리뷰입니다.
# None
#
# 66
# 원짜리가 만원짜리 초밥보다 못해요
# 1/1 [==============================] - 0s 27ms/step
# 83.27% 확률로 긍정 리뷰입니다.
# None
#
# 67
# 우동도 다식은거 대충주고 퀄리티는 개뿔 맛없음
# 1/1 [==============================] - 0s 25ms/step
# 84.35% 확률로 긍정 리뷰입니다.
# None
#
# 68
# 제주 초밥맛집이 여기네요 초밥 회가 엄청 부드럽고 완전 녹아요 고급 횟감 쓰는것 같아요 직원들 전부 친절하시고 가격도 괜찮아요 분위기도 좋고 자주 갈 것 같아요
# 1/1 [==============================] - 0s 24ms/step
# 61.76% 확률로 부정 리뷰입니다.
# None
#
# 69
# 혼밥하기 좋음 쏘쏘
# 1/1 [==============================] - 0s 26ms/step
# 85.65% 확률로 긍정 리뷰입니다.
# None
#
# 70
# 굿
# 1/1 [==============================] - 0s 25ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 71
# 좋아요
# 1/1 [==============================] - 0s 26ms/step
# 78.74% 확률로 긍정 리뷰입니다.
# None
#
# 72
# 가격이 좀 비싼편이고 음식양이 작아요
# 1/1 [==============================] - 0s 24ms/step
# 85.13% 확률로 긍정 리뷰입니다.
# None
#
# 73
# 초밥은 밥양이 많지 않아 맛있고 좋았어요
# 1/1 [==============================] - 0s 25ms/step
# 85.13% 확률로 긍정 리뷰입니다.
# None
#
# 74
# 시더스 오늘의 초밥 먹방
# 1/1 [==============================] - 0s 24ms/step
# 85.65% 확률로 긍정 리뷰입니다.
# None
