# %%
import re
import pandas as pd
import numpy as np 
# import matplotlib.pyplot as plt
# import urllib.request
from collections import Counter
from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from konlpy.tag import Okt
from tensorflow.keras.models import load_model
import json

# %%
# import tensorflow
# import keras
# import numpy as np
# import pandas as pd
# import h5py
# import konlpy 

# print('tensorflow ',tensorflow.__version__)
# print('keras', keras.__version__)
# print('numpy', np.__version__)
# print('padnas', pd.__version__)
# print('h5py', h5py.__version__)
# print('konlpy', konlpy.__version__)

# %%
# class psng_predict_all:
#     def __init__(self, df):
#         self.df = df
#         path = 'C:/Users/PiGiraffe0/Documents/triton-modeldata/modeldata'
#         self.loaded_model = load_model(f'{path}/new_model_01_v2.h5')
#         train_data = pd.read_csv(f'{path}/train_data_main.csv', encoding='euc-kr')
#         test_data = pd.read_csv(f'{path}/test_data_main.csv', encoding='euc-kr')
#         X_train = train_data['tokenized'].apply(eval).values
#         self.X_test = test_data['tokenized'].apply(eval).values
#         self.y_test = np.array(test_data['label'].values)
#         self.X_test_tkd = None
#         vocab_size = 87912 # change
#         self.tokenizer = Tokenizer(vocab_size, oov_token='OOV')
#         self.tokenizer.fit_on_texts(X_train)
#         self.max_len = 250

#     def preprocessing(self):
#         okt = Okt()
#         R_frm = self.df.copy()
#         R_frm['리뷰'] = R_frm['리뷰'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", regex=True)
#         R_frm['리뷰'].replace('', np.nan, inplace=True)
#         R_frm['리뷰'] = R_frm['리뷰'].astype(str)
#         stopwords = ['도', '는', '다', '의', '가', '이', '은',
#                      '한', '에', '하', '고', '을', '를', '인', '듯',
#                      '과', '와', '네', '들', '듯', '지', '임', '게',
#                      '는', '이', '했', '슴', '음', '것', '거', '로',
#                      '들', '거', '곳', '분', '원', '더', '왜', '해',
#                      '수', '할', '그', '함', '돈', '번', '두', '개',
#                      '건', '내', '저', '만', '갈', '걸', '제', '명',
#                      '분',
#                      '인데', '이가', '했었', '해서',
#                      '습니다', '했는데', '입니다']

#         okt = Okt()
#         R_frm['tokenized'] = R_frm['리뷰'].apply(okt.pos)
#         # R_frm['tokenized'] = R_frm['리뷰'].apply(lambda x: okt.pos(x, norm=True, stem=True))
#         R_frm['tokenized'] = R_frm['tokenized'].apply(
#             lambda x: [word for word, shape in x if shape in ['Verb', 'Adjective', 'Noun', 'VerbPrefix'] if word not in stopwords])
#         R_pred = R_frm['tokenized'].values
#         return R_pred

#     def model_test(self):
#         tokenizer = self.tokenizer
#         X_test = tokenizer.texts_to_sequences(self.X_test)
#         y_test = self.y_test
#         X_test = pad_sequences(X_test, maxlen=self.max_len)
#         print("\n 테스트 정확도: %.4f" % (self.loaded_model.evaluate(X_test, y_test)[1]))

#     def word_index(self):
#         tokenizer = self.tokenizer
#         print(tokenizer.word_index)

#     def predict(self):
#         R_pred = self.preprocessing()
#         max_len = self.max_len
#         tokenizer = self.tokenizer
#         result = []
#         pred = tokenizer.texts_to_sequences(R_pred)
#         pred = pad_sequences(pred, maxlen=max_len)
#         score = self.loaded_model.predict(pred)
#         return score

#     def prediction(self):
#         result = []
#         score = self.predict()
#         for num in range(len(score)):
#             if score[num][0] > 0.9:
#                 result.append('0')
#             elif score[num][0] < 0.1:
#                 result.append('1')
#             else:
#                 result.append('2')
#         return result

# %%
# youngho/nare

import pyodbc

DSNNAME = "Tibero6"
DBUSER = "youngho"
DBPWD = "nare"

cnxn = pyodbc.connect('DSN='+DSNNAME+';UID='+DBUSER+';PWD='+DBPWD)
cursor = cnxn.cursor()
cursor.execute("SELECT REST_ID , REVIEW , LABEL_TF from REVIEW_TF;")

# 1개 row만 가져오기
# row = cursor.fetchone()
# 모든 row 가져오기
row2 = cursor.fetchall()
# while row :
#     print(row[0])
#     row = cursor.fetchone()
#     # row = cursor.fetchall()
# print(row)

cnxn.commit()
cnxn.close()

# %%
### youngho/nare

import pyodbc

DSNNAME = "Tibero6"
DBUSER = "JH"
DBPWD = "nare"

cnxn = pyodbc.connect('DSN='+DSNNAME+';UID='+DBUSER+';PWD='+DBPWD)
cursor = cnxn.cursor()
cursor.execute("SELECT REST_ID , REVIEW from youngho.REVIEW_TF;")

# 1개 row만 가져오기
# row = cursor.fetchone()
# 모든 row 가져오기
row = cursor.fetchall()
# while row :
#     print(row[0])
#     row = cursor.fetchone()
#     # row = cursor.fetchall()
# print(row)

cnxn.commit()
cnxn.close()

# %%
len(row)
# Out:
# 77509

# %%
type(row[0])
# Out:
# tuple

# %%
import pandas as pd

row = [
    ('1713847517', '너무맛있다', 'F'),
    ('1713847517', '최고 제주시내 최고인것같음', 'T'),
    ('1713847517', '분위기도 좋고\n맛도 좋고\n친절한 설명까지~!^^\n행복한 시간이었습니다#\n감사합니다~!', 'T'),
    ('1713847517', '리뷰를 미리 남겨버렸네요 ?\n분위기 좋고 친절한 직원분들덕에 제주도에서 분위기내고 식사할 수 있었어요~~^^', 'F'),
    ('1713847517', '전 양고기스테이크 맛있었고 디저트 코코파인도 맛있었어요!!\n소고기스테이크는 레어로 구워야 덜 질길 것 같아요! 스테이크 다 미디움레어로 했는데 소고기는 좀 많이 익은 느낌이었고 오리는 보통 양고기는 딱 좋았어요!!\n같이 왔던 지인은 오리고기스테이크가 제일 특별하고 맛있었대요!! 어디가서 먹어보기 힘든 음식이라고 맛있었다고 하더라구요~~\n그리고 직원분이 와인 설명도 잘 해주시고 나중에 대리도 불러주시고 엄청 친절하셨어요 감사합니다~\n버섯 리조또(?)가 평이 엄청 좋아서 다음에는 버섯 리조또랑 뇨끼 먹어보고 싶어요 ㅎㅎ\n분위기도 좋고 맛도 있어서 제주도에서 특별한 저녁식사 하고가용 ☺️', 'T')
]

# DataFrame으로 변환
df = pd.DataFrame(row, columns=['REST_ID', 'REVIEW', 'LABEL_TF'])

# 결과 출력
print(df)
# Out:
#       REST_ID                                             REVIEW LABEL_TF
# 0  1713847517                                              너무맛있다        F
# 1  1713847517                                     최고 제주시내 최고인것같음        T
# 2  1713847517  분위기도 좋고\n맛도 좋고\n친절한 설명까지~!^^\n행복한 시간이었습니다#\n감사...        T
# 3  1713847517  리뷰를 미리 남겨버렸네요 ?\n분위기 좋고 친절한 직원분들덕에 제주도에서 분위기내고...        F
# 4  1713847517  전 양고기스테이크 맛있었고 디저트 코코파인도 맛있었어요!!\n소고기스테이크는 레어로...        T

# %%
data = row
#data

# %%
lst_id = []
lst_review = []
for i, r in row :
    lst_id.append(i)
    lst_review.append(r)

# %%
row_frm = pd.DataFrame({'REST_ID' : lst_id , 'REVIEW' : lst_review})
row_json = row_frm[['REVIEW']]

# %%
row_frm = pd.DataFrame({'REST_ID' : lst_id , 'REVIEW' : lst_review})
row_json = row_frm[['REVIEW']]
json_row = row_json.to_json(orient='records', force_ascii=False)

# %%
# json_data = json.loads(json_row)
# for review in json_data :
#     print(review['REVIEW'])

# %%
class psng_predict_all_v2:
    def __init__(self, df):
        self.df = df
        path = ''
        self.loaded_model = load_model(f'{path}posneg_no_oneword_v3.h5')
        train_data = pd.read_csv(f'{path}train_data_main_v2.csv', encoding='euc-kr')
        
        X_train = train_data['tokenized'].apply(eval).values
        vocab_size = 20894 # change
        self.tokenizer = Tokenizer(vocab_size, oov_token='OOV')
        self.tokenizer.fit_on_texts(X_train)
        self.max_len = 250

    def preprocessing(self):
        okt = Okt()
        R_frm = self.df.copy()
        R_frm['REVIEW'] = R_frm['REVIEW'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", regex=True)
        R_frm['REVIEW'].replace('', np.nan, inplace=True)
        R_frm['REVIEW'] = R_frm['REVIEW'].astype(str)
        stopwords = ['도', '는', '다', '의', '가', '이', '은',
                     '한', '에', '하', '고', '을', '를', '인', '듯',
                     '과', '와', '네', '들', '듯', '지', '임', '게',
                     '는', '이', '했', '슴', '음', '것', '거', '로',
                     '들', '거', '곳', '분', '원', '더', '왜', '해',
                     '수', '할', '그', '함', '돈', '번', '두', '개',
                     '건', '내', '저', '만', '갈', '걸', '제', '명',
                     '분',
                     '인데', '이가', '했었', '해서',
                     '습니다', '했는데', '입니다']

        okt = Okt()
        # R_frm['tokenized'] = R_frm['리뷰'].apply(okt.pos)
        R_frm['tokenized'] = R_frm['리뷰'].apply(lambda x: okt.pos(x, norm=True, stem=True))
        R_frm['tokenized'] = R_frm['tokenized'].apply(
            lambda x: [word for word, shape in x if shape in ['Verb', 'Adjective', 'Noun', 'VerbPrefix'] if word not in stopwords])
        R_pred = R_frm['tokenized'].values
        return R_pred

    def model_test(self):
        tokenizer = self.tokenizer
        X_test = tokenizer.texts_to_sequences(self.X_test)
        y_test = self.y_test
        X_test = pad_sequences(X_test, maxlen=self.max_len)
        print("\n 테스트 정확도: %.4f" % (self.loaded_model.evaluate(X_test, y_test)[1]))

    def word_index(self):
        tokenizer = self.tokenizer
        print(tokenizer.word_index)

    def predict(self):
        R_pred = self.preprocessing()
        max_len = self.max_len
        tokenizer = self.tokenizer
        result = []
        pred = tokenizer.texts_to_sequences(R_pred)
        pred = pad_sequences(pred, maxlen=max_len)
        score = self.loaded_model.predict(pred)
        return score

    def prediction(self):
        result = []
        score = self.predict()
        for num in range(len(score)):
            if score[num][0] > 0.9:
                result.append('0')
            elif score[num][0] < 0.1:
                result.append('1')
            else:
                result.append('2')
        return result

# %%
class psng_predict_all_v3:
    def __init__(self, lst):
        self.lst = lst
        path = ''
        self.loaded_model = load_model(f'{path}posneg_no_oneword_v3.h5')
        train_data = pd.read_csv(f'{path}train_data_main_v2.csv', encoding='euc-kr')
        
        X_train = train_data['tokenized'].apply(eval).values
        vocab_size = 20894 # change
        self.tokenizer = Tokenizer(vocab_size, oov_token='OOV')
        self.tokenizer.fit_on_texts(X_train)
        self.max_len = 250

    def preprocessing(self):
        okt = Okt()
        R_lst = self.lst
        R_frm = pd.DataFrame(R_lst , columns = ['REVIEW'])
        R_frm['REVIEW'] = R_frm['REVIEW'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", regex=True)
        R_frm['REVIEW'].replace('', np.nan, inplace=True)
        R_frm['REVIEW'] = R_frm['REVIEW'].astype(str)
        stopwords = ['도', '는', '다', '의', '가', '이', '은',
                     '한', '에', '하', '고', '을', '를', '인', '듯',
                     '과', '와', '네', '들', '듯', '지', '임', '게',
                     '는', '이', '했', '슴', '음', '것', '거', '로',
                     '들', '거', '곳', '분', '원', '더', '왜', '해',
                     '수', '할', '그', '함', '돈', '번', '두', '개',
                     '건', '내', '저', '만', '갈', '걸', '제', '명',
                     '분',
                     '인데', '이가', '했었', '해서',
                     '습니다', '했는데', '입니다']

        okt = Okt()
        # R_frm['tokenized'] = R_frm['리뷰'].apply(okt.pos)
        R_frm['tokenized'] = R_frm['리뷰'].apply(lambda x: okt.pos(x, norm=True, stem=True))
        R_frm['tokenized'] = R_frm['tokenized'].apply(
            lambda x: [word for word, shape in x if shape in ['Verb', 'Adjective', 'Noun', 'VerbPrefix'] if word not in stopwords])
        R_pred = R_frm['tokenized'].values
        return R_pred

    def model_test(self):
        tokenizer = self.tokenizer
        X_test = tokenizer.texts_to_sequences(self.X_test)
        y_test = self.y_test
        X_test = pad_sequences(X_test, maxlen=self.max_len)
        print("\n 테스트 정확도: %.4f" % (self.loaded_model.evaluate(X_test, y_test)[1]))

    def word_index(self):
        tokenizer = self.tokenizer
        print(tokenizer.word_index)

    def predict(self):
        R_pred = self.preprocessing()
        max_len = self.max_len
        tokenizer = self.tokenizer
        result = []
        pred = tokenizer.texts_to_sequences(R_pred)
        pred = pad_sequences(pred, maxlen=max_len)
        score = self.loaded_model.predict(pred)
        return score

    def prediction(self):
        result = []
        score = self.predict()
        for num in range(len(score)):
            if score[num][0] > 0.9:
                result.append('0')
            elif score[num][0] < 0.1:
                result.append('1')
            else:
                result.append('2')
        return result

# %%
def test ():
#     self.lst = lst
    path = ''
    loaded_model = load_model(f'{path}posneg_no_oneword_v3.h5')
    train_data = pd.read_csv(f'{path}train_data_main_v2.csv', encoding='euc-kr')

    X_train = train_data['tokenized'].apply(eval).values
    vocab_size = 20894 # change
    tokenizer = Tokenizer(vocab_size, oov_token='OOV')
    tokenizer.fit_on_texts(X_train)
    max_len = 250
    
    return tokenizer

# %%
tknzr = test()

# %%
tknzr.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tknzr.value
#
# AttributeError: 'Tokenizer' object has no attribute 'value'

# %%
import pickle

def test():
    path = ''
    loaded_model = load_model(f'{path}posneg_no_oneword_v3.h5')
    train_data = pd.read_csv(f'{path}train_data_main_v2.csv', encoding='euc-kr')

    X_train = train_data['tokenized'].apply(eval).values
    vocab_size = 20894
    tokenizer = Tokenizer(vocab_size, oov_token='OOV')
    tokenizer.fit_on_texts(X_train)
    max_len = 250

    # 파일로 tokenizer 객체 저장
    with open('tokenizer.pickle', 'wb') as f:
        pickle.dump(tokenizer, f)

    return tokenizer

# %%
tknzr = test()

# %%
import pickle

# 저장된 tokenizer 객체 로드
with open('tokenizer.pickle', 'rb') as f:
    tokenizer = pickle.load(f)

# tokenizer 객체 사용
# ...

# %%
tokenizer

# %%
tokenizer = test()  # tokenizer 객체를 얻어온다.

# 단어와 인덱스 매핑 확인
word_index = tokenizer.word_index
print("단어와 인덱스 매핑:")
for word, index in word_index.items():
    print(f"{word}: {index}")

# 인덱스와 단어 매핑 확인
index_word = tokenizer.index_word
print("\n인덱스와 단어 매핑:")
for index, word in index_word.items():
    print(f"{index}: {word}")
# Out:
# 단어와 인덱스 매핑:
# OOV: 1
# 하다: 2
# 맛: 3
# 먹다: 4
# 있다: 5
# 맛있다: 6
# 좋다: 7
# 없다: 8
# 안: 9
# 이다: 10
# 않다: 11
# 가다: 12
# 같다: 13
# 집: 14
# 나오다: 15
# 가격: 16
# 아니다: 17
# 많다: 18
# 보다: 19
# 되다: 20
# 음식: 21
# 정말: 22
# 들다: 23
# 그냥: 24
# 오다: 25
# 사람: 26
# 방문: 27
# 고기: 28
# 별로: 29
# 좀: 30
# 시키다: 31
# 싶다: 32
# 때: 33
# 정도: 34
# 그렇다: 35
# 주문: 36
# 자다: 37
# 메뉴: 38
# 직원: 39
# 생각: 40
# 진짜: 41
# 못: 42
# 분위기: 43
# 괜찮다: 44
# 다른: 45
# 밥: 46
# 서비스: 47
# 느낌: 48
# 손님: 49
# 나다: 50
# 양: 51
# 비싸다: 52
# 주다: 53
# 친절하다: 54
# 시간: 55
# 커피: 56
# 들어가다: 57
# 하나: 58
# 모르다: 59
# 국물: 60
# 가게: 61
# 추천: 62
# 말: 63
# 식당: 64
# 여기: 65
# 깔끔하다: 66
# 카페: 67
# 테이블: 68
# 받다: 69
# 기다리다: 70
# 갈다: 71
# 빵: 72
# 조금: 73
# 점: 74
# 줄: 75
# 좋아하다: 76
# 짜다: 77
# 사장: 78
# 자리: 79
# 중: 80
# 처음: 81
# 유명하다: 82
# 식사: 83
# 기분: 84
# 전: 85
# 크다: 86
# 맛없다: 87
# 소스: 88
# 아쉽다: 89
# 되어다: 90
# 적다: 91
# 성비: 92
# 시: 93
# 말다: 94
# 가지: 95
# 불친절하다: 96
# 주차: 97
# 다시: 98
# 파스타: 99
# 튀김: 100
# 반찬: 101
# 해주다: 102
# 나: 103
# 만두: 104
# 아주: 105
# 가보다: 106
# 또: 107
# 이렇다: 108
# 면: 109
# 기본: 110
# 보고: 111
# 먹기: 112
# 알다: 113
# 최악: 114
# 만들다: 115
# 30920: 렌
# 30921: 빠다
# 30922: 무방비
# 30923: 뉴릉
# 30924: 주윌
# 30925: 빠작
# 30926: 흘끗
# 30927: 누수
# 30928: 엎어놔
# 30929: 자랑거리다
# 30930: 아오이
# 30931: 조카딸
# 30932: 경로당
# 30933: 근해
# 30934: 어른거리다
# 30935: 수출
# 30936: 바벨탑
# 30937: 희망봉
# 30938: 꼬꾸라지다
# 30939: 금융위기
# 30940: 생복
# 30941: 공력
# 30942: 안속
# 30943: 황토색
# 30944: 그닥이엿둠
# 30945: 녹사평역
# 30946: 사다리
# 30947: 애송이
# 30948: 풍경화
# 30949: 허우적거리다
# 30950: 빗나가다
# 30951: 쿠비
# 30952: 파벨
# 30953: 샤도네
# 30954: 바네스
# 30955: 반듯하다
# 30956: 다난
# 30957: 동양화
# 30958: 옹색
# 30959: 누누
# 30960: 뭄넌무
# 30961: 토티
# 30962: 고걸
# 30963: 까딱이다
# 30964: 팔리니
# 30965: 불유쾌
# 30966: 우월감
# 30967: 매매
# 30968: 면알
# 30969: 바피
# 30970: 닭챠슈
# 30971: 좔
# 30972: 마싯쪙
# 30973: 유쾌
# 30974: 상쾌
# 30975: 통쾌
# 30976: 컬러풀
# 30977: 이씨
# 30978: 베지터
# 30979: 무기한
# 30980: 교관
# 30981: 체킹
# 30982: 무사비
# 30983: 바리톤
# 30984: 뽀짜이판
# 30985: 버벅거렸는데
# 30986: 이베이
# 30987: 봥
# 30988: 통복
# 30989: 교만
# 30990: 할리갈리
# 30991: 떡락
# 30992: 쭈그렁
# 30993: 이민호
# 30994: 스테이지
# 30995: 촉진
# 30996: 흐물했음
# 30997: 드나
# 30998: 놨어
# 30999: 항도
# 31000: 복배
# 31001: 가쥐먀새효
# 31002: 잉봉싞댱
# 31003: 마넌
# 31004: 꼬불거리
# 31005: 카운티
# 31006: 임이도
# 31007: 문정식
# 31008: 망마
# 31009: 단결
# 31010: 뿌님팟퐁까리
# 31011: 맹우
# 31012: 유애
# 31013: 빻았으
# 31014: 주변머리
# 31015: 넋두리
# 31016: 쒯더아
# 31017: 동송루
# 31018: 긎
# 31019: 강권
# 31020: 식비
# 31021: 프레임
# 31022: 방알
# 31023: 공리
# 31024: 꼬끼오
# 31025: 일박
# 31026: 필통
# 31027: 캣
# 31028: 버캐
# 31029: 변방
# 31030: 표백
# 31031: 끙끙
# 31032: 우운
# 31033: 소셜미디어
# 31034: 연습장
# 31035: 등록증
# 31036: 탭룸
# 31037: 이취
# 31038: 갤럭시
# 31039: 홍리
# 31040: 리젠
# 31041: 반구동
# 31042: 어자
# 31043: 쉬름프
# 31044: 평민
# 31045: 국맛
# 31046: 더티해
# 31047: 현영
# 31048: 교토시
# 31049: 마차도
# 31050: 돈코츠중
# 31051: 약어
# 31052: 침노
# 31053: 동묘앞역
# 31054: 푸팟풍
# 31055: 별룬뎅
# 31056: 장티푸스
# 31057: 억하심정
# 31058: 루번
# 31059: 히러
# 31060: 신천지
# 31061: 두갸르송
# 31062: 않슘다
# 31063: 옮갸
# 31064: 상줄
# 31065: 처신
# 31066: 씨지브이
# 31067: 밀땅
# 31068: 부가가치
# 31069: 박용
# 31070: 훈도면
# 31071: 분열
# 31072: 닭밥국
# 31073: 빗방울
# 31074: 민문연
# 31075: 떨어트려놓
# 31076: 자삭
# 31077: 측정기
# 31078: 뉴웨이브
# 31079: 해운대온천
# 31080: 봉퍙이
# 31081: 도고온천
# 31082: 김종림
# 31083: 칼국슨
# 31084: 오죽헌
# 31085: 캔버스
# 31086: 멉을만
# 31087: 꼬뿌잔
# 31088: 동트
# 31089: 홍은동
# 31090: 읎으
# 31091: 주무르다
# 31092: 팽창
# 31093: 싱그
# 31094: 비긴
# 31095: 소화기관
# 31096: 엲
# 31097: 물구나무서기
# 31098: 사주지
# 31099: 무르거
# 31100: 돈탕반
# 31101: 직거린
# 31102: 직거려
# 31103: 스팸류
# 31104: 노버트
# 31105: 노조
# 31106: 짜임
# 31107: 뿜뿜함
# 31108: 중간지점
# 31109: 급땅겨
# 31110: 친추
# 31111: 쿠랑
# 31112: 뿌남퐁
# 31113: 재산
# 31114: 몰수
# 31115: 일벌
# 31116: 엄벌
# 31117: 바삭쫀득
# 31118: 라뒤레
# 31119: 소복하다
# 31120: 안딲앗
# 31121: 쾨쾨
# 31122: 쉑섁
# 31123: 샵겹살
# 31124: 몽쉘
# 31125: 쇼숑드뽐므
# 31126: 통밥
# 31127: 해인
# 31128: 둨
# 31129: 사이클
# 31130: 완자류
# 31131: 외산
# 31132: 문법
# 31133: 태깔
# 31134: 저었더
# 31135: 롤를
# 31136: 재봉
# 31137: 샹궈마라롱샤
# 31138: 항거
# 31139: 일여
# 31140: 혀으
# 31141: 동본
# 31142: 배륵
# 31143: 비비빅
# 31144: 병입
# 31145: 면괴
# 31146: 골탕
# 31147: 실드
# 31148: 디즈니
# 31149: 짹
# 31150: 달골
# 31151: 랐습나
# 31152: 정초
# 31153: 도르프
# 31154: 박지영
# 31155: 농간
# 31156: 해삼만
# 31157: 비명
# 31158: 월미도
# 31159: 엠시
# 31160: 거셔
# 31161: 밀크쉐이크
# 31162: 화이트골드
# 31163: 빠삐용
# 31164: 감잎
# 31165: 마두
# 31166: 채원
# 31167: 필녀
# 31168: 빈대
# 31169: 관리사
# 31170: 인셉션
# 31171: 포근포근
# 31172: 드레이프
# 31173: 독산역
# 31174: 복자
# 31175: 뛰어나가다
# 31176: 야맹증
# 31177: 정망
# 31178: 어글리
# 31179: 칙촉
# 31180: 그름
# 31181: 떨
# 31182: 하레
# 31183: 울트라
# 31184: 청경
# 31185: 무제
# 31186: 커민
# 31187: 빵샘
# 31188: 역삼세무서
# 31189: 공학
# 31190: 북마크
# 31191: 장죽
# 31192: 앞서서
# 31193: 아비규환
# 31194: 아닛맛
# 31195: 루치아노
# 31196: 엠앤엠
# 31197: 노보
# 31198: 구인
# 31199: 샤포
# 31200: 보록
# 31201: 검암
# 31202: 터음
# 31203: 그랬댄닼
# 31204: 면관
# 31205: 쉑갈바맹
# 31206: 뀌듯
# 31207: 뺑끼
# 31208: 부소산성
# 31209: 폼폼
# 31210: 본위
# 31211: 석조
# 31212: 비충
# 31213: 전학생
# 31214: 배방읍
# 31215: 기우
# 31216: 옆답
# 31217: 짭짜름했어
# 31218: 노리개
# 31219: 히노
# 31220: 쥬빌레
# 31221: 눅눅쫀득
# 31222: 재공
# 31223: 국소
# 31224: 마무
# 31225: 누누이
# 31226: 호로병
# 31227: 사천진항
# 31228: 쇼좌빙
# 31229: 빙비잉
# 31230: 민첩성
# 31231: 기독
# 31232: 허튼
# 31233: 훈녀
# 31234: 주조
# 31235: 흥국
# 31236: 파우스트
# 31237: 부카케
# 31238: 세랑
# 31239: 육체
# 31240: 후레
# 31241: 권혁수
# 31242: 먀
# 31243: 찬부
# 31244: 완결
# 31245: 해머
# 31246: 드뢉
# 31247: 꽁냥꽁
# 31248: 안검
# 31249: 죄짐
# 31250: 방뭉
# 31251: 카렌
# 31252: 샬롯
# 31253: 일광해수욕장
# 31254: 층고
# 31255: 파릇
# 31256: 돛
# 31257: 까슬거림
# 31258: 케파
# 31259: 해박
# 31260: 광역시
# 31261: 홍산면
# 31262: 술심
# 31263: 버스커
# 31264: 장범준
# 31265: 돌산대교
# 31266: 엎었던
# 31267: 뎋
# 31268: 자화자찬
# 31269: 탈영
# 31270: 금촌역
# 31271: 창렬급
# 31272: 꼽다
# 31273: 졋음
# 31274: 두우
# 31275: 달성군
# 31276: 문간
# 31277: 기념샷
# 31278: 도그
# 31279: 느므느므
# 31280: 클레멘타인
# 31281: 리메이크
# 31282: 미영
# 31283: 셀레
# 31284: 우잉
# 31285: 아이스링크
# 31286: 혼연
# 31287: 어눌려
# 31288: 눅진듯
# 31289: 터스랩
# 31290: 때임
# 31291: 싸윘는
# 31292: 스피아
# 31293: 나와욬
# 31294: 명심
# 31295: 구레나룻
# 31296: 망사
# 31297: 밥퍼
# 31298: 널렸네
# 31299: 망삘
# 31300: 구독
# 31301: 어찡
# 31302: 트로피카나
# 31303: 아흐
# 31304: 건만
# 31305: 넣어드심
# 31306: 대봉
# 31307: 도발
# 31308: 세번
# 31309: 섹
# 31310: 스크랩
# 31311: 근사
# 31312: 그맇
# 31313: 맇
# 31314: 쿵쿰한
# 31315: 무쯔
# 31316: 뒹구
# 31317: 하늘나라
# 31318: 취직
# 31319: 오우야
# 31320: 돞
# 31321: 느데
# 31322: 김성근
# 31323: 원더
# 31324: 케엪씨
# 31325: 배터져쥬금
# 31326: 분란
# 31327: 까슬하다
# 31328: 철원
# 31329: 쨔샤이
# 31330: 수천
# 31331: 맛방
# 31332: 웃돈
# 31333: 체온계
# 31334: 이방
# 31335: 열뮈빔밥
# 31336: 꼬르소
# 31337: 유뷰트
# 31338: 싱
# 31339: 빈터
# 31340: 왕희
# 31341: 유라
# 31342: 교문
# 31343: 짱하다
# 31344: 하얬
# 31345: 숨기
# 31346: 대중매체
# 31347: 해댐
# 31348: 쫑
# 31349: 표명
# 31350: 프란체스카
# 31351: 재택
# 31352: 동승
# 31353: 시온
# 31354: 애니멀
# 31355: 황비홍
# 31356: 누더기
# 31357: 몸무게
# 31358: 평탄
# 31359: 멍청
# 31360: 쉽사리
# 31361: 그닼
# 31362: 다리미
# 31363: 감개
# 31364: 무량
# 31365: 중초
# 31366: 절찬
# 31367: 파베
# 31368: 석사동
# 31369: 불보
# 31370: 구제역
# 31371: 이해랑
# 31372: 관객
# 31373: 기문
# 31374: 황인용
# 31375: 운임
# 31376: 오몽
# 31377: 화재경보기
# 31378: 체념하다
# 31379: 쌀국
# 31380: 수르
# 31381: 오본
# 31382: 복제
# 31383: 가료
# 31384: 분파
# 31385: 삼십이
# 31386: 밸브
# 31387: 거슬러주
# 31388: 살길
# 31389: 마싰고
# 31390: 소재지
# 31391: 스뎅
# 31392: 바켓
# 31393: 싳다
# 31394: 촉신
# 31395: 몸짱
# 31396: 마담밍
# 31397: 슉
# 31398: 지릉
# 31399: 죤
# 31400: 티엔
# 31401: 크렘븰레
# 31402: 접견
# 31403: 목감
# 31404: 긔
# 31405: 혜성
# 31406: 복지관
# 31407: 복지사
# 31408: 정황
# 31409: 해오
# 31410: 카포
# 31411: 쿠리다
# 31412: 미끄덩거렸다
# 31413: 따따블
# 31414: 인내력
# 31415: 무학여고
# 31416: 들숨
# 31417: 빌딤
# 31418: 장다이펑
# 31419: 빛임
# 31420: 스타숍
# 31421: 유멍세
# 31422: 출세
# 31423: 호리
# 31424: 휘둥그레지다
# 31425: 참가자
# 31426: 밥돌
# 31427: 띠워
# 31428: 타보이
# 31429: 대추야자
# 31430: 배꼼
# 31431: 봉미선
# 31432: 민스
# 31433: 기정
# 31434: 좋으몀
# 31435: 아낙
# 31436: 깃털
# 31437: 롱보
# 31438: 팝오버
# 31439: 롸콰두들
# 31440: 페미니즘
# 31441: 미츠
# 31442: 온당
# 31443: 표피
# 31444: 거슬러주던
# 31445: 공주시
# 31446: 갈매역
# 31447: 능력자
# 31448: 해피밀
# 31449: 도모
# 31450: 디아볼로
# 31451: 복개천
# 31452: 케케묵
# 31453: 뒷날
# 31454: 극소하다
# 31455: 빨봉
# 31456: 메달
# 31457: 봄맞이
# 31458: 동탯국
# 31459: 숮풀
# 31460: 좋을듷
# 31461: 매콤탕몀
# 31462: 유증
# 31463: 뭉그적뭉그적
# 31464: 샅샅이
# 31465: 원덕역
# 31466: 왓썹맨보
# 31467: 왓썹맨
# 31468: 읊으시길
# 31469: 이육사
# 31470: 판콘
# 31471: 한반도
# 31472: 몽테
# 31473: 쁠
# 31474: 놃
# 31475: 요정
# 31476: 듬뿍듬뿍하다
# 31477: 울화
# 31478: 고봉례
# 31479: 르뮤
# 31480: 박람회
# 31481: 이만원
# 31482: 마렘마
# 31483: 댤곳
# 31484: 차오면
# 31485: 순위도
# 31486: 바닥상태
# 31487: 장심
# 31488: 완소
# 31489: 무즙
# 31490: 똒
# 31491: 서화
# 31492: 수사
# 31493: 빠삭한대
# 31494: 흥이나다
# 31495: 펍스럽
# 31496: 순다
# 31497: 증빙
# 31498: 동대문시장
# 31499: 경상북도
# 31500: 닭류
# 31501: 노빠꾸
# 31502: 깜장
# 31503: 겉바속쫀
# 31504: 성행
# 31505: 재희
# 31506: 이영지
# 31507: 하묘
# 31508: 복싱
# 31509: 좍좍
# 31510: 로컬릿
# 31511: 나프탈렌
# 31512: 차쇼
# 31513: 청진동
# 31514: 캘리그래피
# 31515: 송추계곡
# 31516: 항복
# 31517: 양철
# 31518: 꼬소꼬소
# 31519: 럼버
# 31520: 개심
# 31521: 도습
# 31522: 대덕
# 31523: 버물려
# 31524: 판잣집
# 31525: 비츄
# 31526: 은비
# 31527: 버파
# 31528: 리빙관
# 31529: 날라리
# 31530: 인권위
# 31531: 일초
# 31532: 분등
# 31533: 특무회
# 31534: 솨
# 31535: 솨라펀
# 31536: 수첩
# 31537: 트릴
# 31538: 압승입니
# 31539: 와삭
# 31540: 대타
# 31541: 찌끄레기
# 31542: 한길
# 31543: 파친코
# 31544: 잭팟
# 31545: 유몋
# 31546: 황홀
# 31547: 선구자
# 31548: 굴포
# 31549: 심신
# 31550: 찷
# 31551: 여객
# 31552: 핏대
# 31553: 마인
# 31554: 미란다
# 31555: 청옥산
# 31556: 회유
# 31557: 룸없다
# 31558: 떽떽대
# 31559: 준비운동
# 31560: 상급자
# 31561: 관찬
# 31562: 무채색
# 31563: 르쎄
# 31564: 원론
# 31565: 라멘토
# 31566: 엎었
# 31567: 노회찬
# 31568: 의원님
# 31569: 걸맛
# 31570: 퍼팅
# 31571: 무등
# 31572: 대형화
# 31573: 치켜세우다
# 31574: 방개
# 31575: 신중하
# 31576: 어근
# 31577: 시부
# 31578: 공립
# 31579: 뿌핏퐁커리
# 31580: 기증
# 31581: 역주행
# 31582: 계석
# 31583: 똠냥꿍
# 31584: 상주시
# 31585: 청파
# 31586: 꾸르맛임
# 31587: 맛메무엉
# 31588: 따사롭다
# 31589: 몽촌토성역
# 31590: 포호
# 31591: 스깠는
# 31592: 선분
# 31593: 아라가
# 31594: 집게벌레
# 31595: 구차하다
# 31596: 헤르
# 31597: 군소
# 31598: 크페
# 31599: 루돌프
# 31600: 뻬버렸
# 31601: 무주리조트
# 31602: 스탠스
# 31603: 바스타
# 31604: 참가
# 31605: 자미
# 31606: 한평생
# 31607: 면밀하다
# 31608: 스웩임
# 31609: 목살임
# 31610: 군단
# 31611: 나이키
# 31612: 삭해
# 31613: 배립니
# 31614: 결명자차
# 31615: 여점특
# 31616: 선남선녀
# 31617: 안산역
# 31618: 정해준
# 31619: 만덕
# 31620: 노외
# 31621: 보름달
# 31622: 호텔뷔풰
# 31623: 본정신
# 31624: 리거
# 31625: 왕모래
# 31626: 대애
# 31627: 애박
# 31628: 끅
# 31629: 유마
# 31630: 새터민
# 31631: 떡빔
# 31632: 안비
# 31633: 과민반응
# 31634: 우윀
# 31635: 파리스
# 31636: 뷔베
# 31637: 폭스바겐
# 31638: 드업
# 31639: 귀엣말
# 31640: 어원
# 31641: 신용문객잔
# 31642: 나빳으
# 31643: 풋팟퐁커리
# 31644: 평버엄
# 31645: 싰으
# 31646: 알박기
# 31647: 영해
# 31648: 마이쮸
# 31649: 돈띁
# 31650: 낙영
# 31651: 포향
# 31652: 전경련
# 31653: 중요도
# 31654: 철조망
# 31655: 벼텨주길
# 31656: 성시경
# 31657: 사마요
# 31658: 루이비통
# 31659: 가이드북
# 31660: 흐릿해
# 31661: 중주
# 31662: 르프리크
# 31663: 슬론
# 31664: 땠습니
# 31665: 고갯길
# 31666: 서낙동강
# 31667: 레바논
# 31668: 슈스
# 31669: 트링
# 31670: 구이일
# 31671: 와카
# 31672: 드셔보셩
# 31673: 조리퐁
# 31674: 스페
# 31675: 조세호
# 31676: 비지땀
# 31677: 염치
# 31678: 생식기
# 31679: 이입
# 31680: 공예
# 31681: 얄쨜없
# 31682: 얄궂
# 31683: 기뢰
# 31684: 랜떡랜떡
# 31685: 선입선출
# 31686: 마라탕샹궈
# 31687: 낙점
# 31688: 출격
# 31689: 숭덩
# 31690: 음함
# 31691: 설일
# 31692: 일개
# 31693: 펍이기
# 31694: 핵맛업
# 31695: 파들거리다
# 31696: 봄꽃
# 31697: 닥스훈트
# 31698: 램숄더라구
# 31699: 불쾔했응
# 31700: 내후년
# 31701: 콜라주
# 31702: 구하라
# 31703: 걧수
# 31704: 격동
# 31705: 테헤란로
# 31706: 깨꿋
# 31707: 전전날
# 31708: 지산
# 31709: 지소
# 31710: 선수촌
# 31711: 도봉산역
# 31712: 눌레휘
# 31713: 수일
# 31714: 계도
# 31715: 끙끙대다
# 31716: 인기상
# 31717: 와인숍
# 31718: 낫기
# 31719: 익일
# 31720: 탈주
# 31721: 뿜는
# 31722: 칼보
# 31723: 완전뱔
# 31724: 리비아
# 31725: 플래트
# 31726: 푸님팟퐁커리
# 31727: 병산
# 31728: 토방
# 31729: 베지밀
# 31730: 밥겸
# 31731: 햇물
# 31732: 멸종
# 31733: 창령
# 31734: 찜류
# 31735: 쎈느
# 31736: 중계역
# 31737: 변사
# 31738: 무뼈생
# 31739: 매리어트
# 31740: 지질
# 31741: 동측
# 31742: 의령
# 31743: 캍
# 31744: 렌치소스
# 31745: 치병
# 31746: 촌년
# 31747: 퍼먹던
# 31748: 열의
# 31749: 선량하다
# 31750: 테감
# 31751: 맹고
# 31752: 음반
# 31753: 한울
# 31754: 빠꾸먹으
# 31755: 뚠
# 31756: 생듬심
# 31757: 쉣이겠
# 31758: 그라니타
# 31759: 썩힌
# 31760: 퍼둬
# 31761: 괘찮아
# 31762: 노즐
# 31763: 삽곱
# 31764: 윤추
# 31765: 멀쩡
# 31766: 광내
# 31767: 부단하다
# 31768: 되읶어
# 31769: 일이십
# 31770: 경청
# 31771: 꼬까
# 31772: 진스
# 31773: 바텐들
# 31774: 양송
# 31775: 화표
# 31776: 유점
# 31777: 물손
# 31778: 종웝원들
# 31779: 꼰
# 31780: 미춋어
# 31781: 너츠
# 31782: 후학
# 31783: 휴롬
# 31784: 축령산
# 31785: 뻬스카토레
# 31786: 서칭해
# 31787: 배꽃
# 31788: 데빌
# 31789: 효고
# 31790: 하임
# 31791: 시켯움
# 31792: 법정공휴일
# 31793: 소비자원
# 31794: 레더
# 31795: 큐티
# 31796: 슈샤
# 31797: 정애
# 31798: 분팃느엉천원
# 31799: 거게
# 31800: 심감
# 31801: 찜직
# 31802: 십오만
# 31803: 십이만
# 31804: 원흥
# 31805: 스스키노
# 31806: 다루마
# 31807: 빛바
# 31808: 발레이
# 31809: 고스트
# 31810: 비씬편
# 31811: 주사위
# 31812: 아이코닉
# 31813: 집어치우다
# 31814: 월용
# 31815: 조선왕릉
# 31816: 현직
# 31817: 경찰관
# 31818: 급작
# 31819: 키오
# 31820: 좋아핮
# 31821: 동물원
# 31822: 양구
# 31823: 빠득빠득
# 31824: 적조
# 31825: 구합
# 31826: 삼바
# 31827: 대폭소
# 31828: 뿌링클핫
# 31829: 턱밑
# 31830: 죽귾인것같
# 31831: 맹숭
# 31832: 워낭소리
# 31833: 박달
# 31834: 득수
# 31835: 겄음
# 31836: 크리에이터
# 31837: 학보
# 31838: 오해해
# 31839: 측은하다
# 31840: 볼멘소리
# 31841: 혼구
# 31842: 녕
# 31843: 웠더헬
# 31844: 여름방학
# 31845: 보슬거림
# 31846: 토핑이었
# 31847: 호날두
# 31848: 조던
# 31849: 망인
# 31850: 어버린
# 31851: 일상생활
# 31852: 레지나
# 31853: 여생
# 31854: 논의
# 31855: 볼린
# 31856: 종주국
# 31857: 브뤼셀
# 31858: 릭스
# 31859: 베이킹파우더
# 31860: 실망습럽내
# 31861: 덧살
# 31862: 금지명령
# 31863: 폭포수
# 31864: 홍현희
# 31865: 배꼽인사
# 31866: 밀란
# 31867: 학점
# 31868: 기풍
# 31869: 김나영
# 31870: 절었
# 31871: 봉수
# 31872: 쌨어
# 31873: 뮘미
# 31874: 노매드
# 31875: 흙내
# 31876: 연간
# 31877: 잡쪼롬
# 31878: 맹밥
# 31879: 스텔
# 31880: 신동진
# 31881: 눈뎅
# 31882: 개찌덕거림
# 31883: 콘플레이크
# 31884: 투툼
# 31885: 쇼쿠
# 31886: 압승이었
# 31887: 레이더망
# 31888: 강시
# 31889: 가츠몽
# 31890: 승자
# 31891: 잠수
# 31892: 쟁여두
# 31893: 재호
# 31894: 병갑
# 31895: 길죽
# 31896: 녹용
# 31897: 깜빠뉴샤
# 31898: 꼽을
# 31899: 원함
# 31900: 윤상
# 31901: 개나리색
# 31902: 그른가
# 31903: 매운줗
# 31904: 육장
# 31905: 물렿
# 31906: 물엏나봐
# 31907: 악한
# 31908: 나베류
# 31909: 개봉역
# 31910: 뉸데
# 31911: 상쇄시킬만
# 31912: 황충
# 31913: 초유
# 31914: 번드르르하다
# 31915: 우스터소스
# 31916: 호랭이
# 31917: 삼립식품
# 31918: 인갑
# 31919: 원광대
# 31920: 질깃해
# 31921: 왅전
# 31922: 은짬
# 31923: 뱀파이어
# 31924: 안전모
# 31925: 국채
# 31926: 보카
# 31927: 김태완
# 31928: 흑색
# 31929: 통침
# 31930: 텅스텐
# 31931: 두툼한
# 31932: 발뮤
# 31933: 웅성거리다
# 31934: 흐물대
# 31935: 나소
# 31936: 시에나
# 31937: 딘주놀러왓다
# 31938: 무협지
# 31939: 개쩌증나
# 31940: 립스
# 31941: 탕종
# 31942: 기립박수
# 31943: 화쿵부
# 31944: 걸인
# 31945: 택별
# 31946: 르왈왈
# 31947: 퐁실퐁실
# 31948: 도쿄역
# 31949: 컵반
# 31950: 실사판
# 31951: 존맛팅이에오
# 31952: 샷다문
# 31953: 할아범
# 31954: 헹궈냈네
# 31955: 꿍짝꿍짝
# 31956: 유니버설
# 31957: 고관
# 31958: 과점
# 31959: 자백
# 31960: 부마
# 31961: 맛진
# 31962: 어렴풋하다
# 31963: 장수식
# 31964: 블렌딩해
# 31965: 메막
# 31966: 허름할
# 31967: 추나
# 31968: 궈바로우
# 31969: 마드리드
# 31970: 가불
# 31971: 김맛
# 31972: 깓두기
# 31973: 직하
# 31974: 예담
# 31975: 조포
# 31976: 타게팅
# 31977: 레스쟈우르스
# 31978: 그르
# 31979: 황반
# 31980: 아닌둣
# 31981: 광팬
# 31982: 호재
# 31983: 유대
# 31984: 초급
# 31985: 데트
# 31986: 픔절일
# 31987: 목공소
# 31988: 보톡스
# 31989: 목수
# 31990: 푼돈
# 31991: 냉각기
# 31992: 관광업
# 31993: 도음
# 31994: 일급
# 31995: 또갈랭
# 31996: 무당
# 31997: 었다
# 31998: 특박상
# 31999: 후텁지근
# 32000: 티쉬
# 32001: 비냉물냉
# 32002: 차림표
# 32003: 통일로
# 32004: 밤밥
# 32005: 이상두
# 32006: 사워크라우트
# 32007: 허름함이
# 32008: 괠
# 32009: 뒤발
# 32010: 위스
# 32011: 객기
# 32012: 헤냉면
# 32013: 내연
# 32014: 미국바퀴
# 32015: 김녕
# 32016: 제등
# 32017: 함냉
# 32018: 몆
# 32019: 끝눈
# 32020: 수크레
# 32021: 가르침
# 32022: 암컷
# 32023: 생이별
# 32024: 계간지
# 32025: 새벽같이
# 32026: 교황
# 32027: 쫀딕하
# 32028: 소다라
# 32029: 튀어버
# 32030: 어른스럽다
# 32031: 초능력
# 32032: 무의식
# 32033: 뚭겁
# 32034: 수인선
# 32035: 연수역
# 32036: 인총
# 32037: 해독
# 32038: 유탕
# 32039: 몸빵
# 32040: 꼼작
# 32041: 쁘띠프랑스
# 32042: 우니미쁘동
# 32043: 궈줘
# 32044: 번뜩이다
# 32045: 들레다
# 32046: 찌르레기
# 32047: 불확실하다
# 32048: 우장산
# 32049: 백혈병
# 32050: 등말
# 32051: 감물
# 32052: 백골
# 32053: 멸추
# 32054: 북청
# 32055: 물렁거립니
# 32056: 상당산성
# 32057: 트립어드바이저
# 32058: 떨어트렸다
# 32059: 쨍쨍거리다
# 32060: 미납
# 32061: 백구
# 32062: 중말
# 32063: 아닐듓
# 32064: 섭식
# 32065: 송중기
# 32066: 면치
# 32067: 생태계
# 32068: 종임
# 32069: 거보
# 32070: 고비
# 32216: 알반
# 32217: 나침
# 32218: 마스카니
# 32219: 새콤꼬릿
# 32220: 룸메이트
# 32221: 봏
# 32222: 쫀득쫑득해
# 32223: 시외
# 32224: 뺸
# 32225: 노정
# 32226: 옥토버
# 32227: 에궁
# 32228: 뿌님팟퐁
# 32229: 로그아웃
# 32230: 비스름한걸
# 32231: 뮐보
# 32232: 어럽
# 32233: 팔방미인
# 32234: 맺혔습니
# 32235: 띄우기
# 32236: 교배종
# 32237: 탕로
# 32238: 뻔뼌하
# 32239: 마시시
# 32240: 엉
# 32241: 스타인
# 32242: 모수
# 32243: 레노
# 32244: 레빗
# 32245: 꾸러미
# 32246: 파티세리
# 32247: 창렬창렬개창렬
# 32248: 존맛로투스
# 32249: 등목
# 32250: 부뤼별
# 32251: 무릉도원
# 32252: 먹장어
# 32253: 무형문화재
# 32254: 제호
# 32255: 덧술
# 32256: 명주
# 32257: 원서동
# 32258: 다큐프라임
# 32259: 왜국
# 32260: 시코쿠
# 32261: 사국
# 32262: 고치현
# 32263: 노지현
# 32264: 사카모토
# 32265: 료마
# 32266: 선릉로
# 32267: 컴플렘
# 32268: 강서동
# 32269: 복대동
# 32270: 대전광역시
# 32271: 년산
# 32272: 박주
# 32273: 페로
# 32274: 비론
# 32275: 진성면
# 32276: 디맥
# 32277: 좋읗
# 32278: 일자리
# 32279: 상쇄될
# 32280: 굉징히어둡
# 32281: 헤져
# 32282: 늑장
# 32283: 옹고집
# 32284: 한인타운
# 32285: 버켓통
# 32286: 슴슴했던
# 32287: 꼽줘
# 32288: 개봉동
# 32289: 괘석
# 32290: 어절
# 32291: 증미역
# 32292: 투박
# 32293: 교차점
# 32294: 뜨걱지두않
# 32295: 경포
# 32296: 이필
# 32297: 접지
# 32298: 비버
# 32299: 산유
# 32300: 부인과
# 32301: 탐광
# 32302: 첵스
# 32303: 냉뽕
# 32304: 타구
# 32305: 남도현
# 32306: 대운
# 32307: 잔무
# 32308: 아누
# 32309: 성수진
# 32310: 낚시꾼
# 32311: 약체
# 32312: 밋볼
# 32313: 얍삽
# 32314: 병따개
# 32315: 벨로나
# 32316: 기체
# 32317: 멊나
# 32318: 각박
# 32319: 공표
# 32320: 음재
# 32321: 엔쵸피뇨
# 32322: 환급
# 32323: 물막
# 32324: 조오
# 32325: 워줌
# 32326: 금송아지
# 32327: 프릳츠에일
# 32328: 경해
# 32329: 택음료택
# 32330: 폰카
# 32331: 무텃
# 32332: 라티
# 32333: 카오팟쌉파릇
# 32334: 삐까이텃
# 32335: 맛맀러
# 32336: 전원주택
# 32337: 캐잌
# 32338: 연양갱
# 32339: 태전
# 32340: 걍쥬금
# 32341: 증편
# 32342: 나아졋길

# %%
class psng_predict_all_v3:
    def __init__(self, lst):
        self.lst = lst
        path = ''
        # 저장된 tokenizer 객체 로드
        with open(f'{path}tokenizer.pickle', 'rb') as f:
            self.tokenizer = pickle.load(f)
        self.max_len = 250

    def preprocessing(self):
        okt = Okt()
        R_lst = self.lst
        R_frm = pd.DataFrame(R_lst , columns = ['REVIEW'])
        R_frm['REVIEW'] = R_frm['REVIEW'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", regex=True)
        R_frm['REVIEW'].replace('', np.nan, inplace=True)
        R_frm['REVIEW'] = R_frm['REVIEW'].astype(str)
        stopwords = ['도', '는', '다', '의', '가', '이', '은',
                     '한', '에', '하', '고', '을', '를', '인', '듯',
                     '과', '와', '네', '들', '듯', '지', '임', '게',
                     '는', '이', '했', '슴', '음', '것', '거', '로',
                     '들', '거', '곳', '분', '원', '더', '왜', '해',
                     '수', '할', '그', '함', '돈', '번', '두', '개',
                     '건', '내', '저', '만', '갈', '걸', '제', '명',
                     '분',
                     '인데', '이가', '했었', '해서',
                     '습니다', '했는데', '입니다']

        okt = Okt()
        # R_frm['tokenized'] = R_frm['리뷰'].apply(okt.pos)
        R_frm['tokenized'] = R_frm['REVIEW'].apply(lambda x: okt.pos(x, norm=True, stem=True))
        R_frm['tokenized'] = R_frm['tokenized'].apply(
            lambda x: [word for word, shape in x if shape in ['Verb', 'Adjective', 'Noun', 'VerbPrefix'] if word not in stopwords])
        R_pred = R_frm['tokenized'].values
        return R_pred

    def model_test(self):
        tokenizer = self.tokenizer
        X_test = tokenizer.texts_to_sequences(self.X_test)
        y_test = self.y_test
        X_test = pad_sequences(X_test, maxlen=self.max_len)
        print("\n 테스트 정확도: %.4f" % (self.loaded_model.evaluate(X_test, y_test)[1]))

    def word_index(self):
        tokenizer = self.tokenizer
        print(tokenizer.word_index)

    def predict(self):
        R_pred = self.preprocessing()
        max_len = self.max_len
        tokenizer = self.tokenizer
        result = []
        pred = tokenizer.texts_to_sequences(R_pred)
        pred = pad_sequences(pred, maxlen=max_len)
        score = self.loaded_model.predict(pred)
        return score

    def prediction(self):
        result = []
        score = self.predict()
        for num in range(len(score)):
            if score[num][0] > 0.9:
                result.append('0')
            elif score[num][0] < 0.1:
                result.append('1')
            else:
                result.append('2')
        return result

# %%
t1 = psng_predict_all_v3(['여기 햄버거 정말 맛있어요' , '서비스가 개판입니다. 정말 끔찍했어요'])

# %%
t1.prediction()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '리뷰'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 t1.prediction()
#
# Cell In[12], line 59, in psng_predict_all_v3.prediction(self)
#      57 def prediction(self):
#      58     result = []
# ---> 59     score = self.predict()
#      60     for num in range(len(score)):
#      61         if score[num][0] > 0.9:
#
# Cell In[12], line 48, in psng_predict_all_v3.predict(self)
#      47 def predict(self):
# ---> 48     R_pred = self.preprocessing()
#      49     max_len = self.max_len
#      50     tokenizer = self.tokenizer
#
# Cell In[12], line 30, in psng_predict_all_v3.preprocessing(self)
#      28 okt = Okt()
#      29 # R_frm['tokenized'] = R_frm['리뷰'].apply(okt.pos)
# ---> 30 R_frm['tokenized'] = R_frm['리뷰'].apply(lambda x: okt.pos(x, norm=True, stem=True))
#      31 R_frm['tokenized'] = R_frm['tokenized'].apply(
#      32     lambda x: [word for word, shape in x if shape in ['Verb', 'Adjective', 'Noun', 'VerbPrefix'] if word not in stopwords])
#      33 R_pred = R_frm['tokenized'].values
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: '리뷰'
