# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt
import json

# %matplotlib inline

# 한글 폰트 문제 해결
import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')


# 노란색 글씨의 warining 문구 강제 생략
import warnings
warnings.filterwarnings(action='ignore')
    

# 차트 축 <- 음수 부호 지원
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False


print('numpy version - ' , np.__version__)
print('pandas version - ' , pd.__version__)

# 크롤링
from bs4 import BeautifulSoup
from urllib.request import urlopen , urlretrieve
from urllib.error   import HTTPError
from urllib.error   import URLError

import requests
import re
# Out:
# numpy version -  1.23.5
# pandas version -  1.5.3

# %% [markdown]
# #### 학습목표
# - 스크래핑   : 웹 사이트 상에서 위치를 지정하여 원하는 데이터를 추출하는 방법 (정적파일)
# - 크롤링     : 자동화 봇을 이용하여 링크를 따라서연결된 페이지를 가져와 원하는 데이터를 추출 (동적파일)
#
# - 라이브러리 : BeautifulSoup & Selenium

# %%
# 1 요청하기
url = 'https://www.daangn.com/hot_articles'
response = requests.get(url)

# 요청(request - response 확인)

print('status - ' , response)
print()

# 출력은 문자열이며, 이 문자열을 구분하기위해 BS(BeautlfulSoup ) 라이브러리가 필요하다.
print('text   - ' , response.text)
# Out:
# status -  <Response [200]>
#
# text   -  <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">
#
#
#
# <title>당근마켓 중고거래 | 당신 근처의 당근마켓</title>
# <meta name="description" content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." />
# <link rel="author" href="당근마켓" />
# <meta property="og:url" content="https://www.daangn.com/hot_articles" />
# <meta property="og:title" content="당근마켓 중고거래 | 당신 근처의 당근마켓" />
# <meta property="og:description" content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." />
# <meta property="og:site_name" content="당근마켓" />
# <meta property="og:image" content="https://www.daangn.com/images/meta/home/flea_market.png" />
# <meta property="og:type" content="article" />
# <meta property="og:locale" content="ko_KR" />
# <meta property="fb:app_id" content="1463621440622064" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:site" content="@danggeunmarket" />
# <meta name="twitter:title" content="당근마켓 중고거래 | 당신 근처의 당근마켓" />
# <meta name="twitter:description" content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." />
# <meta name="twitter:image" content="https://www.daangn.com/images/meta/home/flea_market.png" />
# <meta name="naver-site-verification" content="d1f8112731c18313535732cf2516d6401bfed40a" />
# <meta name="csrf-param" content="authenticity_token" />
# <meta name="csrf-token" content="IPPBwu1bMcR0zEczPWwDjwRSFrPGi2btPH-x3PDE_1OhAcjbq9NBwXn9XTgjK0JD2L-b1d70bNRV2m9aK-OyzA" />
#
# <link rel="shortcut icon" type="image/x-icon" href="https://d1unjqcospf8gs.cloudfront.net/favicon.ico" />
#   <link rel="apple-touch-icon" sizes="192x192" href="/images/icons/daangn_logo_192.png">
#   <link rel="apple-touch-icon-precomposed" href="/images/icons/daangn_logo_192.png">
#   <link rel="icon" sizes="192x192" href="/images/icons/daangn_logo_android_192.png">
#
#
#         <link rel="canonical" href="https://www.daangn.com/hot_articles" />
#
#
#
#     <link rel="stylesheet" media="all" href="https://d1unjqcospf8gs.cloudfront.net/assets/home/articles/hot-05663f2aed8868551a676d610d7322afa2255ed6964e18672346c35fe876bcc4.css" />
#       <script src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base-4b55f04bb2798d1f6aa4e078c0ad3504ef4993ad4123005ec35dde545e5788bd.js"></script>
#
#     <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
#     <!--[if lt IE 9]>
#     <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#     <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
#     <script>
#       window.fbAsyncInit = function() {
#         FB.init({
#           appId      : '1463621440622064',
#           xfbml      : true,
#           version    : 'v2.4'
#         });
#       };
#
#       (function(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#       }(document, 'script', 'facebook-jssdk'));
#     </script>
#
#     <!-- Facebook Pixel Code -->
#     <script>
#       !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#         n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#         document,'script','//connect.facebook.net/en_US/fbevents.js');
#
#       fbq('init', '992961397411651');
#       facebookClickEvent("PageView")
#
#       function facebookClickEvent(eventName, data) {
#         if (data !== undefined) {
#           fbq('track', eventName, data)
#         } else {
#           fbq('track', eventName)
#         }
#       }
#
#       function facebookClickEventWithPageMove(eventName, data, targetUrl) {
#         facebookClickEvent(eventName, data);
#         window.location.href = targetUrl;
#       }
#     </script>
#     <!-- End Facebook Pixel Code -->
#     <!-- Google Tag Manager -->
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-PJSK4QL');</script>
#     <!-- End Google Tag Manager -->
#
#     <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#               (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-64551386-2', 'auto');
#      ga('send', 'pageview'); </script>
#   <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "name": "당근마켓",
#   "url": "https://www.daangn.com",
#   "sameAs": [
#     "https://www.facebook.com/daangn",
#     "https://blog.naver.com/daangn",
#     "https://www.youtube.com/channel/UC8tsBsQBuF7QybxgLmStihA",
#     "https://twitter.com/daangnmarket",
#     "https://www.instagram.com/daangnmarket",
#     "https://apps.apple.com/kr/app/id1018769995",
#     "https://play.google.com/store/apps/details?id=com.towneers.www"
#   ],
#   "logo": "https://www.daangn.com/logo.png"
# }
# </script>
#
# </head>
# <body class="hoian-kr">
#   <noscript><img height="1" width="1" style="display:none"
#                  alt="facebook" src="https://www.facebook.com/tr?id=992961397411651&ev=PageView&noscript=1" /></noscript>
#
#
#
# <!-- Appsflyer Smart Banner -->
# <script>
#     !function(t,e,n,s,a,c,i,o,p){t.AppsFlyerSdkObject=a,t.AF=t.AF||function(){(t.AF.q=t.AF.q||[]).push([Date.now()].concat(Array.prototype.slice.call(arguments)))},t.AF.id=t.AF.id||i,t.AF.plugins={},o=e.createElement(n),p=e.getElementsByTagName(n)[0],o.async=1,o.src="https://websdk.appsflyer.com?"+(c.length>0?"st="+c.split(",").sort().join(",")+"&":"")+(i.length>0?"af_id="+i:""),p.parentNode.insertBefore(o,p)}(window,document,"script",0,"AF","banners",{banners: {key: "629f6f7a-a2a6-49c0-8d27-ffa48df1cd0e"}})
#     AF('banners', 'showBanner')
# </script>
# <!-- End Appsflyer Smart Banner-->
#
# <div id="gnb-root"><div class="light-theme"><div class="_1knjz490"><div class="_1knjz491 _1s38h9c0"><a class="_1knjz492" href="https://www.daangn.com" aria-label="logo"><span class="_1knjz493"><svg width="100" height="28" viewBox="0 0 100 28" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M10.6241 5.1897C4.76013 5.1897 0 9.94831 0 15.8104C0 18.2759 0.845096 20.5345 2.24209 22.3276C2.34557 22.4655 2.4663 22.6035 2.56978 22.7414C2.74225 22.9311 2.89747 23.1207 3.08719 23.3104L3.10443 23.3276C5.13956 25.4828 7.70934 27.1207 10.6068 28C13.5043 27.1207 16.0741 25.4828 18.1092 23.3276L18.1264 23.3104C18.2989 23.1207 18.4714 22.9311 18.6439 22.7414C18.7646 22.6035 18.8681 22.4655 18.9715 22.3276C20.3685 20.5345 21.2136 18.2759 21.2136 15.8104C21.2309 9.93107 16.488 5.1897 10.6241 5.1897ZM10.6241 19.8621C8.38197 19.8621 6.57105 18.0518 6.57105 15.8104C6.57105 13.569 8.38197 11.7587 10.6241 11.7587C12.8662 11.7587 14.6771 13.569 14.6771 15.8104C14.6771 18.0518 12.8662 19.8621 10.6241 19.8621Z" fill="#FF7E36"></path><path d="M14.0743 4.96552C14.7814 4.81035 15.2988 4.18965 15.2988 3.44827C15.2988 2.58621 14.5917 1.87931 13.7293 1.87931C13.4879 1.87931 13.2637 1.93104 13.0567 2.03449C12.8325 0.879318 11.8322 0 10.6076 0C9.38312 0 8.3828 0.879318 8.1586 2.03449C7.95163 1.93104 7.72742 1.87931 7.48597 1.87931C6.62363 1.87931 5.9165 2.58621 5.9165 3.44827C5.9165 4.18965 6.45116 4.81035 7.14103 4.96552C8.22758 4.58621 9.38312 4.37931 10.5904 4.37931C11.7977 4.37931 12.9877 4.58621 14.0743 4.96552Z" fill="#00B493"></path><path d="M28.8191 15.9481H35.3211C36.1317 15.9481 36.7699 15.4654 36.7699 14.4654C36.7699 13.4654 36.1317 12.9826 35.3211 12.9826H29.6642C29.371 12.9826 29.1985 12.8102 29.1985 12.5344V9.98264C29.1985 9.70678 29.371 9.53437 29.6642 9.53437H35.3211C36.1317 9.53437 36.7699 9.0516 36.7699 8.0516C36.7699 7.0516 36.1317 6.56885 35.3211 6.56885H28.8191C26.6115 6.56885 25.5767 7.5516 25.5767 9.39643V13.1378C25.5767 14.9826 26.6115 15.9481 28.8191 15.9481Z" fill="#FF7E36"></path><path d="M36.9594 17.1379H30.5608C27.6806 17.1379 25.7834 18.7241 25.7834 21.0517C25.7834 23.3276 27.6806 24.9138 30.5608 24.9138H36.9594C39.8396 24.9138 41.754 23.3276 41.754 21.0517C41.754 18.7414 39.8396 17.1379 36.9594 17.1379ZM36.9594 21.9138H30.5608C29.8537 21.9138 29.4743 21.5345 29.4743 21.0517C29.4743 20.5345 29.8537 20.1379 30.5608 20.1379H36.9594C37.6665 20.1379 38.0632 20.5345 38.0632 21.0517C38.0632 21.5345 37.6493 21.9138 36.9594 21.9138Z" fill="#FF7E36"></path><path d="M42.3754 9.60339H41.3578V7.65512C41.3578 6.81029 40.6162 6.17236 39.5469 6.17236C38.4776 6.17236 37.7188 6.81029 37.7188 7.65512V15.2068C37.7188 16.0517 38.4776 16.6896 39.5469 16.6896C40.6162 16.6896 41.3578 16.0517 41.3578 15.2068V13.1551H42.3754C43.2032 13.1551 43.8586 12.431 43.8586 11.3965C43.8586 10.3965 43.2032 9.60339 42.3754 9.60339Z" fill="#FF7E36"></path><path d="M60.5189 17.6206H45.6693C44.807 17.6206 44.0999 17.0516 44.0999 15.9999C44.0999 15.0171 44.807 14.4137 45.6693 14.4137H60.5189C61.3812 14.4137 62.0883 15.0344 62.0883 15.9999C62.0883 17.0344 61.3812 17.6206 60.5189 17.6206ZM57.4662 12.3964V10.4654C57.4662 10.1206 57.2764 9.93092 56.9833 9.93092H46.6869C45.79 9.93092 45.0312 9.36194 45.0312 8.27574C45.0312 7.24125 45.79 6.56885 46.6869 6.56885H57.7766C59.9842 6.56885 61.1052 7.70678 61.1052 9.72402V12.3964C61.1052 13.2413 60.3636 13.8792 59.2943 13.8792C58.225 13.8792 57.4662 13.2413 57.4662 12.3964ZM48.7565 19.7068V20.9826C48.7565 21.2413 48.9462 21.4137 49.2394 21.4137H59.829C60.7258 21.4137 61.4847 21.9999 61.4847 23.0688C61.4847 24.1033 60.7258 24.724 59.829 24.724H48.4633C46.273 24.724 45.1002 23.793 45.1002 21.8102V19.7068C45.1002 18.8619 45.8418 18.224 46.9111 18.224C47.9804 18.224 48.7565 18.8619 48.7565 19.7068Z" fill="#FF7E36"></path><path d="M63.9343 21.362V9.12063C63.9343 7.44822 64.7794 6.56891 66.5214 6.56891H71.2642C73.0062 6.56891 73.8513 7.43098 73.8513 9.12063V21.362C73.8513 23.0344 73.0062 23.9137 71.2642 23.9137H66.5214C64.7967 23.9 ...
#
# <section id="content">
#   <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>
#
#   <nav id="hot-articles-navigation">
#     <select name="region1" id="region1" onchange="changeRegion(&#39;r1&#39;, this.value)" class="hot-articles-nav-select"><option value="">지역을 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
#     <select name="region2" id="region2" disabled="disabled" onchange="changeRegion(&#39;r2&#39;, this.value)" class="hot-articles-nav-select"><option value="">동네를 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
#
#   </nav>
#
#   <section class="cards-wrap">
#       <article class="card-top ">
#   <a class="card-link " data-event-label="580560908" href="/articles/580560908">
#     <div class="card-photo ">
#         <img alt="아이폰13" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/ef5df919752dee22f02bb8b2b5cac04c467c1dbdd06fcd1f9e44d0062e27cf16_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">아이폰13</h2>
#       <div class="card-price ">
#         200,000원
#       </div>
#       <div class="card-region-name">
#         광주 광산구 신가동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 19
#           </span>
#         ∙
#         <span>
#             채팅 73
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581040255" href="/articles/581040255">
#     <div class="card-photo ">
#         <img alt="코카콜라 미니 냉장고 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/203710016bf5fb8b8075392a5aec17d78aea5b79170c9d46a96a879475bf7496.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">코카콜라 미니 냉장고 판매</h2>
#       <div class="card-price ">
#         10,000원
#       </div>
#       <div class="card-region-name">
#         충남 당진시 송악읍
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 32
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580762227" href="/articles/580762227">
#     <div class="card-photo ">
#         <img alt="전화주세요 01048506787" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/4158482b6b216ce0d6aa2ff38a686b77915efcca5872e9850b277750e6ec6de3.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">전화주세요 01048506787</h2>
#       <div class="card-price ">
#         1원
#       </div>
#       <div class="card-region-name">
#         전남 목포시 북항동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 46
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580875569" href="/articles/580875569">
#     <div class="card-photo ">
#         <img alt="농약분무기 가져가세요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/032f45d1bc21f5fced44de58113b2cdc7bde18e83a549e1cb210e18a7ebe6d75_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">농약분무기 가져가세요</h2>
#       <div class="card-price ">
#         30,000원
#       </div>
#       <div class="card-region-name">
#         경북 김천시 다수동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="578417402" href="/articles/578417402">
#     <div class="card-photo ">
#         <img alt="아이폰 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/347eb486adae9deb6d2335b21550fdce4a0bb3b636867371e3404c20cf3bc8d8.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">아이폰 팔아요</h2>
#       <div class="card-price ">
#         5,000원
#       </div>
#       <div class="card-region-name">
#         전북 군산시 경암동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 89
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580882649" href="/articles/580882649">
#     <div class="card-photo ">
#         <img alt="나이키 운동화 새제품" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/4a05154ac42318d114c979d23c8365433154d1639aaf61090e00efa7cdd2090d.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">나이키 운동화 새제품</h2>
#       <div class="card-price ">
#         40,000원
#       </div>
#       <div class="card-region-name">
#         경기도 부천시 상동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 41
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580866787" href="/articles/580866787">
#     <div class="card-photo ">
#         <img alt="크록스 260" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/aadd5eb4ed24f784bcabc9c2b6b84b9ea920bde981db9f1a5b2c5eafe87cd082_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">크록스 260</h2>
#       <div class="card-price ">
#         15,000원
#       </div>
#       <div class="card-region-name">
#         대구 달서구 월성동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 35
#           </span>
#         ∙
#         <span>
#             채팅 48
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580772115" href="/articles/580772115">
#     <div class="card-photo ">
#         <img alt="중고 컨테이너 3*6 판매 합니다 / 급처분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/12c6f83daa23664e589b57db21b3a36399e2229c1dc245be638d95d722b4edc9_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">중고 컨테이너 3*6 판매 합니다 / 급처분</h2>
#       <div class="card-price ">
#         900,000원
#       </div>
#       <div class="card-region-name">
#         대구 동구 신천동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 22
#           </span>
#         ∙
#         <span>
#             채팅 40
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="578159254" href="/articles/578159254">
#     <div class="card-photo ">
#         <img alt="세차기 세척기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/53b869b41265acbccec0b28e51150ca9b334c222ee29fefe306b3a286e97d08a.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">세차기 세척기</h2>
#       <div class="card-price ">
#         20,000원
#       </div>
#       <div class="card-region-name">
#         경남 창원시 의창구 북면
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 14
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581016803" href="/articles/581016803">
#     <div class="card-photo ">
#         <img alt="자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/5f0deffb2bd042d27c63d8ea880eae28d6f888b934de03f1458c737b94b1b790.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">자전거</h2>
#       <div class="card-price ">
#         30,000원
#       </div>
#       <div class="card-region-name">
#         인천 미추홀구 관교동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 25
#           </span>
#         ∙
#         <span>
#             채팅 32
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580907341" href="/articles/580907341">
#     <div class="card-photo ">
#         <img alt="삼성제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/d23d20a7e4e413d282ae4d4a95cd0046e8f0316ae47b10ff83100e56ff72e746_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">삼성제습기</h2>
#       <div class="card-price ">
#         30,000원
#       </div>
#       <div class="card-region-name">
#         인천 연수구 송도동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="579568759" href="/articles/579568759">
#     <div class="card-photo ">
#         <img alt="베베드피노 키즈 올오버 베들링턴 BP31PH315 세트 100 110 120 130" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/09f56634131c971bdd963852bddcf490ed3cb6e0d3e5ee9aca4e3abbc5197385.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">베베드피노 키즈 올오버 베들링턴 BP31PH315 세트 100 110 120 130</h2>
#       <div class="card-price ">
#         42,000원
#       </div>
#       <div class="card-region-name">
#         경기도 김포시 고촌읍
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 28
#           </span>
#         ∙
#         <span>
#             채팅 56
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581053384" href="/articles/581053384">
#     <div class="card-photo ">
#         <img alt="중고컨테이너 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/069d72217fac82cf6ec66d1dc25e3c80068626b640452539f242d0c71ae6ddfd_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">중고컨테이너 판매</h2>
#       <div class="card-price ">
#         150만원
#       </div>
#       <div class="card-region-name">
#         전남 영암군 삼호읍
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 7
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581059266" href="/articles/581059266">
#     <div class="card-photo ">
#         <img alt="커피믹스" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/896e09db56e9506d021a062a94678f48e96e32205cf89043668da89cae2f2846_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">커피믹스</h2>
#       <div class="card-price ">
#         9,000원
#       </div>
#       <div class="card-region-name">
#         울산 북구 중산동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581061200" href="/articles/581061200">
#     <div class="card-photo ">
#         <img alt="수납함 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/aa219e276f737965edc0027d84e4af7cedbb91ec9976e00a2b2b25660962c09a.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">수납함 팝니다</h2>
#       <div class="card-price ">
#         5,000원
#       </div>
#       <div class="card-region-name">
#         경북 포항시 북구 창포동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 5
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="578148642" href="/articles/578148642">
#     <div class="card-photo ">
#         <img alt="트레일러 팝니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/7460bbe5fa854a8684c7e3f4cc0feec0246632bf30a22afcb5c85de1af6fbdf4.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">트레일러 팝니다.</h2>
#       <div class="card-price ">
#         200,000원
#       </div>
#       <div class="card-region-name">
#         경기도 남양주시 별내동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580756769" href="/articles/580756769">
#     <div class="card-photo ">
#         <img alt="모니터 새거 팔어요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/066b666cf681dc9325360c19d8c09d51403947edaac9e6a6ff5405914641a75f.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">모니터 새거 팔어요</h2>
#       <div class="card-price ">
#         50,000원
#       </div>
#       <div class="card-region-name">
#         경기도 시흥시 정왕동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 4
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="578156718" href="/articles/578156718">
#     <div class="card-photo ">
#         <img alt="노비타 6리터 가성비 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/50cd582ad22784529deef1b60087888276f67cf7bb747c8aa2df7fabd31da099_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">노비타 6리터 가성비 제습기</h2>
#       <div class="card-price ">
#         30,000원
#       </div>
#       <div class="card-region-name">
#         경기도 양주시 고읍동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580605666" href="/articles/580605666">
#     <div class="card-photo ">
#         <img alt="갤럭시버즈 판매(버즈2 pro)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/0f8cda4db454e7eec3f8357e9393903ded10ed1ebd39ec6a1eb75771a0c28c0e_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">갤럭시버즈 판매(버즈2 pro)</h2>
#       <div class="card-price ">
#         70,000원
#       </div>
#       <div class="card-region-name">
#         대전 서구 월평2동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 26
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580669065" href="/articles/580669065">
#     <div class="card-photo ">
#         <img alt="자전거 3만원" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/99599caaae3e3d6ed9a2fa37f9490584f9e5cbf3203fafee4d726e9a4a3303d9.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">자전거 3만원</h2>
#       <div class="card-price ">
#         30,000원
#       </div>
#       <div class="card-region-name">
#         서울 서초구 양재2동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 6
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580940307" href="/articles/580940307">
#     <div class="card-photo ">
#         <img alt="포르쉐 푸쉬카 판매합니다. (제일 먼저 챗주신분께 예약잡았습니다)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/28750b48167a543589a90880613ade2e5525ed784bc2f46ed9933b0db8f3546b_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">포르쉐 푸쉬카 판매합니다. (제일 먼저 챗주신분께 예약잡았습니다)</h2>
#       <div class="card-price ">
#         50,000원
#       </div>
#       <div class="card-region-name">
#         경기도 김포시 장기본동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="579828761" href="/articles/579828761">
#     <div class="card-photo ">
#         <img alt="아이폰11pro팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/706291aea642dd9d58f6acb87f8561ef6b24bf3b5a79128a131793fbab382d6d.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">아이폰11pro팝니다</h2>
#       <div class="card-price ">
#         200,000원
#       </div>
#       <div class="card-region-name">
#         경기도 화성시 향남읍
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 44
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581078442" href="/articles/581078442">
#     <div class="card-photo ">
#         <img alt="아우디 푸쉬카" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/d6c63ad1ca87e3f7dfa34ad9414a870cc00a91bb296293294ca27366cfdad4b6_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">아우디 푸쉬카</h2>
#       <div class="card-price ">
#         15,000원
#       </div>
#       <div class="card-region-name">
#         서울 동작구 신대방동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581083056" href="/articles/581083056">
#     <div class="card-photo ">
#         <img alt="놀라운자연" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/ff8a1a77f2a448b4cedcc2854947d247ae7ebda33a4de8cbabdf588c89ae7818.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">놀라운자연</h2>
#       <div class="card-price ">
#         100,000원
#       </div>
#       <div class="card-region-name">
#         서울 강서구 가양제3동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580851527" href="/articles/580851527">
#     <div class="card-photo ">
#         <img alt="대우냉장고 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/d2e384005ede792c6748821a9ccedf59e6f031e94b007de17fca4234abb20346.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">대우냉장고 판매</h2>
#       <div class="card-price ">
#         30,000원
#       </div>
#       <div class="card-region-name">
#         서울 동대문구 장안동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580827638" href="/articles/580827638">
#     <div class="card-photo ">
#         <img alt="수납장 선반 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/e9d07efc5aba9e6ced920559be69e4134e064cbea99bcd1bed969691468a9293.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">수납장 선반 팝니다</h2>
#       <div class="card-price ">
#         5,000원
#       </div>
#       <div class="card-region-name">
#         부산 동래구 안락동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="579989085" href="/articles/579989085">
#     <div class="card-photo ">
#         <img alt="냉장고 상태 양호 가져가실분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/bddb9d17a95a7a2ae328e7aa67d9370679362d2ad849883461fe1ed2ce15a789.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">냉장고 상태 양호 가져가실분</h2>
#       <div class="card-price ">
#         55,000원
#       </div>
#       <div class="card-region-name">
#         인천 남동구 논현동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="578467362" href="/articles/578467362">
#     <div class="card-photo ">
#         <img alt="수납장 책상 조명 등등 각각 5천원에 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/4aca8c72939efb4ce3e95a7bf3616d199ceb63b83171d5ab480564afd795b200.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">수납장 책상 조명 등등 각각 5천원에 팝니다</h2>
#       <div class="card-price ">
#         5,000원
#       </div>
#       <div class="card-region-name">
#         경기도 부천시 심곡동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 41
#           </span>
#         ∙
#         <span>
#             채팅 39
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="579875601" href="/articles/579875601">
#     <div class="card-photo ">
#         <img alt="이사 물품 처리합니다!!(협탁, 실내자전거)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/9bdbd4c92da095245d2cb10425f8d1d90ce2a6a8e2e958532c649e57e8608e08.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">이사 물품 처리합니다!!(협탁, 실내자전거)</h2>
#       <div class="card-price ">
#         30,000원
#       </div>
#       <div class="card-region-name">
#         강원도 춘천시 후평동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580640950" href="/articles/580640950">
#     <div class="card-photo ">
#         <img alt="위닉스제습기 16리터" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/09ff21eecf5a1ba65d24cb25025325f8e2fe1e97310f73fb63ee6c8e4a569b8b_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">위닉스제습기 16리터</h2>
#       <div class="card-price ">
#         120,000원
#       </div>
#       <div class="card-region-name">
#         경기도 하남시 망월동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 23
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580933592" href="/articles/580933592">
#     <div class="card-photo ">
#         <img alt="야외 테이블의자" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/b8c1f64476408d0ac8cf16247e5a0aca72971601baabaf0890ad9de6016e6a9a.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">야외 테이블의자</h2>
#       <div class="card-price ">
#         10,000원
#       </div>
#       <div class="card-region-name">
#         경기도 파주시 야당동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 8
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580701872" href="/articles/580701872">
#     <div class="card-photo ">
#         <img alt="스트라이더 밸런스 바이크 블랙" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/138808c34357658379cf0eeb2f6221f1ad8994094d8d4601e32c18044332a856_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">스트라이더 밸런스 바이크 블랙</h2>
#       <div class="card-price ">
#         20,000원
#       </div>
#       <div class="card-region-name">
#         경기도 수원시 영통구 망포동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580686509" href="/articles/580686509">
#     <div class="card-photo ">
#         <img alt="앵글 선반 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/216098ab5c60c86225d2df7c327d942617ff6a22a9555b80e1366b5f56ccc006.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">앵글 선반 팝니다</h2>
#       <div class="card-price ">
#         20,000원
#       </div>
#       <div class="card-region-name">
#         대구 남구 대명4동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581051671" href="/articles/581051671">
#     <div class="card-photo ">
#         <img alt="스팸" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/6865a963f45b5d041de5d4662fff21c9d12dcb260b8ee1ca517314da7e638191_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">스팸</h2>
#       <div class="card-price ">
#         5,000원
#       </div>
#       <div class="card-region-name">
#         경기도 안양시 동안구 호계1동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581025915" href="/articles/581025915">
#     <div class="card-photo ">
#         <img alt="티티카카 접이식자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/e14711b0b0a38aefa731e56d95748751e5f2fbef9b3ef72bf93e4a90f3a0a9d3_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">티티카카 접이식자전거</h2>
#       <div class="card-price ">
#         100,000원
#       </div>
#       <div class="card-region-name">
#         인천 부평구 삼산2동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 8
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580827570" href="/articles/580827570">
#     <div class="card-photo ">
#         <img alt="이사가서 내놓습니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/ba74019d2078edea0af05f43a0c3269004d54a9f085818a7be8330e309fef46f_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">이사가서 내놓습니다.</h2>
#       <div class="card-price ">
#         1,000원
#       </div>
#       <div class="card-region-name">
#         인천 미추홀구 도화동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580951873" href="/articles/580951873">
#     <div class="card-photo ">
#         <img alt="에어팟 프로 급처 합니다 !" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/fe9c8bf219c00fa850d43b22e9856d6d84f47c15b692f93f434e279011cd64dc.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">에어팟 프로 급처 합니다 !</h2>
#       <div class="card-price ">
#         50,000원
#       </div>
#       <div class="card-region-name">
#         대전 대덕구 중리동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 16
#           </span>
#         ∙
#         <span>
#             채팅 42
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581047056" href="/articles/581047056">
#     <div class="card-photo ">
#         <img alt="세탁기&amp;냉장고 판매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/3b34a98091840bba7e29f728cdbdcfd940c51d1905ec8a19e563dd4a6c2596ea_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">세탁기&amp;냉장고 판매합니다.</h2>
#       <div class="card-price ">
#         10,000원
#       </div>
#       <div class="card-region-name">
#         경기도 시흥시 거모동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580953088" href="/articles/580953088">
#     <div class="card-photo ">
#         <img alt="벽걸이 에어컨) 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/2db4f35e5ad430cc246b8384508dcd5d93ee67f2de8e535b79de3a62364177c1_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">벽걸이 에어컨) 팝니다</h2>
#       <div class="card-price ">
#         50,000원
#       </div>
#       <div class="card-region-name">
#         광주 서구 화정동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580767132" href="/articles/580767132">
#     <div class="card-photo ">
#         <img alt="예초기 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/6d7995678ba1bd47b4a2e7f6d4ee7a17d5c8fd5f8fbd022c4cb818ebae3ad173_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">예초기 팝니다</h2>
#       <div class="card-price ">
#         50,000원
#       </div>
#       <div class="card-region-name">
#         경남 진주시 칠암동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 8
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="579961502" href="/articles/579961502">
#     <div class="card-photo ">
#         <img alt="[여름대비] 위니아 제습기 11리터  20년 출시제품" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/e9c6b61435effbbc10a5a55a6d1f91784d11c0f5f533c77f1865720dc0f56153_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">[여름대비] 위니아 제습기 11리터  20년 출시제품</h2>
#       <div class="card-price ">
#         110,000원
#       </div>
#       <div class="card-region-name">
#         광주 서구 농성동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 20
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581087353" href="/articles/581087353">
#     <div class="card-photo ">
#         <img alt="전기톱 마끼다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/89d263dc2fcf128b97bad5533e6464c04b30e6c0fc22c9bc18f1cfdd3ad0a9df_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">전기톱 마끼다</h2>
#       <div class="card-price ">
#         10,000원
#       </div>
#       <div class="card-region-name">
#         경기도 양주시 회천2동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="578353692" href="/articles/578353692">
#     <div class="card-photo ">
#         <img alt="진짜 급해요 사례금 드립니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/4f88bbc969ea2d1e6ed6bf02640864f5e137c02ac38452b9fb7b2549f2dc8a95.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">진짜 급해요 사례금 드립니다</h2>
#       <div class="card-price ">
#         200,000원
#       </div>
#       <div class="card-region-name">
#         경기도 안산시 상록구 본오2동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581099618" href="/articles/581099618">
#     <div class="card-photo ">
#         <img alt="삼성 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/48c06b4b21c11e6bfba03acc95d48b8b60939ef340f7e350e5cc524063de2a14.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">삼성 제습기</h2>
#       <div class="card-price ">
#         50,000원
#       </div>
#       <div class="card-region-name">
#         인천 연수구 송도3동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581085301" href="/articles/581085301">
#     <div class="card-photo ">
#         <img alt="벽걸이 에어컨 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/00c06de770ce6d224d65b59f0a64f9ef3293f0295cd730ee895e16816788e661_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">벽걸이 에어컨 판매</h2>
#       <div class="card-price ">
#         10,000원
#       </div>
#       <div class="card-region-name">
#         강원도 원주시 호저면
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580683568" href="/articles/580683568">
#     <div class="card-photo ">
#         <img alt="마샬 액톤2 블랙" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/9eaaa7fb853ebe0926e30091a0170fd686128b1c9446bddaf97a24fea4ca0d2b.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">마샬 액톤2 블랙</h2>
#       <div class="card-price ">
#         130,000원
#       </div>
#       <div class="card-region-name">
#         충북 청주시 서원구 개신동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 6
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="580893573" href="/articles/580893573">
#     <div class="card-photo ">
#         <img alt="구찌가방" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/b1bc5711883384d39235d0dea3805c245c2d92458b3462730e1bd1a33aad2bc2.jpg?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">구찌가방</h2>
#       <div class="card-price ">
#         60,000원
#       </div>
#       <div class="card-region-name">
#         경기도 화성시 산척동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 16
#           </span>
#         ∙
#         <span>
#             채팅 6
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="577859512" href="/articles/577859512">
#     <div class="card-photo ">
#         <img alt="텐트 처분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/9068095998ae4ae03467c7f9c9ec013cb591cdaf8ebfae1f3f0c11b9aafa490e_0.webp?q=82&amp;s=300x300&amp;t=crop" />
#     </div>
#     <div class="card-desc">
#       <h2 class="card-title">텐트 처분</h2>
#       <div class="card-price ">
#         600,000원
#       </div>
#       <div class="card-region-name">
#         인천 남동구 구월2동
#       </div>
#       <div class="card-counts">
#           <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 35
#           </span>
#       </div>
#     </div>
# </a></article>
# <article class="card-top ">
#   <a class="card-link " data-event-label="581069687" href="/articles/581069687">
# ...
# `+wo+e}var xo=!1;function ko(e,t){if(!e||xo)return"";xo=!0;var n=Error.prepareStackTrace;Error.prepareStackTrace=void 0;try{if(t)if(t=function(){throw Error()},Object.defineProperty(t.prototype,"props",{set:function(){throw Error()}}),typeof Reflect=="object"&&Reflect.construct){try{Reflect.construct(t,[])}catch(a){var r=a}Reflect.construct(e,[],t)}else{try{t.call()}catch(a){r=a}e.call(t.prototype)}else{try{throw Error()}catch(a){r=a}e()}}catch(a){if(a&&r&&typeof a.stack=="string"){for(var l=a.stack.split(`
# `),o=r.stack.split(`
# `),i=l.length-1,u=o.length-1;1<=i&&0<=u&&l[i]!==o[u];)u--;for(;1<=i&&0<=u;i--,u--)if(l[i]!==o[u]){if(i!==1||u!==1)do if(i--,u--,0>u||l[i]!==o[u]){var s=`
# `+l[i].replace(" at new "," at ");return e.displayName&&s.includes("<anonymous>")&&(s=s.replace("<anonymous>",e.displayName)),s}while(1<=i&&0<=u);break}}}finally{xo=!1,Error.prepareStackTrace=n}return(e=e?e.displayName||e.name:"")?Tn(e):""}function Vf(e){switch(e.tag){case 5:return Tn(e.type);case 16:return Tn("Lazy");case 13:return Tn("Suspense");case 19:return Tn("SuspenseList");case 0:case 2:case 15:return e=ko(e.type,!1),e;case 11:return e=ko(e.type.render,!1),e;case 1:return e=ko(e.type,!0),e;default:return""}}function qo(e){if(e==null)return null;if(typeof e=="function")return e.displayName||e.name||null;if(typeof e=="string")return e;switch(e){case Bt:return"Fragment";case At:return"Portal";case $o:return"Profiler";case Ii:return"StrictMode";case Zo:return"Suspense";case Wo:return"SuspenseList"}if(typeof e=="object")switch(e.$$typeof){case Fa:return(e.displayName||"Context")+".Consumer";case ja:return(e._context.displayName||"Context")+".Provider";case Vi:var t=e.render;return e=e.displayName,e||(e=t.displayName||t.name||"",e=e!==""?"ForwardRef("+e+")":"ForwardRef"),e;case ji:return t=e.displayName||null,t!==null?t:qo(e.type)||"Memo";case et:t=e._payload,e=e._init;try{return qo(e(t))}catch(n){}}return null}function jf(e){var t=e.type;switch(e.tag){case 24:return"Cache";case 9:return(t.displayName||"Context")+".Consumer";case 10:return(t._context.displayName||"Context")+".Provider";case 18:return"DehydratedFragment";case 11:return e=t.render,e=e.displayName||e.name||"",t.displayName||(e!==""?"ForwardRef("+e+")":"ForwardRef");case 7:return"Fragment";case 5:return t;case 4:return"Portal";case 3:return"Root";case 6:return"Text";case 16:return qo(t);case 8:return t===Ii?"StrictMode":"Mode";case 22:return"Offscreen";case 12:return"Profiler";case 21:return"Scope";case 13:return"Suspense";case 19:return"SuspenseList";case 25:return"TracingMarker";case 1:case 0:case 17:case 2:case 14:case 15:if(typeof t=="function")return t.displayName||t.name||null;if(typeof t=="string")return t}return null}function dt(e){switch(typeof e){case"boolean":case"number":case"string":case"undefined":return e;case"object":return e;default:return""}}function Aa(e){var t=e.type;return(e=e.nodeName)&&e.toLowerCase()==="input"&&(t==="checkbox"||t==="radio")}function Ff(e){var t=Aa(e)?"checked":"value",n=Object.getOwnPropertyDescriptor(e.constructor.prototype,t),r=""+e[t];if(!e.hasOwnProperty(t)&&typeof n!="undefined"&&typeof n.get=="function"&&typeof n.set=="function"){var l=n.get,o=n.set;return Object.defineProperty(e,t,{configurable:!0,get:function(){return l.call(this)},set:function(i){r=""+i,o.call(this,i)}}),Object.defineProperty(e,t,{enumerable:n.enumerable}),{getValue:function(){return r},setValue:function(i){r=""+i},stopTracking:function(){e._valueTracker=null,delete e[t]}}}}function Dr(e){e._valueTracker||(e._valueTracker=Ff(e))}function Ba(e){if(!e)return!1;var t=e._valueTracker;if(!t)return!0;var n=t.getValue(),r="";return e&&(r=Aa(e)?e.checked?"true":"false":e.value),e=r,e!==n?(t.setValue(e),!0):!1}function cl(e){if(e=e||(typeof document!="undefined"?document:void 0),typeof e=="undefined")return null;try{return e.activeElement||e.body}catch(t){return e.body}}function Qo(e,t){var n=t.checked;return B({},t,{defaultChecked:void 0,defaultValue:void 0,value:void 0,checked:n!=null?n:e._wrapperState.initialChecked})}function Rs(e,t){var n=t.defaultValue==null?"":t.defaultValue,r=t.checked!=null?t.checked:t.defaultChecked;n=dt(t.value!=null?t.value:n),e._wrapperState={initialChecked:r,initialValue:n,controlled:t.type==="checkbox"||t.type==="radio"?t.checked!=null:t.value!=null}}function Ua(e,t){t=t.checked,t!=null&&Di(e,"checked",t,!1)}function Ko(e,t){Ua(e,t);var n=dt(t.value),r=t.type;if(n!=null)r==="number"?(n===0&&e.value===""||e.value!=n)&&(e.value=""+n):e.value!==""+n&&(e.value=""+n);else if(r==="submit"||r==="reset"){e.removeAttribute("value");return}t.hasOwnProperty("value")?Go(e,t.type,n):t.hasOwnProperty("defaultValue")&&Go(e,t.type,dt(t.def ...
# `).replace(q0,"")}function qr(e,t,n){if(t=ta(t),ta(e)!==t&&n)throw Error(v(425))}function gl(){}var ai=null;function ci(e,t){return e==="textarea"||e==="noscript"||typeof t.children=="string"||typeof t.children=="number"||typeof t.dangerouslySetInnerHTML=="object"&&t.dangerouslySetInnerHTML!==null&&t.dangerouslySetInnerHTML.__html!=null}var fi=typeof setTimeout=="function"?setTimeout:void 0,Q0=typeof clearTimeout=="function"?clearTimeout:void 0,na=typeof Promise=="function"?Promise:void 0,K0=typeof queueMicrotask=="function"?queueMicrotask:typeof na!="undefined"?function(e){return na.resolve(null).then(e).catch(G0)}:fi;function G0(e){setTimeout(function(){throw e})}function zo(e,t){var n=t,r=0;do{var l=n.nextSibling;if(e.removeChild(n),l&&l.nodeType===8)if(n=l.data,n==="/$"){if(r===0){e.removeChild(l),Kn(t);return}r--}else n!=="$"&&n!=="$?"&&n!=="$!"||r++;n=l}while(n);Kn(t)}function Be(e){for(;e!=null;e=e.nextSibling){var t=e.nodeType;if(t===1||t===3)break;if(t===8){if(t=e.data,t==="$"||t==="$!"||t==="$?")break;if(t==="/$")return null}}return e}function ra(e){e=e.previousSibling;for(var t=0;e;){if(e.nodeType===8){var n=e.data;if(n==="$"||n==="$!"||n==="$?"){if(t===0)return e;t--}else n==="/$"&&t++}e=e.previousSibling}return null}var pn=Math.random().toString(36).slice(2),Oe="__reactFiber$"+pn,bn="__reactProps$"+pn,qe="__reactContainer$"+pn,di="__reactEvents$"+pn,Y0="__reactListeners$"+pn,X0="__reactHandles$"+pn;function wt(e){var t=e[Oe];if(t)return t;for(var n=e.parentNode;n;){if(t=n[qe]||n[Oe]){if(n=t.alternate,t.child!==null||n!==null&&n.child!==null)for(e=ra(e);e!==null;){if(n=e[Oe])return n;e=ra(e)}return t}e=n,n=e.parentNode}return null}function ar(e){return e=e[Oe]||e[qe],!e||e.tag!==5&&e.tag!==6&&e.tag!==13&&e.tag!==3?null:e}function Wt(e){if(e.tag===5||e.tag===6)return e.stateNode;throw Error(v(33))}function Hl(e){return e[bn]||null}var pi=[],qt=-1;function vt(e){return{current:e}}function F(e){0>qt||(e.current=pi[qt],pi[qt]=null,qt--)}function I(e,t){qt++,pi[qt]=e.current,e.current=t}var pt={},te=vt(pt),ae=vt(!1),Pt=pt;function ln(e,t){var n=e.type.contextTypes;if(!n)return pt;var r=e.stateNode;if(r&&r.__reactInternalMemoizedUnmaskedChildContext===t)return r.__reactInternalMemoizedMaskedChildContext;var l={},o;for(o in n)l[o]=t[o];return r&&(e=e.stateNode,e.__reactInternalMemoizedUnmaskedChildContext=t,e.__reactInternalMemoizedMaskedChildContext=l),l}function ce(e){return e=e.childContextTypes,e!=null}function yl(){F(ae),F(te)}function la(e,t,n){if(te.current!==pt)throw Error(v(168));I(te,t),I(ae,n)}function M1(e,t,n){var r=e.stateNode;if(t=t.childContextTypes,typeof r.getChildContext!="function")return n;r=r.getChildContext();for(var l in r)if(!(l in t))throw Error(v(108,jf(e)||"Unknown",l));return B({},n,r)}function Cl(e){return e=(e=e.stateNode)&&e.__reactInternalMemoizedMergedChildContext||pt,Pt=te.current,I(te,e),I(ae,ae.current),!0}function oa(e,t,n){var r=e.stateNode;if(!r)throw Error(v(169));n?(e=M1(e,t,Pt),r.__reactInternalMemoizedMergedChildContext=e,F(ae),F(te),I(te,e)):F(ae),I(ae,n)}var Ae=null,Al=!1,Do=!1;function R1(e){Ae===null?Ae=[e]:Ae.push(e)}function J0(e){Al=!0,R1(e)}function gt(){if(!Do&&Ae!==null){Do=!0;var e=0,t=O;try{var n=Ae;for(O=1;e<n.length;e++){var r=n[e];do r=r(!0);while(r!==null)}Ae=null,Al=!1}catch(l){throw Ae!==null&&(Ae=Ae.slice(e+1)),n1(Hi,gt),l}finally{O=t,Do=!1}}return null}var b0=Ke.ReactCurrentBatchConfig;function Le(e,t){if(e&&e.defaultProps){t=B({},t),e=e.defaultProps;for(var n in e)t[n]===void 0&&(t[n]=e[n]);return t}return t}var El=vt(null),wl=null,Qt=null,Ki=null;function Gi(){Ki=Qt=wl=null}function Yi(e){var t=El.current;F(El),e._currentValue=t}function mi(e,t,n){for(;e!==null;){var r=e.alternate;if((e.childLanes&t)!==t?(e.childLanes|=t,r!==null&&(r.childLanes|=t)):r!==null&&(r.childLanes&t)!==t&&(r.childLanes|=t),e===n)break;e=e.return}}function tn(e,t){wl=e,Ki=Qt=null,e=e.dependencies,e!==null&&e.firstContext!==null&&((e.lanes&t)!==0&&(pe=!0),e.firstContext=null)}functio ...
# Error generating stack: `+o.message+`
# `+o.stack}return{value:e,source:t,stack:l}}function Ci(e,t){try{console.error(t.value)}catch(n){setTimeout(function(){throw n})}}var ud=typeof WeakMap=="function"?WeakMap:Map;function rc(e,t,n){n=Ze(-1,n),n.tag=3,n.payload={element:null};var r=t.value;return n.callback=function(){Rl||(Rl=!0,Li=r),Ci(e,t)},n}function lc(e,t,n){n=Ze(-1,n),n.tag=3;var r=e.type.getDerivedStateFromError;if(typeof r=="function"){var l=t.value;n.payload=function(){return r(l)},n.callback=function(){Ci(e,t)}}var o=e.stateNode;return o!==null&&typeof o.componentDidCatch=="function"&&(n.callback=function(){Ci(e,t),typeof r!="function"&&(ct===null?ct=new Set([this]):ct.add(this));var i=t.stack;this.componentDidCatch(t.value,{componentStack:i!==null?i:""})}),n}function pa(e,t,n){var r=e.pingCache;if(r===null){r=e.pingCache=new ud;var l=new Set;r.set(t,l)}else l=r.get(t),l===void 0&&(l=new Set,r.set(t,l));l.has(n)||(l.add(n),e=wd.bind(null,e,t,n),t.then(e,e))}function ma(e){do{var t;if((t=e.tag===13)&&(t=e.memoizedState,t=t!==null?t.dehydrated!==null:!0),t)return e;e=e.return}while(e!==null);return null}function ha(e,t,n,r,l){return(e.mode&1)===0?(e===t?e.flags|=65536:(e.flags|=128,n.flags|=131072,n.flags&=-52805,n.tag===1&&(n.alternate===null?n.tag=17:(t=Ze(-1,1),t.tag=2,at(n,t))),n.lanes|=1),e):(e.flags|=65536,e.lanes=l,e)}var oc,Ei,ic,uc;oc=function(e,t){for(var n=t.child;n!==null;){if(n.tag===5||n.tag===6)e.appendChild(n.stateNode);else if(n.tag!==4&&n.child!==null){n.child.return=n,n=n.child;continue}if(n===t)break;for(;n.sibling===null;){if(n.return===null||n.return===t)return;n=n.return}n.sibling.return=n.return,n=n.sibling}};Ei=function(){};ic=function(e,t,n,r){var l=e.memoizedProps;if(l!==r){e=t.stateNode,xt(Ie.current);var o=null;switch(n){case"input":l=Qo(e,l),r=Qo(e,r),o=[];break;case"select":l=B({},l,{value:void 0}),r=B({},r,{value:void 0}),o=[];break;case"textarea":l=Yo(e,l),r=Yo(e,r),o=[];break;default:typeof l.onClick!="function"&&typeof r.onClick=="function"&&(e.onclick=gl)}Jo(n,r);var i;n=null;for(a in l)if(!r.hasOwnProperty(a)&&l.hasOwnProperty(a)&&l[a]!=null)if(a==="style"){var u=l[a];for(i in u)u.hasOwnProperty(i)&&(n||(n={}),n[i]="")}else a!=="dangerouslySetInnerHTML"&&a!=="children"&&a!=="suppressContentEditableWarning"&&a!=="suppressHydrationWarning"&&a!=="autoFocus"&&($n.hasOwnProperty(a)?o||(o=[]):(o=o||[]).push(a,null));for(a in r){var s=r[a];if(u=l!=null?l[a]:void 0,r.hasOwnProperty(a)&&s!==u&&(s!=null||u!=null))if(a==="style")if(u){for(i in u)!u.hasOwnProperty(i)||s&&s.hasOwnProperty(i)||(n||(n={}),n[i]="");for(i in s)s.hasOwnProperty(i)&&u[i]!==s[i]&&(n||(n={}),n[i]=s[i])}else n||(o||(o=[]),o.push(a,n)),n=s;else a==="dangerouslySetInnerHTML"?(s=s?s.__html:void 0,u=u?u.__html:void 0,s!=null&&u!==s&&(o=o||[]).push(a,s)):a==="children"?typeof s!="string"&&typeof s!="number"||(o=o||[]).push(a,""+s):a!=="suppressContentEditableWarning"&&a!=="suppressHydrationWarning"&&($n.hasOwnProperty(a)?(s!=null&&a==="onScroll"&&j("scroll",e),o||u===s||(o=[])):(o=o||[]).push(a,s))}n&&(o=o||[]).push("style",n);var a=o;(t.updateQueue=a)&&(t.flags|=4)}};uc=function(e,t,n,r){n!==r&&(t.flags|=4)};function Ln(e,t){if(!H)switch(e.tailMode){case"hidden":t=e.tail;for(var n=null;t!==null;)t.alternate!==null&&(n=t),t=t.sibling;n===null?e.tail=null:n.sibling=null;break;case"collapsed":n=e.tail;for(var r=null;n!==null;)n.alternate!==null&&(r=n),n=n.sibling;r===null?t||e.tail===null?e.tail=null:e.tail.sibling=null:r.sibling=null}}function b(e){var t=e.alternate!==null&&e.alternate.child===e.child,n=0,r=0;if(t)for(var l=e.child;l!==null;)n|=l.lanes|l.childLanes,r|=l.subtreeFlags&14680064,r|=l.flags&14680064,l.return=e,l=l.sibling;else for(l=e.child;l!==null;)n|=l.lanes|l.childLanes,r|=l.subtreeFlags,r|=l.flags,l.return=e,l=l.sibling;return e.subtreeFlags|=r,e.childLanes=n,t}function sd(e,t,n){var r=t.pendingProps;switch(bi(t),t.tag){case 2:case 16:case 15:case 0:case 11:case 7:case 8:case 12:case 9:case 14:return b(t),null;case 1:return ce(t.type)&&yl(),b(t),n ...
# /**
#  * @license React
#  * react-dom.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
# /**
#  * @license React
#  * react-jsx-runtime.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
# /**
#  * @license React
#  * react.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
# /**
#  * @license React
#  * scheduler.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
#
# </script>
#
#
# </body>
# </html>

# %%
# text를 BS로 변환

soup = BeautifulSoup(response.text , 'html.parser')
soup

# 특정 문자열을 가져올 수 있다.

print(soup.p)
print(soup.p.string)
# Out:
# <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>
# 당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!

# %%
# 단순 태그 서칭시 가장 먼저 만나는 해당 태그를 찾아온다. -> 내가 원하는 태그를 찾기 힘들다.
print('<h1> - ' , soup.h1)
# Out:
# <h1> -  <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>

# %%
# ul의 서브리스트를 확인해보자 해당 홈페이지 개발툴에서 태그를 찾아오자
print('<ul> - ' , soup.ul)
# Out:
# <ul> -  <ul class="_1knjz49m _1s38h9c5"><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2 _1knjz49q" href="https://www.daangn.com">중고거래</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/nearby-stores/">동네가게</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/jobs/">알바</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/realty/">부동산 직거래</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/car/">중고차 직거래</a></li></ul>

# %%
# ul 태그의 아래 태그들을 검색
for child in soup.ul.children :
    print(child)
# Out:
# <li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2 _1knjz49q" href="https://www.daangn.com">중고거래</a></li>
# <li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/nearby-stores/">동네가게</a></li>
# <li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/jobs/">알바</a></li>
# <li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/realty/">부동산 직거래</a></li>
# <li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/car/">중고차 직거래</a></li>

# %%
# ul 캐그의 상위 태그들을 검색
for parent in soup.ul.parents :
    print(parent)
# Out:
# <nav class="_1knjz49k _1s38h9c0"><ul class="_1knjz49m _1s38h9c5"><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2 _1knjz49q" href="https://www.daangn.com">중고거래</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/nearby-stores/">동네가게</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/jobs/">알바</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/realty/">부동산 직거래</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/car/">중고차 직거래</a></li></ul></nav>
# <div class="_1knjz491 _1s38h9c0"><a aria-label="logo" class="_1knjz492" href="https://www.daangn.com"><span class="_1knjz493"><svg fill="none" height="28" viewbox="0 0 100 28" width="100" xmlns="http://www.w3.org/2000/svg"><path d="M10.6241 5.1897C4.76013 5.1897 0 9.94831 0 15.8104C0 18.2759 0.845096 20.5345 2.24209 22.3276C2.34557 22.4655 2.4663 22.6035 2.56978 22.7414C2.74225 22.9311 2.89747 23.1207 3.08719 23.3104L3.10443 23.3276C5.13956 25.4828 7.70934 27.1207 10.6068 28C13.5043 27.1207 16.0741 25.4828 18.1092 23.3276L18.1264 23.3104C18.2989 23.1207 18.4714 22.9311 18.6439 22.7414C18.7646 22.6035 18.8681 22.4655 18.9715 22.3276C20.3685 20.5345 21.2136 18.2759 21.2136 15.8104C21.2309 9.93107 16.488 5.1897 10.6241 5.1897ZM10.6241 19.8621C8.38197 19.8621 6.57105 18.0518 6.57105 15.8104C6.57105 13.569 8.38197 11.7587 10.6241 11.7587C12.8662 11.7587 14.6771 13.569 14.6771 15.8104C14.6771 18.0518 12.8662 19.8621 10.6241 19.8621Z" fill="#FF7E36"></path><path d="M14.0743 4.96552C14.7814 4.81035 15.2988 4.18965 15.2988 3.44827C15.2988 2.58621 14.5917 1.87931 13.7293 1.87931C13.4879 1.87931 13.2637 1.93104 13.0567 2.03449C12.8325 0.879318 11.8322 0 10.6076 0C9.38312 0 8.3828 0.879318 8.1586 2.03449C7.95163 1.93104 7.72742 1.87931 7.48597 1.87931C6.62363 1.87931 5.9165 2.58621 5.9165 3.44827C5.9165 4.18965 6.45116 4.81035 7.14103 4.96552C8.22758 4.58621 9.38312 4.37931 10.5904 4.37931C11.7977 4.37931 12.9877 4.58621 14.0743 4.96552Z" fill="#00B493"></path><path d="M28.8191 15.9481H35.3211C36.1317 15.9481 36.7699 15.4654 36.7699 14.4654C36.7699 13.4654 36.1317 12.9826 35.3211 12.9826H29.6642C29.371 12.9826 29.1985 12.8102 29.1985 12.5344V9.98264C29.1985 9.70678 29.371 9.53437 29.6642 9.53437H35.3211C36.1317 9.53437 36.7699 9.0516 36.7699 8.0516C36.7699 7.0516 36.1317 6.56885 35.3211 6.56885H28.8191C26.6115 6.56885 25.5767 7.5516 25.5767 9.39643V13.1378C25.5767 14.9826 26.6115 15.9481 28.8191 15.9481Z" fill="#FF7E36"></path><path d="M36.9594 17.1379H30.5608C27.6806 17.1379 25.7834 18.7241 25.7834 21.0517C25.7834 23.3276 27.6806 24.9138 30.5608 24.9138H36.9594C39.8396 24.9138 41.754 23.3276 41.754 21.0517C41.754 18.7414 39.8396 17.1379 36.9594 17.1379ZM36.9594 21.9138H30.5608C29.8537 21.9138 29.4743 21.5345 29.4743 21.0517C29.4743 20.5345 29.8537 20.1379 30.5608 20.1379H36.9594C37.6665 20.1379 38.0632 20.5345 38.0632 21.0517C38.0632 21.5345 37.6493 21.9138 36.9594 21.9138Z" fill="#FF7E36"></path><path d="M42.3754 9.60339H41.3578V7.65512C41.3578 6.81029 40.6162 6.17236 39.5469 6.17236C38.4776 6.17236 37.7188 6.81029 37.7188 7.65512V15.2068C37.7188 16.0517 38.4776 16.6896 39.5469 16.6896C40.6162 16.6896 41.3578 16.0517 41.3578 15.2068V13.1551H42.3754C43.2032 13.1551 43.8586 12.431 43.8586 11.3965C43.8586 10.3965 43.2032 9.60339 42.3754 9.60339Z" fill="#FF7E36"></path><path d="M60.5189 17.6206H45.6693C44.807 17.6206 44.0999 17.0516 44.0999 15.9999C44.0999 15.0171 44.807 14.4137 45.6693 14.4137H60.5189C61.3812 14.4137 62.0883 15.0344 62.0883 15.9999C62.0883 17.0344 61.3812 17.6206 60.5189 17.6206ZM57.4662 12.3964V10.4654C57.4662 10.1206 57.2764 9.93092 56.9833 9.93092H46.6869C45.79 9.93092 45.0312 9.36194 45.0312 8.27574C45.0312 7.24125 45.79 6.56885 46.6869 6.56885H57.7766C59.9842 6.56885 61.1052 7.70678 61.1052 9.72402V12.3964C61.1052 13.2413 60.3636 13.8792 59.2943 13.8792C58.225 13.8792 57.4662 13.2413 57.4662 12.3964ZM48.7565 19.7068V20.9826C48.7565 21.2413 48.9462 21.4137 49.2394 21.4137H59.829C60.7258 21.4137 61.4847 21.9999 61.4847 23.0688C61.4847 24.1033 60.7258 24.724 59.829 24.724H48.4633C46.273 24.724 45.1002 23.793 45.1002 21.8102V19.7068C45.1002 18.8619 45.8418 18.224 46.9111 18.224C47.9804 18.224 48.7565 18.8619 48.7565 19.7068Z" fill="#FF7E36"></path><path d="M63.9343 21.362V9.12063C63.9343 7.44822 64.7794 6.56891 66.5214 6.56891H71.2642C73.0062 6.56891 73.8513 7.43098 73.8513 9.12063V21.362C73.8513 23.0344 73.0062 23.9137 71.2642 23.9137H66.5214C64.7967 23.9137 63.9343 23.0517 63.9343 21.362ZM70.4364 20.2068V10.293C70.4364  ...
# <div class="_1knjz490"><div class="_1knjz491 _1s38h9c0"><a aria-label="logo" class="_1knjz492" href="https://www.daangn.com"><span class="_1knjz493"><svg fill="none" height="28" viewbox="0 0 100 28" width="100" xmlns="http://www.w3.org/2000/svg"><path d="M10.6241 5.1897C4.76013 5.1897 0 9.94831 0 15.8104C0 18.2759 0.845096 20.5345 2.24209 22.3276C2.34557 22.4655 2.4663 22.6035 2.56978 22.7414C2.74225 22.9311 2.89747 23.1207 3.08719 23.3104L3.10443 23.3276C5.13956 25.4828 7.70934 27.1207 10.6068 28C13.5043 27.1207 16.0741 25.4828 18.1092 23.3276L18.1264 23.3104C18.2989 23.1207 18.4714 22.9311 18.6439 22.7414C18.7646 22.6035 18.8681 22.4655 18.9715 22.3276C20.3685 20.5345 21.2136 18.2759 21.2136 15.8104C21.2309 9.93107 16.488 5.1897 10.6241 5.1897ZM10.6241 19.8621C8.38197 19.8621 6.57105 18.0518 6.57105 15.8104C6.57105 13.569 8.38197 11.7587 10.6241 11.7587C12.8662 11.7587 14.6771 13.569 14.6771 15.8104C14.6771 18.0518 12.8662 19.8621 10.6241 19.8621Z" fill="#FF7E36"></path><path d="M14.0743 4.96552C14.7814 4.81035 15.2988 4.18965 15.2988 3.44827C15.2988 2.58621 14.5917 1.87931 13.7293 1.87931C13.4879 1.87931 13.2637 1.93104 13.0567 2.03449C12.8325 0.879318 11.8322 0 10.6076 0C9.38312 0 8.3828 0.879318 8.1586 2.03449C7.95163 1.93104 7.72742 1.87931 7.48597 1.87931C6.62363 1.87931 5.9165 2.58621 5.9165 3.44827C5.9165 4.18965 6.45116 4.81035 7.14103 4.96552C8.22758 4.58621 9.38312 4.37931 10.5904 4.37931C11.7977 4.37931 12.9877 4.58621 14.0743 4.96552Z" fill="#00B493"></path><path d="M28.8191 15.9481H35.3211C36.1317 15.9481 36.7699 15.4654 36.7699 14.4654C36.7699 13.4654 36.1317 12.9826 35.3211 12.9826H29.6642C29.371 12.9826 29.1985 12.8102 29.1985 12.5344V9.98264C29.1985 9.70678 29.371 9.53437 29.6642 9.53437H35.3211C36.1317 9.53437 36.7699 9.0516 36.7699 8.0516C36.7699 7.0516 36.1317 6.56885 35.3211 6.56885H28.8191C26.6115 6.56885 25.5767 7.5516 25.5767 9.39643V13.1378C25.5767 14.9826 26.6115 15.9481 28.8191 15.9481Z" fill="#FF7E36"></path><path d="M36.9594 17.1379H30.5608C27.6806 17.1379 25.7834 18.7241 25.7834 21.0517C25.7834 23.3276 27.6806 24.9138 30.5608 24.9138H36.9594C39.8396 24.9138 41.754 23.3276 41.754 21.0517C41.754 18.7414 39.8396 17.1379 36.9594 17.1379ZM36.9594 21.9138H30.5608C29.8537 21.9138 29.4743 21.5345 29.4743 21.0517C29.4743 20.5345 29.8537 20.1379 30.5608 20.1379H36.9594C37.6665 20.1379 38.0632 20.5345 38.0632 21.0517C38.0632 21.5345 37.6493 21.9138 36.9594 21.9138Z" fill="#FF7E36"></path><path d="M42.3754 9.60339H41.3578V7.65512C41.3578 6.81029 40.6162 6.17236 39.5469 6.17236C38.4776 6.17236 37.7188 6.81029 37.7188 7.65512V15.2068C37.7188 16.0517 38.4776 16.6896 39.5469 16.6896C40.6162 16.6896 41.3578 16.0517 41.3578 15.2068V13.1551H42.3754C43.2032 13.1551 43.8586 12.431 43.8586 11.3965C43.8586 10.3965 43.2032 9.60339 42.3754 9.60339Z" fill="#FF7E36"></path><path d="M60.5189 17.6206H45.6693C44.807 17.6206 44.0999 17.0516 44.0999 15.9999C44.0999 15.0171 44.807 14.4137 45.6693 14.4137H60.5189C61.3812 14.4137 62.0883 15.0344 62.0883 15.9999C62.0883 17.0344 61.3812 17.6206 60.5189 17.6206ZM57.4662 12.3964V10.4654C57.4662 10.1206 57.2764 9.93092 56.9833 9.93092H46.6869C45.79 9.93092 45.0312 9.36194 45.0312 8.27574C45.0312 7.24125 45.79 6.56885 46.6869 6.56885H57.7766C59.9842 6.56885 61.1052 7.70678 61.1052 9.72402V12.3964C61.1052 13.2413 60.3636 13.8792 59.2943 13.8792C58.225 13.8792 57.4662 13.2413 57.4662 12.3964ZM48.7565 19.7068V20.9826C48.7565 21.2413 48.9462 21.4137 49.2394 21.4137H59.829C60.7258 21.4137 61.4847 21.9999 61.4847 23.0688C61.4847 24.1033 60.7258 24.724 59.829 24.724H48.4633C46.273 24.724 45.1002 23.793 45.1002 21.8102V19.7068C45.1002 18.8619 45.8418 18.224 46.9111 18.224C47.9804 18.224 48.7565 18.8619 48.7565 19.7068Z" fill="#FF7E36"></path><path d="M63.9343 21.362V9.12063C63.9343 7.44822 64.7794 6.56891 66.5214 6.56891H71.2642C73.0062 6.56891 73.8513 7.43098 73.8513 9.12063V21.362C73.8513 23.0344 73.0062 23.9137 71.2642 23.9137H66.5214C64.7967 23.9137 63.9343 23.0517 63.9343 21.362ZM70.4364  ...
# <div class="light-theme"><div class="_1knjz490"><div class="_1knjz491 _1s38h9c0"><a aria-label="logo" class="_1knjz492" href="https://www.daangn.com"><span class="_1knjz493"><svg fill="none" height="28" viewbox="0 0 100 28" width="100" xmlns="http://www.w3.org/2000/svg"><path d="M10.6241 5.1897C4.76013 5.1897 0 9.94831 0 15.8104C0 18.2759 0.845096 20.5345 2.24209 22.3276C2.34557 22.4655 2.4663 22.6035 2.56978 22.7414C2.74225 22.9311 2.89747 23.1207 3.08719 23.3104L3.10443 23.3276C5.13956 25.4828 7.70934 27.1207 10.6068 28C13.5043 27.1207 16.0741 25.4828 18.1092 23.3276L18.1264 23.3104C18.2989 23.1207 18.4714 22.9311 18.6439 22.7414C18.7646 22.6035 18.8681 22.4655 18.9715 22.3276C20.3685 20.5345 21.2136 18.2759 21.2136 15.8104C21.2309 9.93107 16.488 5.1897 10.6241 5.1897ZM10.6241 19.8621C8.38197 19.8621 6.57105 18.0518 6.57105 15.8104C6.57105 13.569 8.38197 11.7587 10.6241 11.7587C12.8662 11.7587 14.6771 13.569 14.6771 15.8104C14.6771 18.0518 12.8662 19.8621 10.6241 19.8621Z" fill="#FF7E36"></path><path d="M14.0743 4.96552C14.7814 4.81035 15.2988 4.18965 15.2988 3.44827C15.2988 2.58621 14.5917 1.87931 13.7293 1.87931C13.4879 1.87931 13.2637 1.93104 13.0567 2.03449C12.8325 0.879318 11.8322 0 10.6076 0C9.38312 0 8.3828 0.879318 8.1586 2.03449C7.95163 1.93104 7.72742 1.87931 7.48597 1.87931C6.62363 1.87931 5.9165 2.58621 5.9165 3.44827C5.9165 4.18965 6.45116 4.81035 7.14103 4.96552C8.22758 4.58621 9.38312 4.37931 10.5904 4.37931C11.7977 4.37931 12.9877 4.58621 14.0743 4.96552Z" fill="#00B493"></path><path d="M28.8191 15.9481H35.3211C36.1317 15.9481 36.7699 15.4654 36.7699 14.4654C36.7699 13.4654 36.1317 12.9826 35.3211 12.9826H29.6642C29.371 12.9826 29.1985 12.8102 29.1985 12.5344V9.98264C29.1985 9.70678 29.371 9.53437 29.6642 9.53437H35.3211C36.1317 9.53437 36.7699 9.0516 36.7699 8.0516C36.7699 7.0516 36.1317 6.56885 35.3211 6.56885H28.8191C26.6115 6.56885 25.5767 7.5516 25.5767 9.39643V13.1378C25.5767 14.9826 26.6115 15.9481 28.8191 15.9481Z" fill="#FF7E36"></path><path d="M36.9594 17.1379H30.5608C27.6806 17.1379 25.7834 18.7241 25.7834 21.0517C25.7834 23.3276 27.6806 24.9138 30.5608 24.9138H36.9594C39.8396 24.9138 41.754 23.3276 41.754 21.0517C41.754 18.7414 39.8396 17.1379 36.9594 17.1379ZM36.9594 21.9138H30.5608C29.8537 21.9138 29.4743 21.5345 29.4743 21.0517C29.4743 20.5345 29.8537 20.1379 30.5608 20.1379H36.9594C37.6665 20.1379 38.0632 20.5345 38.0632 21.0517C38.0632 21.5345 37.6493 21.9138 36.9594 21.9138Z" fill="#FF7E36"></path><path d="M42.3754 9.60339H41.3578V7.65512C41.3578 6.81029 40.6162 6.17236 39.5469 6.17236C38.4776 6.17236 37.7188 6.81029 37.7188 7.65512V15.2068C37.7188 16.0517 38.4776 16.6896 39.5469 16.6896C40.6162 16.6896 41.3578 16.0517 41.3578 15.2068V13.1551H42.3754C43.2032 13.1551 43.8586 12.431 43.8586 11.3965C43.8586 10.3965 43.2032 9.60339 42.3754 9.60339Z" fill="#FF7E36"></path><path d="M60.5189 17.6206H45.6693C44.807 17.6206 44.0999 17.0516 44.0999 15.9999C44.0999 15.0171 44.807 14.4137 45.6693 14.4137H60.5189C61.3812 14.4137 62.0883 15.0344 62.0883 15.9999C62.0883 17.0344 61.3812 17.6206 60.5189 17.6206ZM57.4662 12.3964V10.4654C57.4662 10.1206 57.2764 9.93092 56.9833 9.93092H46.6869C45.79 9.93092 45.0312 9.36194 45.0312 8.27574C45.0312 7.24125 45.79 6.56885 46.6869 6.56885H57.7766C59.9842 6.56885 61.1052 7.70678 61.1052 9.72402V12.3964C61.1052 13.2413 60.3636 13.8792 59.2943 13.8792C58.225 13.8792 57.4662 13.2413 57.4662 12.3964ZM48.7565 19.7068V20.9826C48.7565 21.2413 48.9462 21.4137 49.2394 21.4137H59.829C60.7258 21.4137 61.4847 21.9999 61.4847 23.0688C61.4847 24.1033 60.7258 24.724 59.829 24.724H48.4633C46.273 24.724 45.1002 23.793 45.1002 21.8102V19.7068C45.1002 18.8619 45.8418 18.224 46.9111 18.224C47.9804 18.224 48.7565 18.8619 48.7565 19.7068Z" fill="#FF7E36"></path><path d="M63.9343 21.362V9.12063C63.9343 7.44822 64.7794 6.56891 66.5214 6.56891H71.2642C73.0062 6.56891 73.8513 7.43098 73.8513 9.12063V21.362C73.8513 23.0344 73.0062 23.9137 71.2642 23.9137H66.5214C64.7967 23.9137 63.9343 23.0517 ...
# <div id="gnb-root"><div class="light-theme"><div class="_1knjz490"><div class="_1knjz491 _1s38h9c0"><a aria-label="logo" class="_1knjz492" href="https://www.daangn.com"><span class="_1knjz493"><svg fill="none" height="28" viewbox="0 0 100 28" width="100" xmlns="http://www.w3.org/2000/svg"><path d="M10.6241 5.1897C4.76013 5.1897 0 9.94831 0 15.8104C0 18.2759 0.845096 20.5345 2.24209 22.3276C2.34557 22.4655 2.4663 22.6035 2.56978 22.7414C2.74225 22.9311 2.89747 23.1207 3.08719 23.3104L3.10443 23.3276C5.13956 25.4828 7.70934 27.1207 10.6068 28C13.5043 27.1207 16.0741 25.4828 18.1092 23.3276L18.1264 23.3104C18.2989 23.1207 18.4714 22.9311 18.6439 22.7414C18.7646 22.6035 18.8681 22.4655 18.9715 22.3276C20.3685 20.5345 21.2136 18.2759 21.2136 15.8104C21.2309 9.93107 16.488 5.1897 10.6241 5.1897ZM10.6241 19.8621C8.38197 19.8621 6.57105 18.0518 6.57105 15.8104C6.57105 13.569 8.38197 11.7587 10.6241 11.7587C12.8662 11.7587 14.6771 13.569 14.6771 15.8104C14.6771 18.0518 12.8662 19.8621 10.6241 19.8621Z" fill="#FF7E36"></path><path d="M14.0743 4.96552C14.7814 4.81035 15.2988 4.18965 15.2988 3.44827C15.2988 2.58621 14.5917 1.87931 13.7293 1.87931C13.4879 1.87931 13.2637 1.93104 13.0567 2.03449C12.8325 0.879318 11.8322 0 10.6076 0C9.38312 0 8.3828 0.879318 8.1586 2.03449C7.95163 1.93104 7.72742 1.87931 7.48597 1.87931C6.62363 1.87931 5.9165 2.58621 5.9165 3.44827C5.9165 4.18965 6.45116 4.81035 7.14103 4.96552C8.22758 4.58621 9.38312 4.37931 10.5904 4.37931C11.7977 4.37931 12.9877 4.58621 14.0743 4.96552Z" fill="#00B493"></path><path d="M28.8191 15.9481H35.3211C36.1317 15.9481 36.7699 15.4654 36.7699 14.4654C36.7699 13.4654 36.1317 12.9826 35.3211 12.9826H29.6642C29.371 12.9826 29.1985 12.8102 29.1985 12.5344V9.98264C29.1985 9.70678 29.371 9.53437 29.6642 9.53437H35.3211C36.1317 9.53437 36.7699 9.0516 36.7699 8.0516C36.7699 7.0516 36.1317 6.56885 35.3211 6.56885H28.8191C26.6115 6.56885 25.5767 7.5516 25.5767 9.39643V13.1378C25.5767 14.9826 26.6115 15.9481 28.8191 15.9481Z" fill="#FF7E36"></path><path d="M36.9594 17.1379H30.5608C27.6806 17.1379 25.7834 18.7241 25.7834 21.0517C25.7834 23.3276 27.6806 24.9138 30.5608 24.9138H36.9594C39.8396 24.9138 41.754 23.3276 41.754 21.0517C41.754 18.7414 39.8396 17.1379 36.9594 17.1379ZM36.9594 21.9138H30.5608C29.8537 21.9138 29.4743 21.5345 29.4743 21.0517C29.4743 20.5345 29.8537 20.1379 30.5608 20.1379H36.9594C37.6665 20.1379 38.0632 20.5345 38.0632 21.0517C38.0632 21.5345 37.6493 21.9138 36.9594 21.9138Z" fill="#FF7E36"></path><path d="M42.3754 9.60339H41.3578V7.65512C41.3578 6.81029 40.6162 6.17236 39.5469 6.17236C38.4776 6.17236 37.7188 6.81029 37.7188 7.65512V15.2068C37.7188 16.0517 38.4776 16.6896 39.5469 16.6896C40.6162 16.6896 41.3578 16.0517 41.3578 15.2068V13.1551H42.3754C43.2032 13.1551 43.8586 12.431 43.8586 11.3965C43.8586 10.3965 43.2032 9.60339 42.3754 9.60339Z" fill="#FF7E36"></path><path d="M60.5189 17.6206H45.6693C44.807 17.6206 44.0999 17.0516 44.0999 15.9999C44.0999 15.0171 44.807 14.4137 45.6693 14.4137H60.5189C61.3812 14.4137 62.0883 15.0344 62.0883 15.9999C62.0883 17.0344 61.3812 17.6206 60.5189 17.6206ZM57.4662 12.3964V10.4654C57.4662 10.1206 57.2764 9.93092 56.9833 9.93092H46.6869C45.79 9.93092 45.0312 9.36194 45.0312 8.27574C45.0312 7.24125 45.79 6.56885 46.6869 6.56885H57.7766C59.9842 6.56885 61.1052 7.70678 61.1052 9.72402V12.3964C61.1052 13.2413 60.3636 13.8792 59.2943 13.8792C58.225 13.8792 57.4662 13.2413 57.4662 12.3964ZM48.7565 19.7068V20.9826C48.7565 21.2413 48.9462 21.4137 49.2394 21.4137H59.829C60.7258 21.4137 61.4847 21.9999 61.4847 23.0688C61.4847 24.1033 60.7258 24.724 59.829 24.724H48.4633C46.273 24.724 45.1002 23.793 45.1002 21.8102V19.7068C45.1002 18.8619 45.8418 18.224 46.9111 18.224C47.9804 18.224 48.7565 18.8619 48.7565 19.7068Z" fill="#FF7E36"></path><path d="M63.9343 21.362V9.12063C63.9343 7.44822 64.7794 6.56891 66.5214 6.56891H71.2642C73.0062 6.56891 73.8513 7.43098 73.8513 9.12063V21.362C73.8513 23.0344 73.0062 23.9137 71.2642 23.9137H66.5214C64.7967 23.9 ...
# <body class="hoian-kr">
# <noscript><img alt="facebook" height="1" src="https://www.facebook.com/tr?id=992961397411651&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- Appsflyer Smart Banner -->
# <script>
#     !function(t,e,n,s,a,c,i,o,p){t.AppsFlyerSdkObject=a,t.AF=t.AF||function(){(t.AF.q=t.AF.q||[]).push([Date.now()].concat(Array.prototype.slice.call(arguments)))},t.AF.id=t.AF.id||i,t.AF.plugins={},o=e.createElement(n),p=e.getElementsByTagName(n)[0],o.async=1,o.src="https://websdk.appsflyer.com?"+(c.length>0?"st="+c.split(",").sort().join(",")+"&":"")+(i.length>0?"af_id="+i:""),p.parentNode.insertBefore(o,p)}(window,document,"script",0,"AF","banners",{banners: {key: "629f6f7a-a2a6-49c0-8d27-ffa48df1cd0e"}})
#     AF('banners', 'showBanner')
# </script>
# <!-- End Appsflyer Smart Banner-->
# <div id="gnb-root"><div class="light-theme"><div class="_1knjz490"><div class="_1knjz491 _1s38h9c0"><a aria-label="logo" class="_1knjz492" href="https://www.daangn.com"><span class="_1knjz493"><svg fill="none" height="28" viewbox="0 0 100 28" width="100" xmlns="http://www.w3.org/2000/svg"><path d="M10.6241 5.1897C4.76013 5.1897 0 9.94831 0 15.8104C0 18.2759 0.845096 20.5345 2.24209 22.3276C2.34557 22.4655 2.4663 22.6035 2.56978 22.7414C2.74225 22.9311 2.89747 23.1207 3.08719 23.3104L3.10443 23.3276C5.13956 25.4828 7.70934 27.1207 10.6068 28C13.5043 27.1207 16.0741 25.4828 18.1092 23.3276L18.1264 23.3104C18.2989 23.1207 18.4714 22.9311 18.6439 22.7414C18.7646 22.6035 18.8681 22.4655 18.9715 22.3276C20.3685 20.5345 21.2136 18.2759 21.2136 15.8104C21.2309 9.93107 16.488 5.1897 10.6241 5.1897ZM10.6241 19.8621C8.38197 19.8621 6.57105 18.0518 6.57105 15.8104C6.57105 13.569 8.38197 11.7587 10.6241 11.7587C12.8662 11.7587 14.6771 13.569 14.6771 15.8104C14.6771 18.0518 12.8662 19.8621 10.6241 19.8621Z" fill="#FF7E36"></path><path d="M14.0743 4.96552C14.7814 4.81035 15.2988 4.18965 15.2988 3.44827C15.2988 2.58621 14.5917 1.87931 13.7293 1.87931C13.4879 1.87931 13.2637 1.93104 13.0567 2.03449C12.8325 0.879318 11.8322 0 10.6076 0C9.38312 0 8.3828 0.879318 8.1586 2.03449C7.95163 1.93104 7.72742 1.87931 7.48597 1.87931C6.62363 1.87931 5.9165 2.58621 5.9165 3.44827C5.9165 4.18965 6.45116 4.81035 7.14103 4.96552C8.22758 4.58621 9.38312 4.37931 10.5904 4.37931C11.7977 4.37931 12.9877 4.58621 14.0743 4.96552Z" fill="#00B493"></path><path d="M28.8191 15.9481H35.3211C36.1317 15.9481 36.7699 15.4654 36.7699 14.4654C36.7699 13.4654 36.1317 12.9826 35.3211 12.9826H29.6642C29.371 12.9826 29.1985 12.8102 29.1985 12.5344V9.98264C29.1985 9.70678 29.371 9.53437 29.6642 9.53437H35.3211C36.1317 9.53437 36.7699 9.0516 36.7699 8.0516C36.7699 7.0516 36.1317 6.56885 35.3211 6.56885H28.8191C26.6115 6.56885 25.5767 7.5516 25.5767 9.39643V13.1378C25.5767 14.9826 26.6115 15.9481 28.8191 15.9481Z" fill="#FF7E36"></path><path d="M36.9594 17.1379H30.5608C27.6806 17.1379 25.7834 18.7241 25.7834 21.0517C25.7834 23.3276 27.6806 24.9138 30.5608 24.9138H36.9594C39.8396 24.9138 41.754 23.3276 41.754 21.0517C41.754 18.7414 39.8396 17.1379 36.9594 17.1379ZM36.9594 21.9138H30.5608C29.8537 21.9138 29.4743 21.5345 29.4743 21.0517C29.4743 20.5345 29.8537 20.1379 30.5608 20.1379H36.9594C37.6665 20.1379 38.0632 20.5345 38.0632 21.0517C38.0632 21.5345 37.6493 21.9138 36.9594 21.9138Z" fill="#FF7E36"></path><path d="M42.3754 9.60339H41.3578V7.65512C41.3578 6.81029 40.6162 6.17236 39.5469 6.17236C38.4776 6.17236 37.7188 6.81029 37.7188 7.65512V15.2068C37.7188 16.0517 38.4776 16.6896 39.5469 16.6896C40.6162 16.6896 41.3578 16.0517 41.3578 15.2068V13.1551H42.3754C43.2032 13.1551 43.8586 12.431 43.8586 11.3965C43.8586 10.3965 43.2032 9.60339 42.3754 9.60339Z" fill="#FF7E36"></path><path d="M60.5189 17.6206H45.6693C44.807 17.6206 44.0999 17.0516 44.0999 15.9999C44.0999 15.0171 44.807 14.4137 45.6693 14.4137H60.5189C61.3812 14.4137 62.0883 15.0344 62.0883 15.9999C62.0883 17.0344 61.3812 17.6206 60.5189 17.6206ZM57.4662 12.3964V10.4654C57.4662 10.1206 57.2764 9.93092 56.9833 9.93092H46.6869C45.79 9.93092 45.0312 9.36194 45.0312 8.27574C45.0312 7.24125 45.79 6.56885 46.6869 6.56885H57.7766C59.9842 6.56885 61.1052 7.70678 61.1052 9.72402V12.3964C61.1052 13.2413 60.3636 13.8792 59.2943 13.8792C58.225 13.8792 57.4662 13.2413 57.4662 12.3964ZM48.7565 19.7068V20.9826C48.7565 21.2413 48.9462 21.4137 49.2394 21.4137H59.829C60.7258 21.4137 61.4847 21.9999 61.4847 23.0688C61.4847 24.1033 60.7258 24.724 59.829 24.724H48.4633C46.273 24.724 45.1002 23.793 45.1002 21.8102V19.7068C45.1002 18.8619 45.8418 18.224 46.9111 18.224C47.9804 18.224 48.7565 18.8619 48.7565 19.7068Z" fill="#FF7E36"></path><path d="M63.9343 21.362V9.12063C63.9343 7.44822 64.7794 6.56891 66.5214 6.56891H71.2642C73.0062 6.56891 73.8513 7.43098 73.8513 9.12063V21.362C73.8513 23.0344 73.0062 23.9137 71.2642 23.9137H66.5214C64.7967 23.9 ...
# <section id="content">
# <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>
# <nav id="hot-articles-navigation">
# <select class="hot-articles-nav-select" id="region1" name="region1" onchange="changeRegion('r1', this.value)"><option value="">지역을 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# <select class="hot-articles-nav-select" disabled="disabled" id="region2" name="region2" onchange="changeRegion('r2', this.value)"><option value="">동네를 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# </nav>
# <section class="cards-wrap">
# <article class="card-top">
# <a class="card-link" data-event-label="580560908" href="/articles/580560908">
# <div class="card-photo">
# <img alt="아이폰13" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/ef5df919752dee22f02bb8b2b5cac04c467c1dbdd06fcd1f9e44d0062e27cf16_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰13</h2>
# <div class="card-price">
#         200,000원
#       </div>
# <div class="card-region-name">
#         광주 광산구 신가동
#       </div>
# <div class="card-counts">
# <span>
#             관심 19
#           </span>
#         ∙
#         <span>
#             채팅 73
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="581040255" href="/articles/581040255">
# <div class="card-photo">
# <img alt="코카콜라 미니 냉장고 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/203710016bf5fb8b8075392a5aec17d78aea5b79170c9d46a96a879475bf7496.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">코카콜라 미니 냉장고 판매</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         충남 당진시 송악읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 32
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580762227" href="/articles/580762227">
# <div class="card-photo">
# <img alt="전화주세요 01048506787" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/4158482b6b216ce0d6aa2ff38a686b77915efcca5872e9850b277750e6ec6de3.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">전화주세요 01048506787</h2>
# <div class="card-price">
#         1원
#       </div>
# <div class="card-region-name">
#         전남 목포시 북항동
#       </div>
# <div class="card-counts">
# <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 46
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580875569" href="/articles/580875569">
# <div class="card-photo">
# <img alt="농약분무기 가져가세요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/032f45d1bc21f5fced44de58113b2cdc7bde18e83a549e1cb210e18a7ebe6d75_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">농약분무기 가져가세요</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         경북 김천시 다수동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="578417402" href="/articles/578417402">
# <div class="card-photo">
# <img alt="아이폰 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/347eb486adae9deb6d2335b21550fdce4a0bb3b636867371e3404c20cf3bc8d8.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰 팔아요</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         전북 군산시 경암동
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 89
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580882649" href="/articles/580882649">
# <div class="card-photo">
# <img alt="나이키 운동화 새제품" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/4a05154ac42318d114c979d23c8365433154d1639aaf61090e00efa7cdd2090d.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">나이키 운동화 새제품</h2>
# <div class="card-price">
#         40,000원
#       </div>
# <div class="card-region-name">
#         경기도 부천시 상동
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 41
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580866787" href="/articles/580866787">
# <div class="card-photo">
# <img alt="크록스 260" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/aadd5eb4ed24f784bcabc9c2b6b84b9ea920bde981db9f1a5b2c5eafe87cd082_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">크록스 260</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         대구 달서구 월성동
#       </div>
# <div class="card-counts">
# <span>
#             관심 35
#           </span>
#         ∙
#         <span>
#             채팅 48
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580772115" href="/articles/580772115">
# <div class="card-photo">
# <img alt="중고 컨테이너 3*6 판매 합니다 / 급처분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/12c6f83daa23664e589b57db21b3a36399e2229c1dc245be638d95d722b4edc9_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">중고 컨테이너 3*6 판매 합니다 / 급처분</h2>
# <div class="card-price">
#         900,000원
#       </div>
# <div class="card-region-name">
#         대구 동구 신천동
#       </div>
# <div class="card-counts">
# <span>
#             관심 22
#           </span>
#         ∙
#         <span>
#             채팅 40
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="578159254" href="/articles/578159254">
# <div class="card-photo">
# <img alt="세차기 세척기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/53b869b41265acbccec0b28e51150ca9b334c222ee29fefe306b3a286e97d08a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">세차기 세척기</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경남 창원시 의창구 북면
#       </div>
# <div class="card-counts">
# <span>
#             관심 14
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="581016803" href="/articles/581016803">
# <div class="card-photo">
# <img alt="자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/5f0deffb2bd042d27c63d8ea880eae28d6f888b934de03f1458c737b94b1b790.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         인천 미추홀구 관교동
#       </div>
# <div class="card-counts">
# <span>
#             관심 25
#           </span>
#         ∙
#         <span>
#             채팅 32
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580907341" href="/articles/580907341">
# <div class="card-photo">
# <img alt="삼성제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/d23d20a7e4e413d282ae4d4a95cd0046e8f0316ae47b10ff83100e56ff72e746_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼성제습기</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         인천 연수구 송도동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="579568759" href="/articles/579568759">
# <div class="card-photo">
# <img alt="베베드피노 키즈 올오버 베들링턴 BP31PH315 세트 100 110 120 130" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/09f56634131c971bdd963852bddcf490ed3cb6e0d3e5ee9aca4e3abbc5197385.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">베베드피노 키즈 올오버 베들링턴 BP31PH315 세트 100 110 120 130</h2>
# <div class="card-price">
#         42,000원
#       </div>
# <div class="card-region-name">
#         경기도 김포시 고촌읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 28
#           </span>
#         ∙
#         <span>
#             채팅 56
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="581053384" href="/articles/581053384">
# <div class="card-photo">
# <img alt="중고컨테이너 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/069d72217fac82cf6ec66d1dc25e3c80068626b640452539f242d0c71ae6ddfd_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">중고컨테이너 판매</h2>
# <div class="card-price">
#         150만원
#       </div>
# <div class="card-region-name">
#         전남 영암군 삼호읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 7
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="581059266" href="/articles/581059266">
# <div class="card-photo">
# <img alt="커피믹스" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/896e09db56e9506d021a062a94678f48e96e32205cf89043668da89cae2f2846_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">커피믹스</h2>
# <div class="card-price">
#         9,000원
#       </div>
# <div class="card-region-name">
#         울산 북구 중산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="581061200" href="/articles/581061200">
# <div class="card-photo">
# <img alt="수납함 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/aa219e276f737965edc0027d84e4af7cedbb91ec9976e00a2b2b25660962c09a.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">수납함 팝니다</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경북 포항시 북구 창포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 5
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="578148642" href="/articles/578148642">
# <div class="card-photo">
# <img alt="트레일러 팝니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/7460bbe5fa854a8684c7e3f4cc0feec0246632bf30a22afcb5c85de1af6fbdf4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">트레일러 팝니다.</h2>
# <div class="card-price">
#         200,000원
#       </div>
# <div class="card-region-name">
#         경기도 남양주시 별내동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580756769" href="/articles/580756769">
# <div class="card-photo">
# <img alt="모니터 새거 팔어요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/066b666cf681dc9325360c19d8c09d51403947edaac9e6a6ff5405914641a75f.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">모니터 새거 팔어요</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 시흥시 정왕동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 4
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="578156718" href="/articles/578156718">
# <div class="card-photo">
# <img alt="노비타 6리터 가성비 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/50cd582ad22784529deef1b60087888276f67cf7bb747c8aa2df7fabd31da099_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">노비타 6리터 가성비 제습기</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         경기도 양주시 고읍동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580605666" href="/articles/580605666">
# <div class="card-photo">
# <img alt="갤럭시버즈 판매(버즈2 pro)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/0f8cda4db454e7eec3f8357e9393903ded10ed1ebd39ec6a1eb75771a0c28c0e_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">갤럭시버즈 판매(버즈2 pro)</h2>
# <div class="card-price">
#         70,000원
#       </div>
# <div class="card-region-name">
#         대전 서구 월평2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 26
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580669065" href="/articles/580669065">
# <div class="card-photo">
# <img alt="자전거 3만원" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/99599caaae3e3d6ed9a2fa37f9490584f9e5cbf3203fafee4d726e9a4a3303d9.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 3만원</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 양재2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 6
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580940307" href="/articles/580940307">
# <div class="card-photo">
# <img alt="포르쉐 푸쉬카 판매합니다. (제일 먼저 챗주신분께 예약잡았습니다)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/28750b48167a543589a90880613ade2e5525ed784bc2f46ed9933b0db8f3546b_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포르쉐 푸쉬카 판매합니다. (제일 먼저 챗주신분께 예약잡았습니다)</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 김포시 장기본동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="579828761" href="/articles/579828761">
# <div class="card-photo">
# <img alt="아이폰11pro팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/706291aea642dd9d58f6acb87f8561ef6b24bf3b5a79128a131793fbab382d6d.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰11pro팝니다</h2>
# <div class="card-price">
#         200,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 향남읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 44
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="581078442" href="/articles/581078442">
# <div class="card-photo">
# <img alt="아우디 푸쉬카" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/d6c63ad1ca87e3f7dfa34ad9414a870cc00a91bb296293294ca27366cfdad4b6_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아우디 푸쉬카</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         서울 동작구 신대방동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="581083056" href="/articles/581083056">
# <div class="card-photo">
# <img alt="놀라운자연" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/ff8a1a77f2a448b4cedcc2854947d247ae7ebda33a4de8cbabdf588c89ae7818.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">놀라운자연</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         서울 강서구 가양제3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580851527" href="/articles/580851527">
# <div class="card-photo">
# <img alt="대우냉장고 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/d2e384005ede792c6748821a9ccedf59e6f031e94b007de17fca4234abb20346.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">대우냉장고 판매</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         서울 동대문구 장안동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580827638" href="/articles/580827638">
# <div class="card-photo">
# <img alt="수납장 선반 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/e9d07efc5aba9e6ced920559be69e4134e064cbea99bcd1bed969691468a9293.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">수납장 선반 팝니다</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         부산 동래구 안락동
#       </div>
# <div class="card-counts">
# <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="579989085" href="/articles/579989085">
# <div class="card-photo">
# <img alt="냉장고 상태 양호 가져가실분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/bddb9d17a95a7a2ae328e7aa67d9370679362d2ad849883461fe1ed2ce15a789.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">냉장고 상태 양호 가져가실분</h2>
# <div class="card-price">
#         55,000원
#       </div>
# <div class="card-region-name">
#         인천 남동구 논현동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="578467362" href="/articles/578467362">
# <div class="card-photo">
# <img alt="수납장 책상 조명 등등 각각 5천원에 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/4aca8c72939efb4ce3e95a7bf3616d199ceb63b83171d5ab480564afd795b200.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">수납장 책상 조명 등등 각각 5천원에 팝니다</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경기도 부천시 심곡동
#       </div>
# <div class="card-counts">
# <span>
#             관심 41
#           </span>
#         ∙
#         <span>
#             채팅 39
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="579875601" href="/articles/579875601">
# <div class="card-photo">
# <img alt="이사 물품 처리합니다!!(협탁, 실내자전거)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/9bdbd4c92da095245d2cb10425f8d1d90ce2a6a8e2e958532c649e57e8608e08.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">이사 물품 처리합니다!!(협탁, 실내자전거)</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         강원도 춘천시 후평동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580640950" href="/articles/580640950">
# <div class="card-photo">
# <img alt="위닉스제습기 16리터" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/09ff21eecf5a1ba65d24cb25025325f8e2fe1e97310f73fb63ee6c8e4a569b8b_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스제습기 16리터</h2>
# <div class="card-price">
#         120,000원
#       </div>
# <div class="card-region-name">
#         경기도 하남시 망월동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 23
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580933592" href="/articles/580933592">
# <div class="card-photo">
# <img alt="야외 테이블의자" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/b8c1f64476408d0ac8cf16247e5a0aca72971601baabaf0890ad9de6016e6a9a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">야외 테이블의자</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         경기도 파주시 야당동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 8
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580701872" href="/articles/580701872">
# <div class="card-photo">
# <img alt="스트라이더 밸런스 바이크 블랙" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/138808c34357658379cf0eeb2f6221f1ad8994094d8d4601e32c18044332a856_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스트라이더 밸런스 바이크 블랙</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경기도 수원시 영통구 망포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580686509" href="/articles/580686509">
# <div class="card-photo">
# <img alt="앵글 선반 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/216098ab5c60c86225d2df7c327d942617ff6a22a9555b80e1366b5f56ccc006.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">앵글 선반 팝니다</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         대구 남구 대명4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="581051671" href="/articles/581051671">
# <div class="card-photo">
# <img alt="스팸" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/6865a963f45b5d041de5d4662fff21c9d12dcb260b8ee1ca517314da7e638191_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경기도 안양시 동안구 호계1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="581025915" href="/articles/581025915">
# <div class="card-photo">
# <img alt="티티카카 접이식자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/e14711b0b0a38aefa731e56d95748751e5f2fbef9b3ef72bf93e4a90f3a0a9d3_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">티티카카 접이식자전거</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         인천 부평구 삼산2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 8
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580827570" href="/articles/580827570">
# <div class="card-photo">
# <img alt="이사가서 내놓습니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/ba74019d2078edea0af05f43a0c3269004d54a9f085818a7be8330e309fef46f_0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">이사가서 내놓습니다.</h2>
# <div class="card-price">
#         1,000원
#       </div>
# <div class="card-region-name">
#         인천 미추홀구 도화동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="580951873" href="/articles/580951873">
# <div class="card-photo">
# <img alt="에어팟 프로 급처 합니다 !" src="https://dnvefa72aowie.cloudfront.net/origin/article/202305/fe9c8bf219c00fa850d43b22e9856d6d84f47c15b692f93f434e279011cd64dc.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">에어팟 프로 급처 합니다 !</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         대전 대덕구 중리동
#       </div>
# <div class="card-counts">
# <span>
#             관심 16
#           </span>
#         ∙
#         <span>
#             채팅 42
#           </span>
# </div>
# </div>
# </a></article>
# ...
# `+wo+e}var xo=!1;function ko(e,t){if(!e||xo)return"";xo=!0;var n=Error.prepareStackTrace;Error.prepareStackTrace=void 0;try{if(t)if(t=function(){throw Error()},Object.defineProperty(t.prototype,"props",{set:function(){throw Error()}}),typeof Reflect=="object"&&Reflect.construct){try{Reflect.construct(t,[])}catch(a){var r=a}Reflect.construct(e,[],t)}else{try{t.call()}catch(a){r=a}e.call(t.prototype)}else{try{throw Error()}catch(a){r=a}e()}}catch(a){if(a&&r&&typeof a.stack=="string"){for(var l=a.stack.split(`
# `),o=r.stack.split(`
# `),i=l.length-1,u=o.length-1;1<=i&&0<=u&&l[i]!==o[u];)u--;for(;1<=i&&0<=u;i--,u--)if(l[i]!==o[u]){if(i!==1||u!==1)do if(i--,u--,0>u||l[i]!==o[u]){var s=`
# `+l[i].replace(" at new "," at ");return e.displayName&&s.includes("<anonymous>")&&(s=s.replace("<anonymous>",e.displayName)),s}while(1<=i&&0<=u);break}}}finally{xo=!1,Error.prepareStackTrace=n}return(e=e?e.displayName||e.name:"")?Tn(e):""}function Vf(e){switch(e.tag){case 5:return Tn(e.type);case 16:return Tn("Lazy");case 13:return Tn("Suspense");case 19:return Tn("SuspenseList");case 0:case 2:case 15:return e=ko(e.type,!1),e;case 11:return e=ko(e.type.render,!1),e;case 1:return e=ko(e.type,!0),e;default:return""}}function qo(e){if(e==null)return null;if(typeof e=="function")return e.displayName||e.name||null;if(typeof e=="string")return e;switch(e){case Bt:return"Fragment";case At:return"Portal";case $o:return"Profiler";case Ii:return"StrictMode";case Zo:return"Suspense";case Wo:return"SuspenseList"}if(typeof e=="object")switch(e.$$typeof){case Fa:return(e.displayName||"Context")+".Consumer";case ja:return(e._context.displayName||"Context")+".Provider";case Vi:var t=e.render;return e=e.displayName,e||(e=t.displayName||t.name||"",e=e!==""?"ForwardRef("+e+")":"ForwardRef"),e;case ji:return t=e.displayName||null,t!==null?t:qo(e.type)||"Memo";case et:t=e._payload,e=e._init;try{return qo(e(t))}catch(n){}}return null}function jf(e){var t=e.type;switch(e.tag){case 24:return"Cache";case 9:return(t.displayName||"Context")+".Consumer";case 10:return(t._context.displayName||"Context")+".Provider";case 18:return"DehydratedFragment";case 11:return e=t.render,e=e.displayName||e.name||"",t.displayName||(e!==""?"ForwardRef("+e+")":"ForwardRef");case 7:return"Fragment";case 5:return t;case 4:return"Portal";case 3:return"Root";case 6:return"Text";case 16:return qo(t);case 8:return t===Ii?"StrictMode":"Mode";case 22:return"Offscreen";case 12:return"Profiler";case 21:return"Scope";case 13:return"Suspense";case 19:return"SuspenseList";case 25:return"TracingMarker";case 1:case 0:case 17:case 2:case 14:case 15:if(typeof t=="function")return t.displayName||t.name||null;if(typeof t=="string")return t}return null}function dt(e){switch(typeof e){case"boolean":case"number":case"string":case"undefined":return e;case"object":return e;default:return""}}function Aa(e){var t=e.type;return(e=e.nodeName)&&e.toLowerCase()==="input"&&(t==="checkbox"||t==="radio")}function Ff(e){var t=Aa(e)?"checked":"value",n=Object.getOwnPropertyDescriptor(e.constructor.prototype,t),r=""+e[t];if(!e.hasOwnProperty(t)&&typeof n!="undefined"&&typeof n.get=="function"&&typeof n.set=="function"){var l=n.get,o=n.set;return Object.defineProperty(e,t,{configurable:!0,get:function(){return l.call(this)},set:function(i){r=""+i,o.call(this,i)}}),Object.defineProperty(e,t,{enumerable:n.enumerable}),{getValue:function(){return r},setValue:function(i){r=""+i},stopTracking:function(){e._valueTracker=null,delete e[t]}}}}function Dr(e){e._valueTracker||(e._valueTracker=Ff(e))}function Ba(e){if(!e)return!1;var t=e._valueTracker;if(!t)return!0;var n=t.getValue(),r="";return e&&(r=Aa(e)?e.checked?"true":"false":e.value),e=r,e!==n?(t.setValue(e),!0):!1}function cl(e){if(e=e||(typeof document!="undefined"?document:void 0),typeof e=="undefined")return null;try{return e.activeElement||e.body}catch(t){return e.body}}function Qo(e,t){var n=t.checked;return B({},t,{defaultChecked:void 0,defaultValue:void 0,value:void 0,checked:n!=null?n:e._wrapperState.initialChecked})}function Rs(e,t){var n=t.defaultValue==null?"":t.defaultValue,r=t.checked!=null?t.checked:t.defaultChecked;n=dt(t.value!=null?t.value:n),e._wrapperState={initialChecked:r,initialValue:n,controlled:t.type==="checkbox"||t.type==="radio"?t.checked!=null:t.value!=null}}function Ua(e,t){t=t.checked,t!=null&&Di(e,"checked",t,!1)}function Ko(e,t){Ua(e,t);var n=dt(t.value),r=t.type;if(n!=null)r==="number"?(n===0&&e.value===""||e.value!=n)&&(e.value=""+n):e.value!==""+n&&(e.value=""+n);else if(r==="submit"||r==="reset"){e.removeAttribute("value");return}t.hasOwnProperty("value")?Go(e,t.type,n):t.hasOwnProperty("defaultValue")&&Go(e,t.type,dt(t.def ...
# `).replace(q0,"")}function qr(e,t,n){if(t=ta(t),ta(e)!==t&&n)throw Error(v(425))}function gl(){}var ai=null;function ci(e,t){return e==="textarea"||e==="noscript"||typeof t.children=="string"||typeof t.children=="number"||typeof t.dangerouslySetInnerHTML=="object"&&t.dangerouslySetInnerHTML!==null&&t.dangerouslySetInnerHTML.__html!=null}var fi=typeof setTimeout=="function"?setTimeout:void 0,Q0=typeof clearTimeout=="function"?clearTimeout:void 0,na=typeof Promise=="function"?Promise:void 0,K0=typeof queueMicrotask=="function"?queueMicrotask:typeof na!="undefined"?function(e){return na.resolve(null).then(e).catch(G0)}:fi;function G0(e){setTimeout(function(){throw e})}function zo(e,t){var n=t,r=0;do{var l=n.nextSibling;if(e.removeChild(n),l&&l.nodeType===8)if(n=l.data,n==="/$"){if(r===0){e.removeChild(l),Kn(t);return}r--}else n!=="$"&&n!=="$?"&&n!=="$!"||r++;n=l}while(n);Kn(t)}function Be(e){for(;e!=null;e=e.nextSibling){var t=e.nodeType;if(t===1||t===3)break;if(t===8){if(t=e.data,t==="$"||t==="$!"||t==="$?")break;if(t==="/$")return null}}return e}function ra(e){e=e.previousSibling;for(var t=0;e;){if(e.nodeType===8){var n=e.data;if(n==="$"||n==="$!"||n==="$?"){if(t===0)return e;t--}else n==="/$"&&t++}e=e.previousSibling}return null}var pn=Math.random().toString(36).slice(2),Oe="__reactFiber$"+pn,bn="__reactProps$"+pn,qe="__reactContainer$"+pn,di="__reactEvents$"+pn,Y0="__reactListeners$"+pn,X0="__reactHandles$"+pn;function wt(e){var t=e[Oe];if(t)return t;for(var n=e.parentNode;n;){if(t=n[qe]||n[Oe]){if(n=t.alternate,t.child!==null||n!==null&&n.child!==null)for(e=ra(e);e!==null;){if(n=e[Oe])return n;e=ra(e)}return t}e=n,n=e.parentNode}return null}function ar(e){return e=e[Oe]||e[qe],!e||e.tag!==5&&e.tag!==6&&e.tag!==13&&e.tag!==3?null:e}function Wt(e){if(e.tag===5||e.tag===6)return e.stateNode;throw Error(v(33))}function Hl(e){return e[bn]||null}var pi=[],qt=-1;function vt(e){return{current:e}}function F(e){0>qt||(e.current=pi[qt],pi[qt]=null,qt--)}function I(e,t){qt++,pi[qt]=e.current,e.current=t}var pt={},te=vt(pt),ae=vt(!1),Pt=pt;function ln(e,t){var n=e.type.contextTypes;if(!n)return pt;var r=e.stateNode;if(r&&r.__reactInternalMemoizedUnmaskedChildContext===t)return r.__reactInternalMemoizedMaskedChildContext;var l={},o;for(o in n)l[o]=t[o];return r&&(e=e.stateNode,e.__reactInternalMemoizedUnmaskedChildContext=t,e.__reactInternalMemoizedMaskedChildContext=l),l}function ce(e){return e=e.childContextTypes,e!=null}function yl(){F(ae),F(te)}function la(e,t,n){if(te.current!==pt)throw Error(v(168));I(te,t),I(ae,n)}function M1(e,t,n){var r=e.stateNode;if(t=t.childContextTypes,typeof r.getChildContext!="function")return n;r=r.getChildContext();for(var l in r)if(!(l in t))throw Error(v(108,jf(e)||"Unknown",l));return B({},n,r)}function Cl(e){return e=(e=e.stateNode)&&e.__reactInternalMemoizedMergedChildContext||pt,Pt=te.current,I(te,e),I(ae,ae.current),!0}function oa(e,t,n){var r=e.stateNode;if(!r)throw Error(v(169));n?(e=M1(e,t,Pt),r.__reactInternalMemoizedMergedChildContext=e,F(ae),F(te),I(te,e)):F(ae),I(ae,n)}var Ae=null,Al=!1,Do=!1;function R1(e){Ae===null?Ae=[e]:Ae.push(e)}function J0(e){Al=!0,R1(e)}function gt(){if(!Do&&Ae!==null){Do=!0;var e=0,t=O;try{var n=Ae;for(O=1;e<n.length;e++){var r=n[e];do r=r(!0);while(r!==null)}Ae=null,Al=!1}catch(l){throw Ae!==null&&(Ae=Ae.slice(e+1)),n1(Hi,gt),l}finally{O=t,Do=!1}}return null}var b0=Ke.ReactCurrentBatchConfig;function Le(e,t){if(e&&e.defaultProps){t=B({},t),e=e.defaultProps;for(var n in e)t[n]===void 0&&(t[n]=e[n]);return t}return t}var El=vt(null),wl=null,Qt=null,Ki=null;function Gi(){Ki=Qt=wl=null}function Yi(e){var t=El.current;F(El),e._currentValue=t}function mi(e,t,n){for(;e!==null;){var r=e.alternate;if((e.childLanes&t)!==t?(e.childLanes|=t,r!==null&&(r.childLanes|=t)):r!==null&&(r.childLanes&t)!==t&&(r.childLanes|=t),e===n)break;e=e.return}}function tn(e,t){wl=e,Ki=Qt=null,e=e.dependencies,e!==null&&e.firstContext!==null&&((e.lanes&t)!==0&&(pe=!0),e.firstContext=null)}functio ...
# Error generating stack: `+o.message+`
# `+o.stack}return{value:e,source:t,stack:l}}function Ci(e,t){try{console.error(t.value)}catch(n){setTimeout(function(){throw n})}}var ud=typeof WeakMap=="function"?WeakMap:Map;function rc(e,t,n){n=Ze(-1,n),n.tag=3,n.payload={element:null};var r=t.value;return n.callback=function(){Rl||(Rl=!0,Li=r),Ci(e,t)},n}function lc(e,t,n){n=Ze(-1,n),n.tag=3;var r=e.type.getDerivedStateFromError;if(typeof r=="function"){var l=t.value;n.payload=function(){return r(l)},n.callback=function(){Ci(e,t)}}var o=e.stateNode;return o!==null&&typeof o.componentDidCatch=="function"&&(n.callback=function(){Ci(e,t),typeof r!="function"&&(ct===null?ct=new Set([this]):ct.add(this));var i=t.stack;this.componentDidCatch(t.value,{componentStack:i!==null?i:""})}),n}function pa(e,t,n){var r=e.pingCache;if(r===null){r=e.pingCache=new ud;var l=new Set;r.set(t,l)}else l=r.get(t),l===void 0&&(l=new Set,r.set(t,l));l.has(n)||(l.add(n),e=wd.bind(null,e,t,n),t.then(e,e))}function ma(e){do{var t;if((t=e.tag===13)&&(t=e.memoizedState,t=t!==null?t.dehydrated!==null:!0),t)return e;e=e.return}while(e!==null);return null}function ha(e,t,n,r,l){return(e.mode&1)===0?(e===t?e.flags|=65536:(e.flags|=128,n.flags|=131072,n.flags&=-52805,n.tag===1&&(n.alternate===null?n.tag=17:(t=Ze(-1,1),t.tag=2,at(n,t))),n.lanes|=1),e):(e.flags|=65536,e.lanes=l,e)}var oc,Ei,ic,uc;oc=function(e,t){for(var n=t.child;n!==null;){if(n.tag===5||n.tag===6)e.appendChild(n.stateNode);else if(n.tag!==4&&n.child!==null){n.child.return=n,n=n.child;continue}if(n===t)break;for(;n.sibling===null;){if(n.return===null||n.return===t)return;n=n.return}n.sibling.return=n.return,n=n.sibling}};Ei=function(){};ic=function(e,t,n,r){var l=e.memoizedProps;if(l!==r){e=t.stateNode,xt(Ie.current);var o=null;switch(n){case"input":l=Qo(e,l),r=Qo(e,r),o=[];break;case"select":l=B({},l,{value:void 0}),r=B({},r,{value:void 0}),o=[];break;case"textarea":l=Yo(e,l),r=Yo(e,r),o=[];break;default:typeof l.onClick!="function"&&typeof r.onClick=="function"&&(e.onclick=gl)}Jo(n,r);var i;n=null;for(a in l)if(!r.hasOwnProperty(a)&&l.hasOwnProperty(a)&&l[a]!=null)if(a==="style"){var u=l[a];for(i in u)u.hasOwnProperty(i)&&(n||(n={}),n[i]="")}else a!=="dangerouslySetInnerHTML"&&a!=="children"&&a!=="suppressContentEditableWarning"&&a!=="suppressHydrationWarning"&&a!=="autoFocus"&&($n.hasOwnProperty(a)?o||(o=[]):(o=o||[]).push(a,null));for(a in r){var s=r[a];if(u=l!=null?l[a]:void 0,r.hasOwnProperty(a)&&s!==u&&(s!=null||u!=null))if(a==="style")if(u){for(i in u)!u.hasOwnProperty(i)||s&&s.hasOwnProperty(i)||(n||(n={}),n[i]="");for(i in s)s.hasOwnProperty(i)&&u[i]!==s[i]&&(n||(n={}),n[i]=s[i])}else n||(o||(o=[]),o.push(a,n)),n=s;else a==="dangerouslySetInnerHTML"?(s=s?s.__html:void 0,u=u?u.__html:void 0,s!=null&&u!==s&&(o=o||[]).push(a,s)):a==="children"?typeof s!="string"&&typeof s!="number"||(o=o||[]).push(a,""+s):a!=="suppressContentEditableWarning"&&a!=="suppressHydrationWarning"&&($n.hasOwnProperty(a)?(s!=null&&a==="onScroll"&&j("scroll",e),o||u===s||(o=[])):(o=o||[]).push(a,s))}n&&(o=o||[]).push("style",n);var a=o;(t.updateQueue=a)&&(t.flags|=4)}};uc=function(e,t,n,r){n!==r&&(t.flags|=4)};function Ln(e,t){if(!H)switch(e.tailMode){case"hidden":t=e.tail;for(var n=null;t!==null;)t.alternate!==null&&(n=t),t=t.sibling;n===null?e.tail=null:n.sibling=null;break;case"collapsed":n=e.tail;for(var r=null;n!==null;)n.alternate!==null&&(r=n),n=n.sibling;r===null?t||e.tail===null?e.tail=null:e.tail.sibling=null:r.sibling=null}}function b(e){var t=e.alternate!==null&&e.alternate.child===e.child,n=0,r=0;if(t)for(var l=e.child;l!==null;)n|=l.lanes|l.childLanes,r|=l.subtreeFlags&14680064,r|=l.flags&14680064,l.return=e,l=l.sibling;else for(l=e.child;l!==null;)n|=l.lanes|l.childLanes,r|=l.subtreeFlags,r|=l.flags,l.return=e,l=l.sibling;return e.subtreeFlags|=r,e.childLanes=n,t}function sd(e,t,n){var r=t.pendingProps;switch(bi(t),t.tag){case 2:case 16:case 15:case 0:case 11:case 7:case 8:case 12:case 9:case 14:return b(t),null;case 1:return ce(t.type)&&yl(),b(t),n ...
# /**
#  * @license React
#  * react-dom.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
# /**
#  * @license React
#  * react-jsx-runtime.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
# /**
#  * @license React
#  * react.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
# /**
#  * @license React
#  * scheduler.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
#
# </script>
# </body>
# </html>

# %% [markdown]
# - BS : find_all() : 원하는 부분을 모두 가져올 때 사용

# %%
# find_all() 해당 태그를 모두 가져온다.
# list형식으로 가져온다.

soup.find_all('h1')
print()
print('type - ' , type(soup.find_all('h2')))
display(soup.find_all('h2'))
print()

for h in soup.find_all('h2') :
    print(h.string)
# Out:
# type -  <class 'bs4.element.ResultSet'>
# [<h2 class="card-title">아이폰13</h2>,
#  <h2 class="card-title">코카콜라 미니 냉장고 판매</h2>,
#  <h2 class="card-title">전화주세요 01048506787</h2>,
#  <h2 class="card-title">농약분무기 가져가세요</h2>,
#  <h2 class="card-title">아이폰 팔아요</h2>,
#  <h2 class="card-title">나이키 운동화 새제품</h2>,
#  <h2 class="card-title">크록스 260</h2>,
#  <h2 class="card-title">중고 컨테이너 3*6 판매 합니다 / 급처분</h2>,
#  <h2 class="card-title">세차기 세척기</h2>,
#  <h2 class="card-title">자전거</h2>,
#  <h2 class="card-title">삼성제습기</h2>,
#  <h2 class="card-title">베베드피노 키즈 올오버 베들링턴 BP31PH315 세트 100 110 120 130</h2>,
#  <h2 class="card-title">중고컨테이너 판매</h2>,
#  <h2 class="card-title">커피믹스</h2>,
#  <h2 class="card-title">수납함 팝니다</h2>,
#  <h2 class="card-title">트레일러 팝니다.</h2>,
#  <h2 class="card-title">모니터 새거 팔어요</h2>,
#  <h2 class="card-title">노비타 6리터 가성비 제습기</h2>,
#  <h2 class="card-title">갤럭시버즈 판매(버즈2 pro)</h2>,
#  <h2 class="card-title">자전거 3만원</h2>,
#  <h2 class="card-title">포르쉐 푸쉬카 판매합니다. (제일 먼저 챗주신분께 예약잡았습니다)</h2>,
#  <h2 class="card-title">아이폰11pro팝니다</h2>,
#  <h2 class="card-title">아우디 푸쉬카</h2>,
#  <h2 class="card-title">놀라운자연</h2>,
#  <h2 class="card-title">대우냉장고 판매</h2>,
#  <h2 class="card-title">수납장 선반 팝니다</h2>,
#  <h2 class="card-title">냉장고 상태 양호 가져가실분</h2>,
#  <h2 class="card-title">수납장 책상 조명 등등 각각 5천원에 팝니다</h2>,
#  <h2 class="card-title">이사 물품 처리합니다!!(협탁, 실내자전거)</h2>,
#  <h2 class="card-title">위닉스제습기 16리터</h2>,
#  <h2 class="card-title">야외 테이블의자</h2>,
#  <h2 class="card-title">스트라이더 밸런스 바이크 블랙</h2>,
#  <h2 class="card-title">앵글 선반 팝니다</h2>,
#  <h2 class="card-title">스팸</h2>,
#  <h2 class="card-title">티티카카 접이식자전거</h2>,
#  <h2 class="card-title">이사가서 내놓습니다.</h2>,
#  <h2 class="card-title">에어팟 프로 급처 합니다 !</h2>,
#  <h2 class="card-title">세탁기&amp;냉장고 판매합니다.</h2>,
#  <h2 class="card-title">벽걸이 에어컨) 팝니다</h2>,
#  <h2 class="card-title">예초기 팝니다</h2>,
#  <h2 class="card-title">[여름대비] 위니아 제습기 11리터  20년 출시제품</h2>,
#  <h2 class="card-title">전기톱 마끼다</h2>,
#  <h2 class="card-title">진짜 급해요 사례금 드립니다</h2>,
#  <h2 class="card-title">삼성 제습기</h2>,
#  <h2 class="card-title">벽걸이 에어컨 판매</h2>,
#  <h2 class="card-title">마샬 액톤2 블랙</h2>,
#  <h2 class="card-title">구찌가방</h2>,
#  <h2 class="card-title">텐트 처분</h2>,
#  <h2 class="card-title">위니아제습기</h2>,
#  <h2 class="card-title">다 가져가세요</h2>,
#  <h2 class="card-title">10년 된 컴퓨터 판매합니다.</h2>,
#  <h2 class="card-title">위니아제습기 이사로싸게내놓아요</h2>,
#  <h2 class="card-title">스트라이더 밸런스 바이크 12인치 판매합니다!</h2>,
#  <h2 class="card-title">제습기 판매합니다.</h2>,
#  <h2 class="card-title">우유 떨이합니다 5,000원 (유통기한 15일까지)</h2>,
#  <h2 class="card-title">샤넬 카드지갑 떨이</h2>,
#  <h2 class="card-title">다이슨 싸이클론 V10무선청소기</h2>,
#  <h2 class="card-title">선반</h2>,
#  <h2 class="card-title">100원이예요~~</h2>,
#  <h2 class="card-title">베이비젠 요요6+ (에어프랑스 컬러팩 추가)</h2>,
#  <h2 class="card-title">레노버 새거 팝니다</h2>,
#  <h2 class="card-title">65인치 LED TV 팝니다^^</h2>,
#  <h2 class="card-title">위니아 제습기</h2>,
#  <h2 class="card-title">LG 건조기</h2>,
#  <h2 class="card-title">BMW 골프백</h2>,
#  <h2 class="card-title">가구</h2>,
#  <h2 class="card-title">(급처)부산 해운대 반월풀빌라(신상숙소)</h2>,
#  <h2 class="card-title">LG 코드제로9 청소기 팝니다.</h2>,
#  <h2 class="card-title">삼성 겔러리 무풍 2in1 에어컨 판매합니다</h2>,
#  <h2 class="card-title">게이밍 컴퓨터 데스크탑</h2>,
#  <h2 class="card-title">루이비통 몽테뉴</h2>,
#  <h2 class="card-title">144hz 무결점 게이밍 모니터 +모니터암 팝니다.</h2>,
#  <h2 class="card-title">제습기 10L</h2>,
#  <h2 class="card-title">꽃잔디 소분해 드립니다.(무료)</h2>,
#  <h2 class="card-title">전자렌지</h2>,
#  <h2 class="card-title">캐리어 염가판매</h2>,
#  <h2 class="card-title">편백</h2>,
#  <h2 class="card-title">나이키</h2>,
#  <h2 class="card-title">DEWALT 충전드릴</h2>,
#  <h2 class="card-title">쌀</h2>,
#  <h2 class="card-title">새상품라코스테 반팔티</h2>,
#  <h2 class="card-title">베트남 동 팔아요</h2>,
#  <h2 class="card-title">LG TV 45인치</h2>,
#  <h2 class="card-title">프라다 가방</h2>,
#  <h2 class="card-title">도레미곰 전집 50권</h2>,
#  <h2 class="card-title">미니 pc 부품용팝니다</h2>,
#  <h2 class="card-title">코웨이  제습기</h2>,
#  <h2 class="card-title">맥북프로 팝니다</h2>,
#  <h2 class="card-title">나이키 신발</h2>,
#  <h2 class="card-title">칼</h2>,
#  <h2 class="card-title">초등학생자전거</h2>,
#  <h2 class="card-title">고구마 3kg  가져가실분</h2>,
#  <h2 class="card-title">금반지</h2>,
#  <h2 class="card-title">루이비통 정품가방</h2>,
#  <h2 class="card-title">갤럭시노트20 팝니다.</h2>,
#  <h2 class="card-title">농약 분무기</h2>,
#  <h2 class="card-title">아이패드 프로 5세대 12.9 + 애플펜슬 2세대 판매</h2>]
# 아이폰13
# 코카콜라 미니 냉장고 판매
# 전화주세요 01048506787
# 농약분무기 가져가세요
# 아이폰 팔아요
# 나이키 운동화 새제품
# 크록스 260
# 중고 컨테이너 3*6 판매 합니다 / 급처분
# 세차기 세척기
# 자전거
# 삼성제습기
# 베베드피노 키즈 올오버 베들링턴 BP31PH315 세트 100 110 120 130
# 중고컨테이너 판매
# 커피믹스
# 수납함 팝니다
# 트레일러 팝니다.
# 모니터 새거 팔어요
# 노비타 6리터 가성비 제습기
# 갤럭시버즈 판매(버즈2 pro)
# 자전거 3만원
# 포르쉐 푸쉬카 판매합니다. (제일 먼저 챗주신분께 예약잡았습니다)
# 아이폰11pro팝니다
# 아우디 푸쉬카
# 놀라운자연
# 대우냉장고 판매
# 수납장 선반 팝니다
# 냉장고 상태 양호 가져가실분
# 수납장 책상 조명 등등 각각 5천원에 팝니다
# 이사 물품 처리합니다!!(협탁, 실내자전거)
# 위닉스제습기 16리터
# 야외 테이블의자
# 스트라이더 밸런스 바이크 블랙
# 앵글 선반 팝니다
# 스팸
# 티티카카 접이식자전거
# 이사가서 내놓습니다.
# 에어팟 프로 급처 합니다 !
# 세탁기&냉장고 판매합니다.
# 벽걸이 에어컨) 팝니다
# 예초기 팝니다
# [여름대비] 위니아 제습기 11리터  20년 출시제품
# 전기톱 마끼다
# 진짜 급해요 사례금 드립니다
# 삼성 제습기
# 벽걸이 에어컨 판매
# 마샬 액톤2 블랙
# 구찌가방
# 텐트 처분
# 위니아제습기
# 다 가져가세요
# 10년 된 컴퓨터 판매합니다.
# 위니아제습기 이사로싸게내놓아요
# 스트라이더 밸런스 바이크 12인치 판매합니다!
# 제습기 판매합니다.
# 우유 떨이합니다 5,000원 (유통기한 15일까지)
# 샤넬 카드지갑 떨이
# 다이슨 싸이클론 V10무선청소기
# 선반
# 100원이예요~~
# 베이비젠 요요6+ (에어프랑스 컬러팩 추가)
# 레노버 새거 팝니다
# 65인치 LED TV 팝니다^^
# 위니아 제습기
# LG 건조기
# BMW 골프백
# 가구
# (급처)부산 해운대 반월풀빌라(신상숙소)
# LG 코드제로9 청소기 팝니다.
# 삼성 겔러리 무풍 2in1 에어컨 판매합니다
# 게이밍 컴퓨터 데스크탑
# 루이비통 몽테뉴
# 144hz 무결점 게이밍 모니터 +모니터암 팝니다.
# 제습기 10L
# 꽃잔디 소분해 드립니다.(무료)
# 전자렌지
# 캐리어 염가판매
# 편백
# 나이키
# DEWALT 충전드릴
# 쌀
# 새상품라코스테 반팔티
# 베트남 동 팔아요
# LG TV 45인치
# 프라다 가방
# 도레미곰 전집 50권
# 미니 pc 부품용팝니다
# 코웨이  제습기
# 맥북프로 팝니다
# 나이키 신발
# 칼
# 초등학생자전거
# 고구마 3kg  가져가실분
# 금반지
# 루이비통 정품가방
# 갤럭시노트20 팝니다.
# 농약 분무기
# 아이패드 프로 5세대 12.9 + 애플펜슬 2세대 판매

# %% [markdown]
# - 정규표현식(re)
# - 메타문자 : 문자가 가진 뜻이 아닌 특별한 용도로 사용하는 문자
# - ex ) - . $ ? * \ [] () 등
# - 문자 클래스 [문자들과 매치] ex) 알파벳 모두 [a-zA-Z]
# - 문자 클래스 [^문자] : not ex) 숫자를 제외 [^0-9]

# %% [markdown]
# - \d - 숫자와 매치, [0-9]와 동일한 표현식이다.
# - \D - 숫자가 아닌 것과 매치, [^0-9]와 동일한 표현식이다.
# - \s - whitespace 문자와 매치, [ \t\n\r\f\v]와 동일한 표현식이다. 맨 앞의 빈 칸은 공백문자(space)를 의미한다.
# - \S - whitespace 문자가 아닌 것과 매치, [^ \t\n\r\f\v]와 동일한 표현식이다.
# - \w - 문자+숫자(alphanumeric)와 매치, [a-zA-Z0-9_]와 동일한 표현식이다.
# - \W - 문자+숫자(alphanumeric)가 아닌 문자와 매치, [^a-zA-Z0-9_]와 동일한 표현식이다.

# %% [markdown]
# - Dot(.)  : \n을 제외한 모든 문자와 매치됨을 의미 ex) a.b ( a + 모든 문자 + b)
# - 반복 *  : 무한대로 반복  ex ) ca * t 바로 앞의 a 가 0~무한 반복
# - 반복 +  : 무한대로 반복 1 ~ 무한 반복
# - 반복 {} : 횟수제한 ca{2}t == caat , {2,5}
# - 있어도 되고 없어도 된다 - 필수적이지 않다 ? : ab?c =>  abc or ac

# %% [markdown]
# re - match() , search() , findall() , finditer()

# %%
m = re.compile('[a-zA-Z0-9_]')
m
# Out:
# re.compile(r'[a-zA-Z0-9_]', re.UNICODE)

# %%
m.match('python')
# Out:
# <re.Match object; span=(0, 1), match='p'>

# %%
result = m.findall('life is too short')
print(result)
# Out:
# ['l', 'i', 'f', 'e', 'i', 's', 't', 'o', 'o', 's', 'h', 'o', 'r', 't']

# %%
print('ol ul 포함하는 값을 추출하고 싶다면? - ')
soup.find_all(re.compile('[ou]l'))
# Out:
# ol ul 포함하는 값을 추출하고 싶다면? -
# [<ul class="_1knjz49m _1s38h9c5"><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2 _1knjz49q" href="https://www.daangn.com">중고거래</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/nearby-stores/">동네가게</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/jobs/">알바</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/realty/">부동산 직거래</a></li><li class="_1knjz49o"><a class="_1knjz49p _1s38h9c4 _1s38h9c2" href="/kr/car/">중고차 직거래</a></li></ul>,
#  <ul class="_1trxeqsa"><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://www.daangn.com/hot_articles" target="_blank">중고거래</a></li><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://www.daangn.com/kr/nearby-stores" target="_blank">동네가게</a></li><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://www.daangn.com/kr/jobs" target="_blank">당근알바</a></li><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://www.daangn.com/kr/realty" target="_blank">부동산 직거래</a></li><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://www.daangn.com/kr/car" target="_blank">중고차 직거래</a></li></ul>,
#  <ul class="_1trxeqsa"><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://business.daangn.com" target="_blank">당근비즈니스</a></li><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://chat.daangn.com/onboarding" target="_blank">채팅하기</a></li></ul>,
#  <ul class="_1trxeqsa"><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://cs.kr.karrotmarket.com/wv/faqs" target="_blank">자주 묻는 질문</a></li><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://about.daangn.com" target="_blank">회사 소개</a></li><li class="_1trxeqsp"><a class="undefined _1trxeqso" href="https://about.daangn.com/jobs" target="_blank">인재 채용</a></li></ul>]

# %%
print(soup.find_all(re.compile('h[1-9]')))
# Out:
# [<h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>, <h2 class="card-title">아이폰13</h2>, <h2 class="card-title">코카콜라 미니 냉장고 판매</h2>, <h2 class="card-title">전화주세요 01048506787</h2>, <h2 class="card-title">농약분무기 가져가세요</h2>, <h2 class="card-title">아이폰 팔아요</h2>, <h2 class="card-title">나이키 운동화 새제품</h2>, <h2 class="card-title">크록스 260</h2>, <h2 class="card-title">중고 컨테이너 3*6 판매 합니다 / 급처분</h2>, <h2 class="card-title">세차기 세척기</h2>, <h2 class="card-title">자전거</h2>, <h2 class="card-title">삼성제습기</h2>, <h2 class="card-title">베베드피노 키즈 올오버 베들링턴 BP31PH315 세트 100 110 120 130</h2>, <h2 class="card-title">중고컨테이너 판매</h2>, <h2 class="card-title">커피믹스</h2>, <h2 class="card-title">수납함 팝니다</h2>, <h2 class="card-title">트레일러 팝니다.</h2>, <h2 class="card-title">모니터 새거 팔어요</h2>, <h2 class="card-title">노비타 6리터 가성비 제습기</h2>, <h2 class="card-title">갤럭시버즈 판매(버즈2 pro)</h2>, <h2 class="card-title">자전거 3만원</h2>, <h2 class="card-title">포르쉐 푸쉬카 판매합니다. (제일 먼저 챗주신분께 예약잡았습니다)</h2>, <h2 class="card-title">아이폰11pro팝니다</h2>, <h2 class="card-title">아우디 푸쉬카</h2>, <h2 class="card-title">놀라운자연</h2>, <h2 class="card-title">대우냉장고 판매</h2>, <h2 class="card-title">수납장 선반 팝니다</h2>, <h2 class="card-title">냉장고 상태 양호 가져가실분</h2>, <h2 class="card-title">수납장 책상 조명 등등 각각 5천원에 팝니다</h2>, <h2 class="card-title">이사 물품 처리합니다!!(협탁, 실내자전거)</h2>, <h2 class="card-title">위닉스제습기 16리터</h2>, <h2 class="card-title">야외 테이블의자</h2>, <h2 class="card-title">스트라이더 밸런스 바이크 블랙</h2>, <h2 class="card-title">앵글 선반 팝니다</h2>, <h2 class="card-title">스팸</h2>, <h2 class="card-title">티티카카 접이식자전거</h2>, <h2 class="card-title">이사가서 내놓습니다.</h2>, <h2 class="card-title">에어팟 프로 급처 합니다 !</h2>, <h2 class="card-title">세탁기&amp;냉장고 판매합니다.</h2>, <h2 class="card-title">벽걸이 에어컨) 팝니다</h2>, <h2 class="card-title">예초기 팝니다</h2>, <h2 class="card-title">[여름대비] 위니아 제습기 11리터  20년 출시제품</h2>, <h2 class="card-title">전기톱 마끼다</h2>, <h2 class="card-title">진짜 급해요 사례금 드립니다</h2>, <h2 class="card-title">삼성 제습기</h2>, <h2 class="card-title">벽걸이 에어컨 판매</h2>, <h2 class="card-title">마샬 액톤2 블랙</h2>, <h2 class="card-title">구찌가방</h2>, <h2 class="card-title">텐트 처분</h2>, <h2 class="card-title">위니아제습기</h2>, <h2 class="card-title">다 가져가세요</h2>, <h2 class="card-title">10년 된 컴퓨터 판매합니다.</h2>, <h2 class="card-title">위니아제습기 이사로싸게내놓아요</h2>, <h2 class="card-title">스트라이더 밸런스 바이크 12인치 판매합니다!</h2>, <h2 class="card-title">제습기 판매합니다.</h2>, <h2 class="card-title">우유 떨이합니다 5,000원 (유통기한 15일까지)</h2>, <h2 class="card-title">샤넬 카드지갑 떨이</h2>, <h2 class="card-title">다이슨 싸이클론 V10무선청소기</h2>, <h2 class="card-title">선반</h2>, <h2 class="card-title">100원이예요~~</h2>, <h2 class="card-title">베이비젠 요요6+ (에어프랑스 컬러팩 추가)</h2>, <h2 class="card-title">레노버 새거 팝니다</h2>, <h2 class="card-title">65인치 LED TV 팝니다^^</h2>, <h2 class="card-title">위니아 제습기</h2>, <h2 class="card-title">LG 건조기</h2>, <h2 class="card-title">BMW 골프백</h2>, <h2 class="card-title">가구</h2>, <h2 class="card-title">(급처)부산 해운대 반월풀빌라(신상숙소)</h2>, <h2 class="card-title">LG 코드제로9 청소기 팝니다.</h2>, <h2 class="card-title">삼성 겔러리 무풍 2in1 에어컨 판매합니다</h2>, <h2 class="card-title">게이밍 컴퓨터 데스크탑</h2>, <h2 class="card-title">루이비통 몽테뉴</h2>, <h2 class="card-title">144hz 무결점 게이밍 모니터 +모니터암 팝니다.</h2>, <h2 class="card-title">제습기 10L</h2>, <h2 class="card-title">꽃잔디 소분해 드립니다.(무료)</h2>, <h2 class="card-title">전자렌지</h2>, <h2 class="card-title">캐리어 염가판매</h2>, <h2 class="card-title">편백</h2>, <h2 class="card-title">나이키</h2>, <h2 class="card-title">DEWALT 충전드릴</h2>, <h2 class="card-title">쌀</h2>, <h2 class="card-title">새상품라코스테 반팔티</h2>, <h2 class="card-title">베트남 동 팔아요</h2>, <h2 class="card-title">LG TV 45인치</h2>, <h2 class="card-title">프라다 가방</h2>, <h2 class="card-title">도레미곰 전집 50권</h2>, <h2 class="card-title">미니 pc 부품용팝니다</h2>, <h2 class="card-title">코웨이  제습기</h2>, <h2 class="card-title">맥북프로 팝니다</h2>, <h2 class="card-title">나이키 신발</h2>, <h2 class="card-title">칼</h2>, <h2 class="card-title">초등학생자전거</h2>, <h2 class="card-title">고구마 3kg  가져가실분</h2>, <h2 class="card-title">금반지</h2>, <h2 class="card-title">루이비통 정품가방</h2>, <h2 class="card-title">갤럭시노트20 팝니다.</h2>, <h2 class="card-title">농약 분무기</h2>, <h2 class="card ...
#         더 구경하고 싶나요?
#     </h3>]

# %% [markdown]
# - 속성을 활용하는 방법 : attrs

# %%
# class 속성으로 찾아오기
# class 이름으로 찾아올 수 있다.

lst =  soup.find_all(attrs = {'class' : 'card-title'})
for title in lst :
    print(title.string)
# Out:
# 아이폰13
# 코카콜라 미니 냉장고 판매
# 전화주세요 01048506787
# 농약분무기 가져가세요
# 아이폰 팔아요
# 나이키 운동화 새제품
# 크록스 260
# 중고 컨테이너 3*6 판매 합니다 / 급처분
# 세차기 세척기
# 자전거
# 삼성제습기
# 베베드피노 키즈 올오버 베들링턴 BP31PH315 세트 100 110 120 130
# 중고컨테이너 판매
# 커피믹스
# 수납함 팝니다
# 트레일러 팝니다.
# 모니터 새거 팔어요
# 노비타 6리터 가성비 제습기
# 갤럭시버즈 판매(버즈2 pro)
# 자전거 3만원
# 포르쉐 푸쉬카 판매합니다. (제일 먼저 챗주신분께 예약잡았습니다)
# 아이폰11pro팝니다
# 아우디 푸쉬카
# 놀라운자연
# 대우냉장고 판매
# 수납장 선반 팝니다
# 냉장고 상태 양호 가져가실분
# 수납장 책상 조명 등등 각각 5천원에 팝니다
# 이사 물품 처리합니다!!(협탁, 실내자전거)
# 위닉스제습기 16리터
# 야외 테이블의자
# 스트라이더 밸런스 바이크 블랙
# 앵글 선반 팝니다
# 스팸
# 티티카카 접이식자전거
# 이사가서 내놓습니다.
# 에어팟 프로 급처 합니다 !
# 세탁기&냉장고 판매합니다.
# 벽걸이 에어컨) 팝니다
# 예초기 팝니다
# [여름대비] 위니아 제습기 11리터  20년 출시제품
# 전기톱 마끼다
# 진짜 급해요 사례금 드립니다
# 삼성 제습기
# 벽걸이 에어컨 판매
# 마샬 액톤2 블랙
# 구찌가방
# 텐트 처분
# 위니아제습기
# 다 가져가세요
# 10년 된 컴퓨터 판매합니다.
# 위니아제습기 이사로싸게내놓아요
# 스트라이더 밸런스 바이크 12인치 판매합니다!
# 제습기 판매합니다.
# 우유 떨이합니다 5,000원 (유통기한 15일까지)
# 샤넬 카드지갑 떨이
# 다이슨 싸이클론 V10무선청소기
# 선반
# 100원이예요~~
# 베이비젠 요요6+ (에어프랑스 컬러팩 추가)
# 레노버 새거 팝니다
# 65인치 LED TV 팝니다^^
# 위니아 제습기
# LG 건조기
# BMW 골프백
# 가구
# (급처)부산 해운대 반월풀빌라(신상숙소)
# LG 코드제로9 청소기 팝니다.
# 삼성 겔러리 무풍 2in1 에어컨 판매합니다
# 게이밍 컴퓨터 데스크탑
# 루이비통 몽테뉴
# 144hz 무결점 게이밍 모니터 +모니터암 팝니다.
# 제습기 10L
# 꽃잔디 소분해 드립니다.(무료)
# 전자렌지
# 캐리어 염가판매
# 편백
# 나이키
# DEWALT 충전드릴
# 쌀
# 새상품라코스테 반팔티
# 베트남 동 팔아요
# LG TV 45인치
# 프라다 가방
# 도레미곰 전집 50권
# 미니 pc 부품용팝니다
# 코웨이  제습기
# 맥북프로 팝니다
# 나이키 신발
# 칼
# 초등학생자전거
# 고구마 3kg  가져가실분
# 금반지
# 루이비통 정품가방
# 갤럭시노트20 팝니다.
# 농약 분무기
# 아이패드 프로 5세대 12.9 + 애플펜슬 2세대 판매

# %% [markdown]
# - css 선택자를 이용하는 방법 soup.select(id : #, class : .)

# %%
# '.class_name'  : . 은 클래스임을 의미하고 .class_name으로 class를 지칭하여 select로 가져올 수 있다.

lst = soup.select('.card-title')
for title in lst :
    print(title.get_text())
# Out:
# 아이폰13
# 코카콜라 미니 냉장고 판매
# 전화주세요 01048506787
# 농약분무기 가져가세요
# 아이폰 팔아요
# 나이키 운동화 새제품
# 크록스 260
# 중고 컨테이너 3*6 판매 합니다 / 급처분
# 세차기 세척기
# 자전거
# 삼성제습기
# 베베드피노 키즈 올오버 베들링턴 BP31PH315 세트 100 110 120 130
# 중고컨테이너 판매
# 커피믹스
# 수납함 팝니다
# 트레일러 팝니다.
# 모니터 새거 팔어요
# 노비타 6리터 가성비 제습기
# 갤럭시버즈 판매(버즈2 pro)
# 자전거 3만원
# 포르쉐 푸쉬카 판매합니다. (제일 먼저 챗주신분께 예약잡았습니다)
# 아이폰11pro팝니다
# 아우디 푸쉬카
# 놀라운자연
# 대우냉장고 판매
# 수납장 선반 팝니다
# 냉장고 상태 양호 가져가실분
# 수납장 책상 조명 등등 각각 5천원에 팝니다
# 이사 물품 처리합니다!!(협탁, 실내자전거)
# 위닉스제습기 16리터
# 야외 테이블의자
# 스트라이더 밸런스 바이크 블랙
# 앵글 선반 팝니다
# 스팸
# 티티카카 접이식자전거
# 이사가서 내놓습니다.
# 에어팟 프로 급처 합니다 !
# 세탁기&냉장고 판매합니다.
# 벽걸이 에어컨) 팝니다
# 예초기 팝니다
# [여름대비] 위니아 제습기 11리터  20년 출시제품
# 전기톱 마끼다
# 진짜 급해요 사례금 드립니다
# 삼성 제습기
# 벽걸이 에어컨 판매
# 마샬 액톤2 블랙
# 구찌가방
# 텐트 처분
# 위니아제습기
# 다 가져가세요
# 10년 된 컴퓨터 판매합니다.
# 위니아제습기 이사로싸게내놓아요
# 스트라이더 밸런스 바이크 12인치 판매합니다!
# 제습기 판매합니다.
# 우유 떨이합니다 5,000원 (유통기한 15일까지)
# 샤넬 카드지갑 떨이
# 다이슨 싸이클론 V10무선청소기
# 선반
# 100원이예요~~
# 베이비젠 요요6+ (에어프랑스 컬러팩 추가)
# 레노버 새거 팝니다
# 65인치 LED TV 팝니다^^
# 위니아 제습기
# LG 건조기
# BMW 골프백
# 가구
# (급처)부산 해운대 반월풀빌라(신상숙소)
# LG 코드제로9 청소기 팝니다.
# 삼성 겔러리 무풍 2in1 에어컨 판매합니다
# 게이밍 컴퓨터 데스크탑
# 루이비통 몽테뉴
# 144hz 무결점 게이밍 모니터 +모니터암 팝니다.
# 제습기 10L
# 꽃잔디 소분해 드립니다.(무료)
# 전자렌지
# 캐리어 염가판매
# 편백
# 나이키
# DEWALT 충전드릴
# 쌀
# 새상품라코스테 반팔티
# 베트남 동 팔아요
# LG TV 45인치
# 프라다 가방
# 도레미곰 전집 50권
# 미니 pc 부품용팝니다
# 코웨이  제습기
# 맥북프로 팝니다
# 나이키 신발
# 칼
# 초등학생자전거
# 고구마 3kg  가져가실분
# 금반지
# 루이비통 정품가방
# 갤럭시노트20 팝니다.
# 농약 분무기
# 아이패드 프로 5세대 12.9 + 애플펜슬 2세대 판매

# %%
# '#id_name' : #은 id 임을 의미하고 #id_name으로 id를 지칭하여 select로 가져올 수 있다.
# > div  : 자손 선택자 '>' 표현으로 하위태그로 내려갈 수 있다.

soup.select('#hot-articles-go-download')
soup.select('#hot-articles-go-download > div')
soup.select('#hot-articles-go-download > div > a')
soup.select('#hot-articles-go-download > div > a > div')
# Out:
# [<div class="home-apple-store-bar-white"></div>,
#  <div class="download-text">App Store</div>,
#  <div class="home-google-play-bar-white"></div>,
#  <div class="download-text">Google Play</div>]

# %%
# 예외처리를 하여 오류를 잡도록 하자.

try :
    html = urlopen('https://www.daangn.com/hot_articles')
except HTTPError as he :
    print('http error')
except URLError  as ue :
    print('url error')
else :
    soup = BeautifulSoup(html.read() , 'html.parser')

# %%
https://www.pythonscraping.com/pages/page3.html
response = requests.get(url)

# %%
try :
    html = urlopen('https://www.pythonscraping.com/pages/page3.html')
except HTTPError as he :
    print('http error')
except URLError  as ue :
    print('url error')
else :
    soup = BeautifulSoup(html.read() , 'html.parser')

# %%
table = soup.find('table' , {'id' : 'giftList'})
table
# Out:
# <table id="giftList">
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>
# </table>

# %%
title_lst = []
desc_lst  = []
cost_lst  = []
img_lst   = []

for tr in table.find_all('tr') :
    tds = tr.find_all('td')
    for td in tds :
        print(td)
        print('------------------')
        
        if td.find('img') :
            print()
            print('********* pass if ***********')
            print()
            title = tds[0].text.strip()
            title_lst.append(title)
            desc = tds[1].text.strip()
            desc_lst.append(desc)
            cost = tds[2].text.strip()
            cost_lst.append(cost)
            img  = tds[3].find('img')['src']
            img_lst.append(img)

display(title_lst)
display(desc_lst)
display(cost_lst)
display(img_lst)
# Out:
# <td>
# Vegetable Basket
# </td>
# ------------------
# <td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td>
# ------------------
# <td>
# $15.00
# </td>
# ------------------
# <td>
# <img src="../img/gifts/img1.jpg"/>
# </td>
# ------------------
#
# ********* pass if ***********
#
# <td>
# Russian Nesting Dolls
# </td>
# ------------------
# <td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td>
# ------------------
# <td>
# $10,000.52
# </td>
# ------------------
# <td>
# <img src="../img/gifts/img2.jpg"/>
# </td>
# ------------------
#
# ********* pass if ***********
#
# <td>
# Fish Painting
# </td>
# ------------------
# <td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td>
# ------------------
# <td>
# $10,005.00
# </td>
# ------------------
# <td>
# <img src="../img/gifts/img3.jpg"/>
# </td>
# ------------------
#
# ********* pass if ***********
#
# <td>
# Dead Parrot
# </td>
# ------------------
# <td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td>
# ------------------
# <td>
# $0.50
# </td>
# ------------------
# <td>
# <img src="../img/gifts/img4.jpg"/>
# </td>
# ------------------
#
# ********* pass if ***********
#
# <td>
# Mystery Box
# </td>
# ------------------
# <td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td>
# ------------------
# <td>
# $1.50
# </td>
# ------------------
# <td>
# <img src="../img/gifts/img6.jpg"/>
# </td>
# ------------------
#
# ********* pass if ***********
# ['Vegetable Basket',
#  'Russian Nesting Dolls',
#  'Fish Painting',
#  'Dead Parrot',
#  'Mystery Box']
# ['This vegetable basket is the perfect gift for your health conscious (or overweight) friends!\nNow with super-colorful bell peppers!',
#  'Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! 8 entire dolls per set! Octuple the presents!',
#  "If something seems fishy about this painting, it's because it's a fish! Also hand-painted by trained monkeys!",
#  "This is an ex-parrot! Or maybe he's only resting?",
#  'If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. Keep your friends guessing!']
# ['$15.00', '$10,000.52', '$10,005.00', '$0.50', '$1.50']
# ['../img/gifts/img1.jpg',
#  '../img/gifts/img2.jpg',
#  '../img/gifts/img3.jpg',
#  '../img/gifts/img4.jpg',
#  '../img/gifts/img6.jpg']

# %%
df = {'title' : title_lst , 
      'desc'  : desc_lst  , 
      'cost'  : cost_lst  , 
      'img'   : img_lst }
df
pd.DataFrame(df)
# Out:
#                    title                                               desc  \
# 0       Vegetable Basket  This vegetable basket is the perfect gift for ...
# 1  Russian Nesting Dolls  Hand-painted by trained monkeys, these exquisi...
# 2          Fish Painting  If something seems fishy about this painting, ...
# 3            Dead Parrot  This is an ex-parrot! Or maybe he's only resting?
# 4            Mystery Box  If you love suprises, this mystery box is for ...
#
#          cost                    img
# 0      $15.00  ../img/gifts/img1.jpg
# 1  $10,000.52  ../img/gifts/img2.jpg
# 2  $10,005.00  ../img/gifts/img3.jpg
# 3       $0.50  ../img/gifts/img4.jpg
# 4       $1.50  ../img/gifts/img6.jpg

# %%
lst = []
for i in [0,4,8,16] :
    print(i)
    print(soup.select('.gift > td')[i].text.strip())
    lst.append(soup.select('.gift > td')[i].text.strip())
lst
# Out:
# 0
# Vegetable Basket
# 4
# Russian Nesting Dolls
# 8
# Fish Painting
# 16
# Mystery Box
# ['Vegetable Basket', 'Russian Nesting Dolls', 'Fish Painting', 'Mystery Box']

# %%
m = re.compile('[^\n]')
#m = re.compile('[a-z]')
#m = re.compile('\S')
data = soup.select('.gift > td')[0].string
data
m.findall(data)
# Out:
# ['V',
#  'e',
#  'g',
#  'e',
#  't',
#  'a',
#  'b',
#  'l',
#  'e',
#  ' ',
#  'B',
#  'a',
#  's',
#  'k',
#  'e',
#  't']

# %%
m = re.compile('[a-z]+')
m
result = m.findall('life is too short')
print(result)
# Out:
# ['life', 'is', 'too', 'short']

# %%
re - match() , search() , findall() , finditer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 re - match() , search() , findall() , finditer()
#
# NameError: name 'match' is not defined
